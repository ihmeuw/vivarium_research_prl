# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd
pd.set_option('display.max_rows', 40)

from splink.duckdb.duckdb_linker import DuckDBLinker
import splink.duckdb.duckdb_comparison_library as cl

# For viewing waterfall chargs
import altair as alt
alt.renderers.enable('mimetype')
# Note: As far as I saw, the Splink documentation didn't ever specify that
# I needed to enable the 'html' renderer, but the waterfall chart and
# precision-recall curve did not display until I added this line (thanks to Zeb)
alt.renderers.enable('html')

# For viewing the comparison viewer dashboard
from IPython.display import IFrame

# !date
# !whoami
# !uname -a
# !pwd
# Out:
# Fri 06 Jan 2023 08:43:15 PM PST
# ndbs
# Linux int-slurm-sarchive-p0001 5.4.0-88-generic #99-Ubuntu SMP Thu Sep 23 17:29:00 UTC 2021 x86_64 x86_64 x86_64 GNU/Linux
# /mnt/share/code/ndbs/vivarium_research_prl/linkage/demo_notebooks

# %% [markdown]
# # Goal: Complete the prediction and linking steps of the Splink tutorial

# %% [markdown]
# # Load previously saved census test data

# %%
# !ls -l splink_test_data/
# Out:
# total 4192
# -rw-rw-r-- 1 ndbs Domain Users 1059095 Jan  6 15:44 census_2020_test_sample.csv
# -rw-rw-r-- 1 ndbs Domain Users  958764 Jan  6 15:44 census_2030_test_sample.csv
# -rw-rw-r-- 1 ndbs Domain Users 1127312 Jan  5 14:26 cluster_studio.html
# -rw-rw-r-- 1 ndbs Domain Users 1109892 Jan  5 14:26 comparison_viewer.html
# -rw-rw-r-- 1 ndbs Domain Users    5866 Jan  6 15:44 saved_model_from_census_test.json

# %%
test_data_path = 'splink_test_data'

years = [2020, 2030]

census = {
    year:
    pd.read_csv(f"{test_data_path}/census_{year}_test_sample.csv", index_col=0)
    for year in years
}
for year in years:
    print(year, census[year].shape)
# Out:
# 2020 (9495, 11)
# 2030 (8539, 11)

# %%
census[2020]
# Out:
#       first_name   last_name  age date_of_birth  \
# 0       Margaret       Clark   68    1951-07-27
# 1        Jeffrey  Littlejohn   52    1967-05-03
# 2         Briana     Jackson   13    2006-09-07
# 3       Benjamin         Cox   21    1998-10-21
# 4         Willie      Tucker   72    1947-10-09
# ...          ...         ...  ...           ...
# 9995       Jordy      Thomas    9    2011-03-27
# 9997        Carl    Saunders   72    1948-01-24
# 9998       Julie     Hasapis   60    1959-07-23
# 9999       Jason       Cains   23    1996-10-15
# 10000      Megan     Judycki   27    1992-10-22
#
#                                     address  zipcode  \
# 0           1344 winoka rd  brooksville, fl    34601
# 1               927 23rd st  clearwater, fl    34698
# 2               927 23rd st  clearwater, fl    34698
# 3               927 23rd st  clearwater, fl    34698
# 4      8904 167th place  fleming island, fl    32003
# ...                                     ...      ...
# 9995   8 bainridge raod  unincorporated, fl    33446
# 9997         16901 sw 66 st  fort myers, fl    33916
# 9998         16901 sw 66 st  fort myers, fl    33916
# 9999   137 belle terre blvd  vero beach, fl    32967
# 10000  137 belle terre blvd  vero beach, fl    32967
#
#       relation_to_household_head     sex race_ethnicity middle_initial  \
# 0               Reference person  Female          Black              J
# 1               Reference person    Male          Black              V
# 2               Biological child  Female          Black              A
# 3                      Stepchild    Male          Black              D
# 4               Reference person    Male          White              J
# ...                          ...     ...            ...            ...
# 9995            Biological child    Male          White              N
# 9997            Reference person    Male          White              M
# 9998              Opp-sex spouse  Female          White              K
# 9999            Reference person    Male          White              E
# 10000             Opp-sex spouse  Female          White              A
#
#        unique_id
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 9995        9995
# 9997        9997
# 9998        9998
# 9999        9999
# 10000      10000
#
# [9495 rows x 11 columns]

# %% [markdown]
# # Load saved model
#
# [Loading saved model](https://moj-analytical-services.github.io/splink/demos/04_Predicting_results.html#load-estimated-model-from-previous-tutorial) from Splink documentation:
#
# ```python
# linker = DuckDBLinker(df) # The demo was for de-duplication, so only one df
# linker.load_settings_from_json("./demo_settings/saved_model_from_demo.json")
# ```

# %%
linker = DuckDBLinker([census[2020], census[2030]])
linker.load_settings_from_json(f"{test_data_path}/saved_model_from_census_test.json")
linker

# %% [markdown]
# # Predicting which records match
#
# [04 Predicting results](https://moj-analytical-services.github.io/splink/demos/04_Predicting_results.html)
# (Predicting which records match)
#
# > We use `linker.predict()` to run the model.
# >
# > Under the hood this will:
# >
# > Generate all pairwise record comparisons that match at least one of the blocking_rules_to_generate_predictions
# >
# > Use the rules specified in the Comparisons to evaluate the similarity of the input data
# >
# > Use the estimated match weights, applying term frequency adjustments where requested to produce the final match_weight and match_probability scores
# >
# > Optionally, a `threshold_match_probability` or `threshold_match_weight` can be provided, which will drop any row where the predicted score is below the threshold.

# %%
# %%time
df_predictions = linker.predict(threshold_match_probability=0.2)
df_predictions.as_pandas_dataframe(limit=5)
# Out:
# CPU times: user 2.84 s, sys: 22.1 ms, total: 2.87 s
# Wall time: 1.49 s
#    match_weight  match_probability source_dataset_l  unique_id_l  \
# 0      2.043369           0.804766               _a            0
# 1      2.043369           0.804766               _a            1
# 2     10.844743           0.999457               _a            3
# 3      2.043369           0.804766               _a            4
# 4     10.844743           0.999457               _a            5
#
#   source_dataset_r  unique_id_r first_name_l first_name_r  gamma_first_name  \
# 0               _b            0     Margaret     Margaret                 3
# 1               _b            1      Jeffrey      Jeffrey                 3
# 2               _b            3     Benjamin     Benjamin                 3
# 3               _b            4       Willie       Willie                 3
# 4               _b            5        Frank        Frank                 3
#
#    bf_first_name  ...   sex_r gamma_sex    bf_sex  age_l age_r gamma_age  \
# 0     233.313863  ...  Female         1  1.987779     68    70         0
# 1     233.313863  ...    Male         1  1.987779     52    53         0
# 2     233.313863  ...    Male         1  1.987779     21    31         2
# 3     233.313863  ...    Male         1  1.987779     72    78         0
# 4     233.313863  ...    Male         1  1.987779     80    90         2
#
#       bf_age  zipcode_l  zipcode_r  match_key
# 0   0.169551      34601      34601          0
# 1   0.169551      34698      33428          0
# 2  75.644595      34698      32164          0
# 3   0.169551      32003      32003          0
# 4  75.644595      32218      32218          0
#
# [5 rows x 25 columns]

# %%
df_predictions.as_pandas_dataframe().shape
# Out:
# (8246, 25)

# %% [markdown]
# # Cluster the predictions
#
# https://moj-analytical-services.github.io/splink/demos/04_Predicting_results.html#clustering
#
# > Often, an alternative representation of this result is more useful, where each row is an input record, and where records link, they are assigned to the same cluster.
# >
# > The algorithm that converts between the pairwise results and the clusters is called connected components, and it is included in Splink.

# %%
# %%time
clusters = linker.cluster_pairwise_predictions_at_threshold(
    df_predictions, threshold_match_probability=0.5
)
clusters.as_pandas_dataframe(limit=10)
# Out:
# Completed iteration 1, root rows count 0
# CPU times: user 179 ms, sys: 56.5 ms, total: 236 ms
# Wall time: 172 ms
#    cluster_id source_dataset first_name     last_name  age date_of_birth  \
# 0  _a-__-1303             _a       Mary         Smith   71    1948-08-31
# 1  _a-__-2010             _b    William       Schmidt   77    1953-04-12
# 2  _a-__-6200             _b      Kelly         Smith   47    1982-11-23
# 3  _a-__-1004             _a   Jennifer       Wallace   47    1973-02-13
# 4  _a-__-1080             _a      Trent        Wallen   20    2000-03-04
# 5  _a-__-1153             _a     Ramona         Defoy   63    1956-06-27
# 6  _a-__-1173             _a    Michael         Lower   13    2007-03-30
# 7  _a-__-1305             _a    Mildred  Benton Ivers   81    1939-01-01
# 8   _a-__-143             _a    Anthony        Miller   49    1970-07-31
# 9  _a-__-1464             _a    Katelyn         Firth   14    2005-06-22
#
#                                       address zipcode  \
# 0              16263 119th pl ne  lk land, fl   33810
# 1    5047-5059 cherrybark ln se  palm bay, fl   32907
# 2  5785 north tegner ro apt 107 l sunrise, fl   33351
# 3               4475 13th st  spring hill, fl   34606
# 4       10615 nevada avenue  jacksonville, fl   32224
# 5         313 w commerce st  jacksonville, fl   32205
# 6                1556 spring st  lakeland, fl   33813
# 7                   352 plms ave  orlando, fl   32811
# 8   8828 upper 89th street cir s  orlando, fl   32807
# 9            6808 harrowdale r  riverview, fl   33578
#
#   relation_to_household_head     sex race_ethnicity middle_initial  unique_id
# 0           Reference person  Female          Black              M       6778
# 1           Reference person    Male          White              L       2010
# 2           Reference person  Female          White              M       6200
# 3          Other nonrelative  Female          White              R       1004
# 4           Biological child    Male          White              M       1080
# 5           Reference person  Female          White              D       1153
# 6           Biological child    Male          White              D       1173
# 7           Reference person  Female          White              J       1305
# 8           Reference person    Male          Black              M        143
# 9           Biological child  Female          White              R       1464

# %%
clusters.as_pandas_dataframe().shape
# Out:
# (18034, 13)

# %% [markdown]
# # Plot a waterfall chart
#
# https://moj-analytical-services.github.io/splink/demos/05_Visualising_predictions.html
#
# Well, that's annoying. It didn't work for some arcane reason.

# %%
records_to_view  = df_predictions.as_record_dict(limit=5)
linker.waterfall_chart(records_to_view, filter_nulls=False)
# Out:
# <div id="altair-viz-1d802640b40f45f280a810e184b43aa7"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-1d802640b40f45f280a810e184b43aa7") {
#       outputDiv = document.getElementById("altair-viz-1d802640b40f45f280a810e184b43aa7");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"$schema": "https://vega.github.io/schema/vega-lite/v5.2.0.json", "height": 450, "resolve": {"axis": {"y": "independent"}}, "width": {"step": 75}, "data": {"values": [{"column_name": "Prior", "label_for_charts": "Starting match weight (prior)", "sql_condition": null, "log2_bayes_factor": -13.287884990728086, "bayes_factor": 9.998803622053661e-05, "comparison_vector_value": null, "m_probability": null, "u_probability": null, "bayes_factor_description": null, "value_l": "", "value_r": "", "term_frequency_adjustment": null, "bar_sort_order": 0, "record_number": 0}, {"column_name": "first_name", "label_for_charts": "Exact match", "sql_condition": "\"first_name_l\" = \"first_name_r\"", "log2_bayes_factor": 7.866128219691629, "bayes_factor": 233.31386271870795, "comparison_vector_value": 3, "m_probability": 1.0, "u_probability": 0.004286071939092783, "bayes_factor_description": "If comparison level is `exact match` then comparison is 233.31 times more likely to be a match", "value_l": "Margaret", "value_r": "Margaret", "term_frequency_adjustment": false, "bar_sort_order": 1, "record_number": 0}, {"column_name": "last_name", "label_for_charts": "Exact match", "sql_condition": "\"last_name_l\" = \"last_name_r\"", "log2_bayes_factor": 9.034177542187416, "bayes_factor": 524.2741277266608, "comparison_vector_value": 3, "m_probability": 0.9998432475990155, "u_probability": 0.0019071001117955237, "bayes_factor_description": "If comparison level is `exact match` then comparison is 524.27 times more likely to be a match", "value_l": "Clark", "value_r": "Clark", "term_frequency_adjustment": false, "bar_sort_order": 2, "record_number": 0}, {"column_name": "sex", "label_for_charts": "Exact match", "sql_condition": "\"sex_l\" = \"sex_r\"", "log2_bayes_factor": 0.9911572113511078, "bayes_factor": 1.9877787842997856, "comparison_vector_value": 1, "m_probability": 1.0, "u_probability": 0.5030740884742161, "bayes_factor_description": "If comparison level is `exact match` then comparison is 1.99 times more likely to be a match", "value_l": "Female", "value_r": "Female", "term_frequency_adjustment": false, "bar_sort_order": 3, "record_number": 0}, {"column_name": "age", "label_for_charts": "Age difference >= 2 years", "sql_condition": "ELSE", "log2_bayes_factor": -2.560209234863704, "bayes_factor": 0.16955094907932705, "comparison_vector_value": 0, "m_probability": 0.1643026142283147, "u_probability": 0.9690456769513165, "bayes_factor_description": "If comparison level is `age difference >= 2 years` then comparison is  5.90 times less likely to be a match", "value_l": "68", "value_r": "70", "term_frequency_adjustment": false, "bar_sort_order": 4, "record_number": 0}, {"column_name": "Final score", "label_for_charts": "Final score", "sql_condition": null, "log2_bayes_factor": 2.043368747638362, "bayes_factor": 4.1220692658520335, "comparison_vector_value": null, "m_probability": null, "u_probability": null, "bayes_factor_description": null, "value_l": "", "value_r": "", "term_frequency_adjustment": null, "bar_sort_order": 5, "record_number": 0}, {"column_name": "Prior", "label_for_charts": "Starting match weight (prior)", "sql_condition": null, "log2_bayes_factor": -13.287884990728086, "bayes_factor": 9.998803622053661e-05, "comparison_vector_value": null, "m_probability": null, "u_probability": null, "bayes_factor_description": null, "value_l": "", "value_r": "", "term_frequency_adjustment": null, "bar_sort_order": 0, "record_number": 1}, {"column_name": "first_name", "label_for_charts": "Exact match", "sql_condition": "\"first_name_l\" = \"first_name_r\"", "log2_bayes_factor": 7.866128219691629, "bayes_factor": 233.31386271870795, "comparison_vector_value": 3, "m_probability": 1.0, "u_probability": 0.004286071939092783, "bayes_factor_description": "If comparison level is `exact match` then comparison is 233.31 times more likely to be a match", "value_l": "Jeffrey", "value_r": "Jeffrey", "term_frequency_adjustment": false, "bar_sort_order": 1, " ...

# %% [markdown]
# # Make a comparison viewer dashboard
#
# https://moj-analytical-services.github.io/splink/demos/05_Visualising_predictions.html

# %%
comparison_viewer_filpath = f"{test_data_path}/comparison_viewer.html"

linker.comparison_viewer_dashboard(
    df_predictions, comparison_viewer_filpath, overwrite=True
)

# You can view the scv.html file in your browser, or inline in a notbook as follows
IFrame(
    src=comparison_viewer_filpath, width="100%", height=1200
)
# Out:
#         <iframe
#             width="100%"
#             height="1200"
#             src="splink_test_data/comparison_viewer.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Cluster studio dashboard
#
# https://moj-analytical-services.github.io/splink/demos/05_Visualising_predictions.html#cluster-studio-dashboard

# %%
cluster_studio_filepath = f"{test_data_path}/cluster_studio.html"

linker.cluster_studio_dashboard(
    df_predictions,
    clusters,
    cluster_studio_filepath,
    sampling_method="by_cluster_size",
    overwrite=True)

# You can view the scv.html file in your browser, or inline in a notbook as follows
IFrame(
    src=cluster_studio_filepath, width="100%", height=1200
)
# Out:
#         <iframe
#             width="100%"
#             height="1200"
#             src="splink_test_data/cluster_studio.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Precision-Recall curve

# %%
x = linker.precision_recall_chart_from_labels_column("unique_id")
x
# Out:
# <div id="altair-viz-cea390fccf2e4340a7736b5d743ee543"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-cea390fccf2e4340a7736b5d743ee543") {
#       outputDiv = document.getElementById("altair-viz-cea390fccf2e4340a7736b5d743ee543");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "title": "Precision-recall curve", "data": {"values": [{"truth_threshold": -706.2374224170491, "match_probability": 2.5197171506824158e-213, "row_count": 181415.0, "P": 8106.0, "N": 173309.0, "TP": 8106.0, "TN": 0.0, "FP": 173309.0, "FN": 0.0, "P_rate": 0.0, "N_rate": 0.9553179144859314, "TP_rate": 1.0, "TN_rate": 0.0, "FP_rate": 1.0, "FN_rate": 0.0, "precision": 0.044682081788778305, "recall": 1.0, "F1": 0.08554242551326752}, {"truth_threshold": -639.5858027689569, "match_probability": 2.920710861522797e-193, "row_count": 181415.0, "P": 8106.0, "N": 173309.0, "TP": 8106.0, "TN": 2.0, "FP": 173307.0, "FN": 0.0, "P_rate": 0.0, "N_rate": 0.9553179144859314, "TP_rate": 1.0, "TN_rate": 1.1540081686689518e-05, "FP_rate": 0.9999884366989136, "FN_rate": 0.0, "precision": 0.0446825735270977, "recall": 1.0, "F1": 0.08554332703351974}, {"truth_threshold": -635.5881171329419, "match_probability": 4.665646765230689e-192, "row_count": 181415.0, "P": 8106.0, "N": 173309.0, "TP": 8106.0, "TN": 17.0, "FP": 173292.0, "FN": 0.0, "P_rate": 0.0, "N_rate": 0.9553179144859314, "TP_rate": 1.0, "TN_rate": 9.80906916083768e-05, "FP_rate": 0.9999018907546997, "FN_rate": 0.0, "precision": 0.044686269015073776, "recall": 1.0, "F1": 0.08554964512586594}, {"truth_threshold": -630.7844284373053, "match_probability": 1.3030654881990677e-190, "row_count": 181415.0, "P": 8106.0, "N": 173309.0, "TP": 8106.0, "TN": 178.0, "FP": 173131.0, "FN": 0.0, "P_rate": 0.0, "N_rate": 0.9553179144859314, "TP_rate": 1.0, "TN_rate": 0.0010270673083141446, "FP_rate": 0.9989729523658752, "FN_rate": 0.0, "precision": 0.044725965708494186, "recall": 1.0, "F1": 0.08562283962965012}, {"truth_threshold": -555.1329745621823, "match_probability": 7.732556012809649e-168, "row_count": 181415.0, "P": 8106.0, "N": 173309.0, "TP": 8106.0, "TN": 240.0, "FP": 173069.0, "FN": 0.0, "P_rate": 0.0, "N_rate": 0.9553179144859314, "TP_rate": 1.0, "TN_rate": 0.001384809846058488, "FP_rate": 0.9986152052879333, "FN_rate": 0.0, "precision": 0.044741272926330566, "recall": 1.0, "F1": 0.08565089106559753}, {"truth_threshold": -283.23263714130326, "match_probability": 5.4762147346492335e-86, "row_count": 181415.0, "P": 8106.0, "N": 173309.0, "TP": 8106.0, "TN": 242.0, "FP": 173067.0, "FN": 0.0, "P_rate": 0.0, "N_rate": 0.9553179144859314, "TP_rate": 1.0, "TN_rate": 0.0013963498640805483, "FP_rate": 0.9986036419868469, "FN_rate": 0.0, "precision": 0.04474176466464996, "recall": 1.0, "F1": 0.08565179258584976}, {"truth_threshold": -201.62249156854892, "match_probability": 2.0210741033531607e-61, "row_count": 181415.0, "P": 8106.0, "N": 173309.0, "TP": 8106.0, "TN": 248.0, "FP": 173061.0, "FN": 0.0, "P_rate": 0.0, "N_rate": 0.9553179144859314, "TP_rate": 1.0, "TN_rate": 0.0014309701509773731, "FP_rate": 0.9985690116882324, "FN_rate": 0.0, "precision": 0.04474324733018875, "recall": 1.0, "F1": 0.08565450459718704}, {"truth_threshold": -197.6248059325339, "match_probability": 3.228535209296543e-60, "row_count": 181415.0, "P": 8106.0, "N": 173309.0, "TP": 8106.0, "TN": 249.0, "FP": 173060.0, "FN": 0.0, "P_rate": 0.0, "N_rate": 0.9553179144859314, "TP_rate": 1.0, "TN_rate": 0.0014367401599884033, "FP_rate": 0.998563289642334, "FN_rate": 0.0, "precision": 0.04474349319934845, "recall": 1.0, "F1": 0.08565450459718704}, {"truth_threshold": -182.19941074316108, "match_probability": 1.4207320378155313e-55, "row_count": 181415.0, "P": 8106.0, "N": 173309.0, "TP": 8106.0, "TN": 255.0, "FP": 173054.0, "FN": 0.0, "P_rate": 0.0, "N_rate": 0.9553179144859314, "TP_rate": 1.0, "TN_rate": 0.0014713604468852282, "FP_rate": 0.9985286593437195, "FN_rate": 0.0, "precision": 0.04474497586488724, "recall": 1.0, "F1": 0.08565722405910492}, {"truth_threshold": -170.7285755383645, "match_probability": 4.032530361775173e-52, "row_count": 181415.0, "P": 8106.0, "N": 173309.0, "TP": 8106.0, "TN": 257.0, "FP": 173052.0, "FN": 0.0, "P_rate": 0.0, "N_rate": 0.955317914 ...

# %%
type(x)
# Out:
# splink.charts.VegaliteNoValidate

# %%
x.renderers
# Out:
# RendererRegistry(active='html', registered=['colab', 'default', 'html', 'json', 'jupyterlab', 'kaggle', 'mimetype', 'nteract', 'png', 'svg', 'zeppelin'])

# %%
x.schema_path
# Out:
# ('altair.vegalite.v4.display', 'schema/vega-lite-schema.json')

# %%
x.spec
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v4.8.1.json',
#  'title': 'Precision-recall curve',
#  'data': {'values': [{'truth_threshold': -706.2374224170491,
#     'match_probability': 2.5197171506824158e-213,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 0.0,
#     'FP': 173309.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.0,
#     'FP_rate': 1.0,
#     'FN_rate': 0.0,
#     'precision': 0.044682081788778305,
#     'recall': 1.0,
#     'F1': 0.08554242551326752},
#    {'truth_threshold': -639.5858027689569,
#     'match_probability': 2.920710861522797e-193,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 2.0,
#     'FP': 173307.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 1.1540081686689518e-05,
#     'FP_rate': 0.9999884366989136,
#     'FN_rate': 0.0,
#     'precision': 0.0446825735270977,
#     'recall': 1.0,
#     'F1': 0.08554332703351974},
#    {'truth_threshold': -635.5881171329419,
#     'match_probability': 4.665646765230689e-192,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 17.0,
#     'FP': 173292.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 9.80906916083768e-05,
#     'FP_rate': 0.9999018907546997,
#     'FN_rate': 0.0,
#     'precision': 0.044686269015073776,
#     'recall': 1.0,
#     'F1': 0.08554964512586594},
#    {'truth_threshold': -630.7844284373053,
#     'match_probability': 1.3030654881990677e-190,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 178.0,
#     'FP': 173131.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.0010270673083141446,
#     'FP_rate': 0.9989729523658752,
#     'FN_rate': 0.0,
#     'precision': 0.044725965708494186,
#     'recall': 1.0,
#     'F1': 0.08562283962965012},
#    {'truth_threshold': -555.1329745621823,
#     'match_probability': 7.732556012809649e-168,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 240.0,
#     'FP': 173069.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.001384809846058488,
#     'FP_rate': 0.9986152052879333,
#     'FN_rate': 0.0,
#     'precision': 0.044741272926330566,
#     'recall': 1.0,
#     'F1': 0.08565089106559753},
#    {'truth_threshold': -283.23263714130326,
#     'match_probability': 5.4762147346492335e-86,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 242.0,
#     'FP': 173067.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.0013963498640805483,
#     'FP_rate': 0.9986036419868469,
#     'FN_rate': 0.0,
#     'precision': 0.04474176466464996,
#     'recall': 1.0,
#     'F1': 0.08565179258584976},
#    {'truth_threshold': -201.62249156854892,
#     'match_probability': 2.0210741033531607e-61,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 248.0,
#     'FP': 173061.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.0014309701509773731,
#     'FP_rate': 0.9985690116882324,
#     'FN_rate': 0.0,
#     'precision': 0.04474324733018875,
#     'recall': 1.0,
#     'F1': 0.08565450459718704},
#    {'truth_threshold': -197.6248059325339,
#     'match_probability': 3.228535209296543e-60,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 249.0,
#     'FP': 173060.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.0014367401599884033,
#     'FP_rate': 0.998563289642334,
#     'FN_rate': 0.0,
#     'precision': 0.04474349319934845,
#     'recall': 1.0,
#     'F1': 0.08565450459718704},
#    {'truth_threshold': -182.19941074316108,
#     'match_probability': 1.4207320378155313e-55,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 255.0,
#     'FP': 173054.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.0014713604468852282,
#     'FP_rate': 0.9985286593437195,
#     'FN_rate': 0.0,
#     'precision': 0.04474497586488724,
#     'recall': 1.0,
#     'F1': 0.08565722405910492},
#    {'truth_threshold': -170.7285755383645,
#     'match_probability': 4.032530361775173e-52,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 257.0,
#     'FP': 173052.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.0014829004649072886,
#     'FP_rate': 0.9985170960426331,
#     'FN_rate': 0.0,
#     'precision': 0.04474547132849693,
#     'recall': 1.0,
#     'F1': 0.08565812557935715},
#    {'truth_threshold': -166.73088990234947,
#     'match_probability': 6.441706533149079e-51,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 721.0,
#     'FP': 172588.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.00416019931435585,
#     'FP_rate': 0.9958397746086121,
#     'FN_rate': 0.0,
#     'precision': 0.044860370457172394,
#     'recall': 1.0,
#     'F1': 0.08586864173412323},
#    {'truth_threshold': -161.92720120671294,
#     'match_probability': 1.799100079973156e-49,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 1112.0,
#     'FP': 172197.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.006416285410523415,
#     'FP_rate': 0.9935837388038635,
#     'FN_rate': 0.0,
#     'precision': 0.04495765641331673,
#     'recall': 1.0,
#     'F1': 0.08604729920625687},
#    {'truth_threshold': -155.3031803489917,
#     'match_probability': 1.7745338697068606e-47,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 1291.0,
#     'FP': 172018.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.007449122611433268,
#     'FP_rate': 0.9925508499145508,
#     'FN_rate': 0.0,
#     'precision': 0.04500233009457588,
#     'recall': 1.0,
#     'F1': 0.08612867444753647},
#    {'truth_threshold': -151.30549471297667,
#     'match_probability': 2.834703125893617e-46,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 1358.0,
#     'FP': 171951.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.00783571507781744,
#     'FP_rate': 0.9921643137931824,
#     'FN_rate': 0.0,
#     'precision': 0.04501907899975777,
#     'recall': 1.0,
#     'F1': 0.08615979552268982},
#    {'truth_threshold': -146.50180601734013,
#     'match_probability': 7.917024152297462e-45,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 1444.0,
#     'FP': 171865.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.00833193864673376,
#     'FP_rate': 0.9916680455207825,
#     'FN_rate': 0.0,
#     'precision': 0.045040588825941086,
#     'recall': 1.0,
#     'F1': 0.08619919419288635},
#    {'truth_threshold': -145.0633934712133,
#     'match_probability': 2.1456915572013122e-44,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 1506.0,
#     'FP': 171803.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.008689681068062782,
#     'FP_rate': 0.9913102984428406,
#     'FN_rate': 0.0,
#     'precision': 0.04505611211061478,
#     'recall': 1.0,
#     'F1': 0.08622761815786362},
#    {'truth_threshold': -140.25970477557675,
#     'match_probability': 5.992688167791247e-43,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 1507.0,
#     'FP': 171802.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.0086954515427351,
#     'FP_rate': 0.9913045763969421,
#     'FN_rate': 0.0,
#     'precision': 0.045056361705064774,
#     'recall': 1.0,
#     'F1': 0.08622761815786362},
#    {'truth_threshold': -130.97318628444182,
#     'match_probability': 3.742331892310534e-40,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 1512.0,
#     'FP': 171797.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.008724302053451538,
#     'FP_rate': 0.9912757277488708,
#     'FN_rate': 0.0,
#     'precision': 0.04505761340260506,
#     'recall': 1.0,
#     'F1': 0.08623037487268448},
#    {'truth_threshold': -126.97550064842679,
#     'match_probability': 5.978133240712093e-39,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 1679.0,
#     'FP': 171630.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.009687898680567741,
#     'FP_rate': 0.9903120994567871,
#     'FN_rate': 0.0,
#     'precision': 0.04509947821497917,
#     'recall': 1.0,
#     'F1': 0.08630657941102982},
#    {'truth_threshold': -122.17181195279025,
#     'match_probability': 1.66962899289321e-37,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 2552.0,
#     'FP': 170757.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.014725144021213055,
#     'FP_rate': 0.9852748513221741,
#     'FN_rate': 0.0,
#     'precision': 0.04531960189342499,
#     'recall': 1.0,
#     'F1': 0.08671002835035324},
#    {'truth_threshold': -100.07927025425741,
#     'match_probability': 7.466854854329291e-31,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 3005.0,
#     'FP': 170304.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.01733897253870964,
#     'FP_rate': 0.9826610088348389,
#     'FN_rate': 0.0,
#     'precision': 0.04543467238545418,
#     'recall': 1.0,
#     'F1': 0.08692015707492828},
#    {'truth_threshold': -96.08158461824237,
#     'match_probability': 1.1927817866704162e-29,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 85269.0,
#     'FP': 88040.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.4920056164264679,
#     'FP_rate': 0.5079944133758545,
#     'FN_rate': 0.0,
#     'precision': 0.08430927991867065,
#     'recall': 1.0,
#     'F1': 0.15550780296325684},
#    {'truth_threshold': -91.27789592260584,
#     'match_probability': 3.3313125904545245e-28,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 142233.0,
#     'FP': 31076.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.8206902146339417,
#     'FP_rate': 0.17930978536605835,
#     'FN_rate': 0.0,
#     'precision': 0.20688070356845856,
#     'recall': 1.0,
#     'F1': 0.342835396528244},
#    {'truth_threshold': -78.41177382312122,
#     'match_probability': 2.487161955816345e-24,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 170739.0,
#     'FP': 2570.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.9851710200309753,
#     'FP_rate': 0.014829005114734173,
#     'FN_rate': 0.0,
#     'precision': 0.759273111820221,
#     'recall': 1.0,
#     'F1': 0.863166868686676},
#    {'truth_threshold': -74.41408818710619,
#     'match_probability': 3.97308041909673e-23,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 170791.0,
#     'FP': 2518.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.9854710102081299,
#     'FP_rate': 0.014528962783515453,
#     'FN_rate': 0.0,
#     'precision': 0.7629894614219666,
#     'recall': 1.0,
#     'F1': 0.8655632734298706},
#    {'truth_threshold': -69.61039949146965,
#     'match_probability': 1.1096390782400894e-21,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 171398.0,
#     'FP': 1911.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.9889734387397766,
#     'FP_rate': 0.011026548221707344,
#     'FN_rate': 0.0,
#     'precision': 0.8092243075370789,
#     'recall': 1.0,
#     'F1': 0.8946032524108887},
#    {'truth_threshold': -50.518043713682225,
#     'match_probability': 6.202310726021073e-16,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 171782.0,
#     'FP': 1527.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.9911891222000122,
#     'FP_rate': 0.008810852654278278,
#     'FN_rate': 0.0,
#     'precision': 0.841482400894165,
#     'recall': 1.0,
#     'F1': 0.9139699935913086},
#    {'truth_threshold': -46.52035807766719,
#     'match_probability': 9.907790379746114e-15,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 171783.0,
#     'FP': 1526.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.9911949038505554,
#     'FP_rate': 0.00880508217960596,
#     'FN_rate': 0.0,
#     'precision': 0.8415697813034058,
#     'recall': 1.0,
#     'F1': 0.9139699935913086},
#    {'truth_threshold': -41.71666938203065,
#     'match_probability': 2.767140411135712e-13,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 171789.0,
#     'FP': 1520.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.9912295341491699,
#     'FP_rate': 0.00877046212553978,
#     'FN_rate': 0.0,
#     'precision': 0.8420943021774292,
#     'recall': 1.0,
#     'F1': 0.9142792820930481},
#    {'truth_threshold': -19.624127683497814,
#     'match_probability': 1.2375090711914462e-06,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 171794.0,
#     'FP': 1515.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.9912583827972412,
#     'FP_rate': 0.008741611614823341,
#     'FN_rate': 0.0,
#     'precision': 0.8425319790840149,
#     'recall': 1.0,
#     'F1': 0.9145887494087219},
#    {'truth_threshold': -15.626442047482781,
#     'match_probability': 1.9768040991867023e-05,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 172266.0,
#     'FP': 1043.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.9939818382263184,
#     'FP_rate': 0.0060181524604558945,
#     'FN_rate': 0.0,
#     'precision': 0.8859984874725342,
#     'recall': 1.0,
#     'F1': 0.9396082162857056},
#    {'truth_threshold': -10.822753351846243,
#     'match_probability': 0.000551806602629575,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 172908.0,
#     'FP': 401.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.9976862072944641,
#     'FP_rate': 0.00231378641910851,
#     'FN_rate': 0.0,
#     'precision': 0.9528623223304749,
#     'recall': 1.0,
#     'F1': 0.9759210348129272},
#    {'truth_threshold': 2.043368747638362,
#     'match_probability': 0.8047664043384125,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 8106.0,
#     'TN': 173169.0,
#     'FP': 140.0,
#     'FN': 0.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 1.0,
#     'TN_rate': 0.9991921782493591,
#     'FP_rate': 0.000807805685326457,
#     'FN_rate': 0.0,
#     'precision': 0.9830220937728882,
#     'recall': 1.0,
#     'F1': 0.9914383292198181},
#    {'truth_threshold': 6.041054383653394,
#     'match_probability': 0.9850405531381929,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 7185.0,
#     'TN': 173300.0,
#     'FP': 9.0,
#     'FN': 921.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 0.8863804340362549,
#     'TN_rate': 0.9999480843544006,
#     'FP_rate': 5.1930368499597535e-05,
#     'FN_rate': 0.11361954361200333,
#     'precision': 0.9987489581108093,
#     'recall': 0.8863804340362549,
#     'F1': 0.9392156600952148},
#    {'truth_threshold': 10.844743079289934,
#     'match_probability': 0.9994565357882128,
#     'row_count': 181415.0,
#     'P': 8106.0,
#     'N': 173309.0,
#     'TP': 6776.0,
#     'TN': 173309.0,
#     'FP': 0.0,
#     'FN': 1330.0,
#     'P_rate': 0.0,
#     'N_rate': 0.9553179144859314,
#     'TP_rate': 0.8359240293502808,
#     'TN_rate': 1.0,
#     'FP_rate': 0.0,
#     'FN_rate': 0.16407600045204163,
#     'precision': 1.0,
#     'recall': 0.8359240293502808,
#     'F1': 0.9106302857398987}]},
#  'mark': {'type': 'line', 'clip': True, 'point': True},
#  'encoding': {'tooltip': [{'type': 'quantitative',
#     'field': 'truth_threshold',
#     'format': '.4f'},
#    {'type': 'quantitative', 'field': 'match_probability', 'format': '.4%'},
#    {'type': 'quantitative', 'field': 'FP_rate', 'format': '.4f'},
#    {'type': 'quantitative', 'field': 'TP_rate', 'format': '.4f'},
#    {'type': 'quantitative', 'field': 'TP', 'format': ',.0f'},
#    {'type': 'quantitative', 'field': 'TN', 'format': ',.0f'},
#    {'type': 'quantitative', 'field': 'FP', 'format': ',.0f'},
#    {'type': 'quantitative', 'field': 'FN', 'format': ',.0f'},
#    {'type': 'quantitative', 'field': 'precision', 'format': '.4f'},
#    {'type': 'quantitative', 'field': 'recall', 'format': '.4f'},
#    {'type': 'quantitative', 'field': 'F1', 'format': '.4f'}],
#   'x': {'type': 'quantitative',
#    'field': 'recall',
#    'sort': ['-recall'],
#    'title': 'Recall'},
#   'y': {'type': 'quantitative',
#    'field': 'precision',
#    'sort': ['-precision'],
#    'title': 'Precision'}},
#  'height': 400,
#  'width': 400}

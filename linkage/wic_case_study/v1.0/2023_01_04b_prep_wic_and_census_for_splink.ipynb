# %% [markdown]
# #  Simulated Data – Not CUI

# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd
pd.set_option('display.max_rows', 40)

# from vivarium_research_prl.noise import corruption, fake_names, noisify
from vivarium_research_prl.find_kids import datasets, noisify_data
# import vivarium_research_prl.find_kids as find_kids

from splink.duckdb.duckdb_linker import DuckDBLinker
# import splink.duckdb.duckdb_comparison_library as cl

# # For viewing waterfall charts and precision-recall curve
# import altair as alt
# alt.renderers.enable('mimetype')
# alt.renderers.enable('html')

# # For viewing the comparison viewer dashboard
# from IPython.display import IFrame

# !date
# !whoami
# !uname -a
# !pwd
# Out:
# Fri 27 Jan 2023 10:34:07 AM PST
# ndbs
# Linux int-slurm-sarchive-p0012 5.4.0-88-generic #99-Ubuntu SMP Thu Sep 23 17:29:00 UTC 2021 x86_64 x86_64 x86_64 GNU/Linux
# /mnt/share/code/ndbs/vivarium_research_prl/linkage/wic_case_study

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Goal: Link simulated WIC data to simulated decennial census data to identify kids under 5 that were missed in the census but enrolled in WIC
#
# ### Note
#
# We will do the linkage using [Splink](https://github.com/moj-analytical-services/splink), but any record linkage software could be used in its place.

# %% [markdown]
# # Step 0 – Generate simulated data (Pseudopseudopeople)
#
# This section includes the steps corresponding to what would eventually be handled by our **Pseudopeople package** for simulated data, which is still a work in progress.
#
# ## Load state table of 50,000 simulants from Florida

# %%
project_output_dir = '/mnt/team/simulation_science/priv/engineering/vivarium_census_prl_synth_pop'
output_subdir = 'results/special_last_names/florida/2022_10_14_10_49_32/population_table/'
output_dir = f'{project_output_dir}/{output_subdir}'

# !ls -l $output_dir
# Out:
# total 32224
# -rw-rw-r-- 1 albrja   IHME-Simulationscience 12622072 Oct 20 23:08 decennial_census.hdf
# -rwxrwxrwx 1 beatrixh IHME-Simulationscience 20364830 Nov 14 16:42 state_table.hdf

# %%
state_table_path = f'{output_dir}/state_table.hdf'
df_state_table = pd.read_hdf(state_table_path, 'ymd_2020_4_1')
print(f'{df_state_table.shape=}')
# Out:
# df_state_table.shape=(50000, 27)

# %% [markdown]
# ## Set a random seed and create a random number generator

# %%
sq = np.random.SeedSequence(66624024798819663709061712465147975287)
print(sq.entropy)
rng = np.random.default_rng(sq)
rng
# Out:
# 66624024798819663709061712465147975287
# Generator(PCG64) at 0x7FEE76867740

# %% [markdown]
# ## Generate census and WIC data from state table
#
# - The census data will have some people missing at random
#
# - The WIC data include kids under 5 (but not women) sampled from the state table according to age-specific coverage rates of WIC

# %%
df_census_raw = datasets.generate_census_data(
    df_state_table, overall_frac=0.95, kid_frac=0.90, random_state=rng)
df_wic_raw = datasets.generate_wic_data(df_state_table, rng)
print(f"{df_census_raw.shape=}")
print(f"{df_wic_raw.shape=}")
# Out:
# df_census_raw.shape=(47529, 10)
# df_wic_raw.shape=(633, 10)

# %% [markdown]
# ## Add noise to data

# %%
# Allow setting random seed for reproducibility during testing
random_state = rng
df_census_noisy = noisify_data.add_noise_to_census(df_census_raw, random_state)
df_wic_noisy = noisify_data.add_noise_to_wic(df_wic_raw, random_state)

# %%
df_census_noisy
# Out:
#       first_name middle_initial   last_name date_of_birth   age     sex  \
# 0       Margaret              J       Clark    1951-07-27  68.0  Female
# 1        Jeffrey              V  Littlejohn    1967-05-03  52.0    Male
# 2         Briana              A     Jackson    2006-09-07  13.0  Female
# 3       Benjamin              D         Cox    1998-10-21  21.0    Male
# 4         Willie            NaN      Tucker    1947-10-09  72.0    Male
# ...          ...            ...         ...           ...   ...     ...
# 49994     Marcus              S       Roman    1988-07-08  31.0    Male
# 49996  Nathaniel              J    Campbell    1941-01-08  79.0    Male
# 49997  Christian              C     Rosales    1983-12-16  36.0    Male
# 49998    Phillip              J      Morton    1985-06-11  34.0    Male
# 49999  Catherine              H      Talley    1928-08-14  91.0  Female
#
#              race_ethnicity relation_to_household_head  \
# 0                     Black           Reference person
# 1                     Black           Reference person
# 2                     Black           Biological child
# 3                     Black                  Stepchild
# 4                     White           Reference person
# ...                     ...                        ...
# 49994  Multiracial or Other   Institutionalized GQ pop
# 49996                 White   Institutionalized GQ pop
# 49997                Latino   Institutionalized GQ pop
# 49998                 White   Institutionalized GQ pop
# 49999                 Black   Institutionalized GQ pop
#
#                                     address zipcode
# 0           1344 winoka rd  brooksville, fl   34601
# 1               927 23rd st  clearwater, fl   34698
# 2               927 23rd st  clearwater, fl   34698
# 3               927 23rd st  clearwater, fl   34698
# 4      8904 167th place  fleming island, fl   32003
# ...                                     ...     ...
# 49994   2210 henn hyde rd ne  hollywood, fl   33021
# 49996   2210 henn hyde rd ne  hollywood, fl   33021
# 49997          701 haber rd  vero beach, fl   32968
# 49998         114 s frnt st  fort myers, fl   33919
# 49999         701 haber rd  vero beach, fle   32968
#
# [47529 rows x 10 columns]

# %%
df_wic_noisy
# Out:
#       first_name middle_name  last_name date_of_birth     sex race_ethnicity  \
# 82         Sadie       Katia    Tidwell    2017-10-15  Female          Black
# 83       Liliana     Addisyn   Marshall    2019-12-03  Female          Black
# 174        Holly        Emma      Yount    2019-05-17       M          White
# 306       Emilee   Guadalupe     Haskew    2019-12-30  Female         Latino
# 323       Gunner        Liam  Parkinson    2020-03-03    Male          White
# ...          ...         ...        ...           ...     ...            ...
# 48269     Kaylee     Trinity       Hill    2017-10-20  Female          Black
# 48351        Lev         NaN       Dove    2018-10-18    Male          Black
# 48442  Frederick     Cameron  Rodriguez    2019-06-04    Male         Latino
# 48456       Liam      Emmett    Sardone    2017-01-08    Male          White
# 48458    Cameron         NaN    Emerson    2019-02-16    Male          White
#
#                                     address zipcode  household_id  wic_id
# 82                 w 4th st  north port, fl   34287            48       1
# 83                 w 4th st  north port, fl   34287            48       2
# 174    7944 se 62nd ave  unincorporated, fl   32824            88       3
# 306           749 mi ridge ests  destin, fl   32541           150       4
# 323        600 n maranantha rd  hialeah, fl   33016           157       5
# ...                                     ...     ...           ...     ...
# 48269     98 melanie dr  pembroke pines, fl   33026         20380     629
# 48351   671 john muir road  spring hill, fl   34610         20422     630
# 48442  5765 heards forest dr  crestview, fl   32539         20452     631
# 48456     107 brown ave  st. petersburg, fl   33704         20458     632
# 48458     107 brown ave  st. petersburg, fl   33704         20458     633
#
# [633 rows x 10 columns]

# %% [markdown]
# ## Save data
#
# For the real Pseudopeople package, the output would presumably be a downloaded file. But here I'm just going to preprocess the noised data in memory, and then save.

# %%
# Don't actually need to save anything

# %% [markdown]
# # Step 1 - Preprocessing (prepare data for linking)
#
# **Note:** Eventually, this step will need to include all the data cleaning, data alignment, and conforming the data to required software specifications.
#
# For the present datasets, the only steps necessary are to conform the columns to Splink's requirements:
#
# - Ensure WIC and Census data have identical column names
#
#   - If a column appeared in one dataset but not the other, I added an empty column with the same name to the other dataset
#
# - Add a `unique_id` column to both datasets

# %% [markdown]
# ## See how many kids show up in WIC but not census and vice versa
#
# Use our labeled data to check how many missing kids I'll actually be looking for.

# %%
wic_not_census = df_wic_raw.index.difference(df_census_raw.index)
census_not_wic = df_census_raw.loc[df_census_raw.age<5].index.difference(df_wic_raw.index)
print(len(wic_not_census))
print(len(census_not_wic))
# Out:
# 64
# 1672

# %% [markdown]
# ## View columns in the two datasets because I need to conform them

# %%
df_census_noisy.dtypes
# Out:
# first_name                     object
# middle_initial                 object
# last_name                      object
# date_of_birth                  object
# age                           float64
# sex                            object
# race_ethnicity                 object
# relation_to_household_head     object
# address                        object
# zipcode                        object
# dtype: object

# %%
df_wic_noisy.dtypes
# Out:
# first_name        object
# middle_name       object
# last_name         object
# date_of_birth     object
# sex               object
# race_ethnicity    object
# address           object
# zipcode           object
# household_id       int64
# wic_id             int64
# dtype: object

# %%
df_census_noisy.relation_to_household_head.unique()
# Out:
# array(['Reference person', 'Biological child', 'Stepchild',
#        'Opp-sex spouse', 'Grandchild', 'Other nonrelative',
#        'Parent-in-law', 'Roommate', 'Child-in-law', 'Opp-sex partner',
#        'Sibling', 'Parent', 'Adopted child', 'Same-sex partner',
#        'Other relative', 'Same-sex spouse', 'Foster child',
#        'Noninstitutionalized GQ pop', 'Institutionalized GQ pop'],
#       dtype=object)

# %% [markdown]
# ## Define functions to process the above "original" datasets for linking via Splink (or whatever other linking software we'll be using)
#
# [Necessary conditions for Splink data](https://moj-analytical-services.github.io/splink/demos/01_Prerequisites.html):
#
# * Dataframes must have the same column names
# * Each data set needs a column with a unique identifier within that dataset (Splink assumes the column name is "unique_id" by default, but this can be changed if desired)
# * Null values should be represented by actual `NaN`s, not, e.g., empty strings or something
# * Data should be "cleaned," whatever that means for this particular data
#
# To avoid losing data in either dataset, I am:
#
# * Adding columns missing from one data set to the the other dataset, just filled with NaNs (unless there is something more intelligent I could do, like filling in age from birthdate). For example, I add an empty `household_id` column to the census data even though this won't be used directly for linking (though I may use it in a post-processing step, e.g. to identify a kid who was missing from census but whose sibling matched).
# * Renaming `middle_name` and `middle_initial` to just `middle`, rather than only keeping the middle initial in WIC, so as to not lose information by dropping the rest of the name in the WIC data.
#
# ### Note:
#
# In practice, if you *know* a column won't be used in linking (e.g. the `household_id` column, it would probably be more efficient to drop it for the linking step, then join the linked data back with the original data for the post-processing steps. (I kind of like the RecordLinkage strategy where you just keep the original datasets, and you can add columns if you want, and then during the blocking/indexing step, it just creates a MultiIndex containing the pairs you want to compare, and you can specify arbitrary comparison functions on whatever columns are available...)
#
# ### Questions:
#
# * What about something like `relation_to_household_head`, which is not present in WIC, but could be useful for blocking/filtering since I'm only looking for kids?

# %%
def prepare_census_data(df_census_orig):
    df_census = (
        df_census_orig
        .assign(
            unique_id=range(1,1+len(df_census_orig)),
            household_id=np.nan # Need to either drop this from WIC or add it to census
        )
        # Rename middle name/initial columns to have the same column name
        .rename(columns={'middle_initial': 'middle'})
    )
    return df_census

def prepare_wic_data(df_wic_orig):
    df_wic = (
        df_wic_raw
        # Need to either drop these from census or add to WIC
        .assign(
            # I could try actually computing the age based on DOB and census date instead...
            age=np.nan,
            relation_to_household_head=np.nan,
        )
        # To avoid losing data, just rename column instead of keeping only middle initial 
        .rename(columns={'middle_name': 'middle', 'wic_id': 'unique_id'})
        # Seems like I should not avoid 
    )
    return df_wic

# %%
df_census = prepare_census_data(df_census_noisy)
df_census
# Out:
#       first_name middle   last_name date_of_birth   age     sex  \
# 0       Margaret      J       Clark    1951-07-27  68.0  Female
# 1        Jeffrey      V  Littlejohn    1967-05-03  52.0    Male
# 2         Briana      A     Jackson    2006-09-07  13.0  Female
# 3       Benjamin      D         Cox    1998-10-21  21.0    Male
# 4         Willie    NaN      Tucker    1947-10-09  72.0    Male
# ...          ...    ...         ...           ...   ...     ...
# 49994     Marcus      S       Roman    1988-07-08  31.0    Male
# 49996  Nathaniel      J    Campbell    1941-01-08  79.0    Male
# 49997  Christian      C     Rosales    1983-12-16  36.0    Male
# 49998    Phillip      J      Morton    1985-06-11  34.0    Male
# 49999  Catherine      H      Talley    1928-08-14  91.0  Female
#
#              race_ethnicity relation_to_household_head  \
# 0                     Black           Reference person
# 1                     Black           Reference person
# 2                     Black           Biological child
# 3                     Black                  Stepchild
# 4                     White           Reference person
# ...                     ...                        ...
# 49994  Multiracial or Other   Institutionalized GQ pop
# 49996                 White   Institutionalized GQ pop
# 49997                Latino   Institutionalized GQ pop
# 49998                 White   Institutionalized GQ pop
# 49999                 Black   Institutionalized GQ pop
#
#                                     address zipcode  unique_id  household_id
# 0           1344 winoka rd  brooksville, fl   34601          1           NaN
# 1               927 23rd st  clearwater, fl   34698          2           NaN
# 2               927 23rd st  clearwater, fl   34698          3           NaN
# 3               927 23rd st  clearwater, fl   34698          4           NaN
# 4      8904 167th place  fleming island, fl   32003          5           NaN
# ...                                     ...     ...        ...           ...
# 49994   2210 henn hyde rd ne  hollywood, fl   33021      47525           NaN
# 49996   2210 henn hyde rd ne  hollywood, fl   33021      47526           NaN
# 49997          701 haber rd  vero beach, fl   32968      47527           NaN
# 49998         114 s frnt st  fort myers, fl   33919      47528           NaN
# 49999         701 haber rd  vero beach, fle   32968      47529           NaN
#
# [47529 rows x 12 columns]

# %%
df_wic = prepare_wic_data(df_wic_noisy)
df_wic
# Out:
#       first_name     middle  last_name date_of_birth     sex race_ethnicity  \
# 82         Sadie      Katia    Tidwell    2017-10-15  Female          Black
# 83       Liliana    Addisyn   Marshall    2019-12-03  Female          Black
# 174        Holly       Emma      Yount    2019-05-17  Female          White
# 306       Emilee  Guadalupe     Haskew    2019-12-30  Female         Latino
# 323       Gunner       Liam  Parkinson    2020-03-03    Male          White
# ...          ...        ...        ...           ...     ...            ...
# 48269     Kaylee    Trinity       Hill    2017-10-20  Female          Black
# 48351        Lev     Thomas       Dove    2018-10-18    Male          Black
# 48442  Frederick    Cameron  Rodriguez    2019-06-04    Male         Latino
# 48456       Liam     Emmett    Sardone    2017-01-08    Male          White
# 48458    Cameron      Nolan    Emerson    2019-02-16    Male          White
#
#                                     address zipcode  household_id  unique_id  \
# 82                 w 4th st  north port, fl   34287            48          1
# 83                 w 4th st  north port, fl   34287            48          2
# 174    7944 se 62nd ave  unincorporated, fl   32824            88          3
# 306           749 mi ridge ests  destin, fl   32541           150          4
# 323        600 n maranantha rd  hialeah, fl   33016           157          5
# ...                                     ...     ...           ...        ...
# 48269     98 melanie dr  pembroke pines, fl   33026         20380        629
# 48351   671 john muir road  spring hill, fl   34610         20422        630
# 48442  5765 heards forest dr  crestview, fl   32539         20452        631
# 48456     107 brown ave  st. petersburg, fl   33704         20458        632
# 48458     107 brown ave  st. petersburg, fl   33704         20458        633
#
#        age  relation_to_household_head
# 82     NaN                         NaN
# 83     NaN                         NaN
# 174    NaN                         NaN
# 306    NaN                         NaN
# 323    NaN                         NaN
# ...    ...                         ...
# 48269  NaN                         NaN
# 48351  NaN                         NaN
# 48442  NaN                         NaN
# 48456  NaN                         NaN
# 48458  NaN                         NaN
#
# [633 rows x 12 columns]

# %% [markdown]
# ## Test whether data is properly formatted for Splink
#
# **Note:** `profile_columns` complains if the sets of column names in the two datasets are different.

# %%
# Minimal settings needed to call .profile_columns()
initial_settings = {'link_type': 'link_only'}
linker = DuckDBLinker([df_census, df_wic], initial_settings)

# %%
linker.profile_columns(['first_name', 'middle', 'last_name'])
# Out:
# <div id="altair-viz-ea19aeeffcfd4610a064865852ace319"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-ea19aeeffcfd4610a064865852ace319") {
#       outputDiv = document.getElementById("altair-viz-ea19aeeffcfd4610a064865852ace319");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"hconcat": [{"data": {"values": [{"percentile_ex_nulls": 0.9854657053947449, "percentile_inc_nulls": 0.9854657053947449, "value_count": 700, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 700.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.9715543389320374, "percentile_inc_nulls": 0.9715543389320374, "value_count": 670, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 670.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.9597815871238708, "percentile_inc_nulls": 0.9597815871238708, "value_count": 567, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 567.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.9481956958770752, "percentile_inc_nulls": 0.9481956958770752, "value_count": 558, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 558.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.9369004368782043, "percentile_inc_nulls": 0.9369004368782043, "value_count": 544, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 544.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.926477313041687, "percentile_inc_nulls": 0.926477313041687, "value_count": 502, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 502.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.9172376394271851, "percentile_inc_nulls": 0.9172376394271851, "value_count": 445, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 445.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.9084755778312683, "percentile_inc_nulls": 0.9084755778312683, "value_count": 422, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 422.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.9000456929206848, "percentile_inc_nulls": 0.9000456929206848, "value_count": 406, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 406.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.8935467600822449, "percentile_inc_nulls": 0.8935467600822449, "value_count": 313, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 313.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.8871932029724121, "percentile_inc_nulls": 0.8871932029724121, "value_count": 306, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 306.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.880860447883606, "percentile_inc_nulls": 0.880860447883606, "value_count": 305, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 305.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.8747144937515259, "percentile_inc_nulls": 0.8747144937515259, "value_count": 296, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 296.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.8695652484893799, "percentile_inc_nulls": 0.8695652484893799, "value_count": 248, "group_name": "first_name", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 248.0, "distinct_value_count": 4542}, {"percentile_ex_nulls": 0.8644574880599976, "percentile_inc_nulls": 0.8644574880599976, "value_count" ...

# %%
linker.profile_columns(['address', 'zipcode'])
# Out:
# <div id="altair-viz-1a2e59c173f44b75abdd5696adf2ae5d"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-1a2e59c173f44b75abdd5696adf2ae5d") {
#       outputDiv = document.getElementById("altair-viz-1a2e59c173f44b75abdd5696adf2ae5d");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"hconcat": [{"data": {"values": [{"percentile_ex_nulls": 0.9941447377204895, "percentile_inc_nulls": 0.9941447377204895, "value_count": 282, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 282.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.9884141087532043, "percentile_inc_nulls": 0.9884141087532043, "value_count": 276, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 276.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.9830779433250427, "percentile_inc_nulls": 0.9830779433250427, "value_count": 257, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 257.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.978530764579773, "percentile_inc_nulls": 0.978530764579773, "value_count": 219, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 219.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.9744819402694702, "percentile_inc_nulls": 0.9744819402694702, "value_count": 195, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 195.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.970557689666748, "percentile_inc_nulls": 0.970557689666748, "value_count": 189, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 189.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.9701424241065979, "percentile_inc_nulls": 0.9701424241065979, "value_count": 20, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 20.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.9693949818611145, "percentile_inc_nulls": 0.9693949818611145, "value_count": 12, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 36.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.9680246114730835, "percentile_inc_nulls": 0.9680246114730835, "value_count": 11, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 66.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.9659482836723328, "percentile_inc_nulls": 0.9659482836723328, "value_count": 10, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 100.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.963705837726593, "percentile_inc_nulls": 0.963705837726593, "value_count": 9, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 108.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.9568954706192017, "percentile_inc_nulls": 0.9568954706192017, "value_count": 8, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 328.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.9377102255821228, "percentile_inc_nulls": 0.9377102255821228, "value_count": 7, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 924.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.8907437324523926, "percentile_inc_nulls": 0.8907437324523926, "value_count": 6, "group_name": "address", "total_non_null_rows": 48162, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 2262.0, "distinct_value_count": 20724}, {"percentile_ex_nulls": 0.7977243661880493, "percentile_inc_nulls": 0.7977243661880493, "value_count": 5, "group_name": "address", "total_non_nul ...

# %%
linker.profile_columns(['relation_to_household_head', 'race_ethnicity', 'age'])
# Out:
# <div id="altair-viz-27223b55489042af8ef999ffef0be300"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-27223b55489042af8ef999ffef0be300") {
#       outputDiv = document.getElementById("altair-viz-27223b55489042af8ef999ffef0be300");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"hconcat": [{"data": {"values": [{"percentile_ex_nulls": 0.5898504257202148, "percentile_inc_nulls": 0.5952410697937012, "value_count": 19494, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 19494.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.3624313473701477, "percentile_inc_nulls": 0.37081098556518555, "value_count": 10809, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 10809.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.17261040210723877, "percentile_inc_nulls": 0.18348491191864014, "value_count": 9022, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 9022.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.14658421277999878, "percentile_inc_nulls": 0.15780073404312134, "value_count": 1237, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 1237.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.12674367427825928, "percentile_inc_nulls": 0.13822102546691895, "value_count": 943, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 943.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.10947000980377197, "percentile_inc_nulls": 0.1211743950843811, "value_count": 821, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 821.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.09411096572875977, "percentile_inc_nulls": 0.10601717233657837, "value_count": 730, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 730.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.07908856868743896, "percentile_inc_nulls": 0.09119224548339844, "value_count": 714, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 714.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.06442379951477051, "percentile_inc_nulls": 0.0767202377319336, "value_count": 697, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 697.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.05072695016860962, "percentile_inc_nulls": 0.06320333480834961, "value_count": 651, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 651.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.037934720516204834, "percentile_inc_nulls": 0.05057930946350098, "value_count": 608, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 608.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.02646803855895996, "percentile_inc_nulls": 0.03926330804824829, "value_count": 545, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 545.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.01636892557144165, "percentile_inc_nulls": 0.029296934604644775, "value_count": 480, "group_name": "relation_to_household_head", "total_non_null_rows": 47529, "total_rows_inc_nulls": 48162, "sum_tokens_in_value_count_group": 480.0, "distinct_value_count": 19}, {"percentile_ex_nulls": 0.011066913604736328, "percentile_inc_nulls": 0.024064600467681885, "value_count": 252, "group_name": "relation_to_household_h ...

# %% [markdown]
# ## Save prepared data

# %%
data_dir = 'data'
df_census.to_csv(f'{data_dir}/prepared_2020_census_20221014.csv')
df_wic.to_csv(f'{data_dir}/prepared_wic_20221014.csv')

# %%
# !ls -l $data_dir
# Out:
# total 5496
# -rw-rw-r-- 1 ndbs IHME-users 5535621 Jan 27 10:34 prepared_2020_census_20221014.csv
# -rw-rw-r-- 1 ndbs IHME-users   66364 Jan 27 10:34 prepared_wic_20221014.csv
# -rw-rw-r-- 1 ndbs IHME-users    7613 Jan 20 16:21 saved_model_from_wic_census_20221014.json

# %% [raw]
# -rw-rw-r-- 1 ndbs IHME-users 5488326 Jan  5 16:01 prepared_2020_census_20221014.csv
# -rw-rw-r-- 1 ndbs IHME-users   65069 Jan  5 16:01 prepared_wic_20221014.csv

# %% [markdown]
# ### Simulated Data – Disclosure NOT Prohibited: NOT Title 13

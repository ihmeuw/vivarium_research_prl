# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
logging.basicConfig(level=logging.DEBUG, format='{asctime} - {name} - {levelname} - {message}', style='{')
import numpy as np, matplotlib.pyplot as plt, pandas as pd
# For finding and loading multiple files
import os
# Use this to see how much memory the dataframes use
from sys import getsizeof
from pathlib import Path
from linetimer import CodeTimer, linetimer

import pseudopeople as psp

from vivarium_research_prl.utils import sizemb, MappingViaAttributes
from vivarium_research_prl import alpha

# !date
# !whoami
# !uname -a
# !pwd
# !python --version
# !conda info --envs | grep '\*'
# !conda list | grep -e pandas -e numpy -e vivarium -e pseudopeople
# Out:
# 2024-02-06 19:14:48,763 - matplotlib - DEBUG - matplotlib data path: /ihme/homes/ndbs/miniconda3/envs/ppplv1.0-311/lib/python3.11/site-packages/matplotlib/mpl-data
# 2024-02-06 19:14:48,778 - matplotlib - DEBUG - CONFIGDIR=/ihme/homes/ndbs/.config/matplotlib
# 2024-02-06 19:14:48,782 - matplotlib - DEBUG - interactive is False
# 2024-02-06 19:14:48,782 - matplotlib - DEBUG - platform is linux
# 2024-02-06 19:14:48,897 - matplotlib - DEBUG - CACHEDIR=/ihme/homes/ndbs/.cache/matplotlib
# 2024-02-06 19:14:48,902 - matplotlib.font_manager - DEBUG - Using fontManager instance from /ihme/homes/ndbs/.cache/matplotlib/fontlist-v330.json
# 2024-02-06 19:14:49,962 - numexpr.utils - INFO - Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# Tue 06 Feb 2024 07:14:56 PM PST
# ndbs
# Linux long-slurm-sarchive-p0050 5.4.0-167-generic #184-Ubuntu SMP Tue Oct 31 09:21:49 UTC 2023 x86_64 x86_64 x86_64 GNU/Linux
# /mnt/share/code/ndbs/vivarium_research_prl/pseudopeople_testing
# Python 3.11.7
# ppplv1.0-311          *  /ihme/homes/ndbs/miniconda3/envs/ppplv1.0-311
# numpy                     1.26.3                   pypi_0    pypi
# pandas                    2.1.4                    pypi_0    pypi
# pseudopeople              0.8.4.dev34+gc5d0c15          pypi_0    pypi
# vivarium                  2.3.1                    pypi_0    pypi
# vivarium-research-prl     0.0.1                     dev_0    <develop>

# %%
# !pip freeze | grep pseudopeople
# Out:
# pseudopeople @ git+https://github.com/ihmeuw/pseudopeople.git@c5d0c15dc889b0ef51f56fa9757c2949b8531f3b

# %%
# A clickable link to the GitHub UI to see what version I'm using
! pip freeze | grep pseudopeople | sed -e 's|pseudopeople @ ||' | sed -e 's|git+||' | sed -e 's|\.git@|/tree/|'
# Out:
# https://github.com/ihmeuw/pseudopeople/tree/c5d0c15dc889b0ef51f56fa9757c2949b8531f3b

# %% [markdown]
# # Generate all sample datasets

# %%
# %%time
data = alpha.generate_datasets()
# Out:
# 2024-02-06 19:15:05,344 - vivarium_research_prl.alpha - INFO - Function 'generate_datasets' called with args=(), kwargs={}
# 2024-02-06 19:15:05,345 - vivarium_research_prl.alpha - DEBUG - skip_pattern=re.compile('(?!)')
# 2024-02-06 19:15:05,346 - vivarium_research_prl.alpha - INFO - Calling function generate_american_community_survey
# 2024-02-06 19:15:05,912 - vivarium_research_prl.alpha - INFO - Code block 'generate_american_community_survey' took: 0.00941 m
# 2024-02-06 19:15:05,915 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> american_community_survey occupies 0.067614 MB in memory
# 2024-02-06 19:15:05,916 - vivarium_research_prl.alpha - INFO - Calling function generate_current_population_survey
# 2024-02-06 19:15:06,151 - vivarium_research_prl.alpha - INFO - Code block 'generate_current_population_survey' took: 0.00390 m
# 2024-02-06 19:15:06,155 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> current_population_survey occupies 0.035549 MB in memory
# 2024-02-06 19:15:06,155 - vivarium_research_prl.alpha - INFO - Calling function generate_decennial_census
# 2024-02-06 19:15:06,960 - vivarium_research_prl.alpha - INFO - Code block 'generate_decennial_census' took: 0.01339 m
# 2024-02-06 19:15:06,986 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> decennial_census occupies 8.478217 MB in memory
# 2024-02-06 19:15:06,987 - vivarium_research_prl.alpha - INFO - Calling function generate_social_security
# 2024-02-06 19:15:07,573 - vivarium_research_prl.alpha - INFO - Code block 'generate_social_security' took: 0.00973 m
# 2024-02-06 19:15:07,595 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> social_security occupies 7.44879 MB in memory
# 2024-02-06 19:15:07,597 - vivarium_research_prl.alpha - INFO - Calling function generate_taxes_1040
# 2024-02-06 19:15:08,872 - vivarium_research_prl.alpha - INFO - Code block 'generate_taxes_1040' took: 0.02123 m
# 2024-02-06 19:15:08,908 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> taxes_1040 occupies 8.384543 MB in memory
# 2024-02-06 19:15:08,909 - vivarium_research_prl.alpha - INFO - Calling function generate_taxes_w2_and_1099
# 2024-02-06 19:15:09,944 - vivarium_research_prl.alpha - INFO - Code block 'generate_taxes_w2_and_1099' took: 0.01722 m
# 2024-02-06 19:15:09,984 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> taxes_w2_and_1099 occupies 11.864725 MB in memory
# 2024-02-06 19:15:09,985 - vivarium_research_prl.alpha - INFO - Calling function generate_women_infants_and_children
# 2024-02-06 19:15:10,269 - vivarium_research_prl.alpha - INFO - Code block 'generate_women_infants_and_children' took: 0.00471 m
# 2024-02-06 19:15:10,273 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> women_infants_and_children occupies 0.104727 MB in memory
# 2024-02-06 19:15:10,274 - vivarium_research_prl.alpha - INFO - Calculating total memory usage...
# 2024-02-06 19:15:10,403 - vivarium_research_prl.alpha - INFO - All generated datasets occupy 36.384164999999996 MB in memory
# CPU times: user 4.74 s, sys: 181 ms, total: 4.93 s
# Wall time: 5.06 s

# %% [markdown]
# # Generate unnoised sample datasets

# %%
data0 = alpha.generate_datasets(config=psp.NO_NOISE)
# Out:
# 2024-02-06 19:15:10,757 - vivarium_research_prl.alpha - INFO - Function 'generate_datasets' called with args=(), kwargs={'config': 'no_noise'}
# 2024-02-06 19:15:10,760 - vivarium_research_prl.alpha - DEBUG - skip_pattern=re.compile('(?!)')
# 2024-02-06 19:15:10,764 - vivarium_research_prl.alpha - INFO - Calling function generate_american_community_survey
# 2024-02-06 19:15:10,935 - vivarium_research_prl.alpha - INFO - Code block 'generate_american_community_survey' took: 0.00283 m
# 2024-02-06 19:15:10,937 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> american_community_survey occupies 0.06943 MB in memory
# 2024-02-06 19:15:10,938 - vivarium_research_prl.alpha - INFO - Calling function generate_current_population_survey
# 2024-02-06 19:15:11,107 - vivarium_research_prl.alpha - INFO - Code block 'generate_current_population_survey' took: 0.00281 m
# 2024-02-06 19:15:11,110 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> current_population_survey occupies 0.043807 MB in memory
# 2024-02-06 19:15:11,110 - vivarium_research_prl.alpha - INFO - Calling function generate_decennial_census
# 2024-02-06 19:15:11,561 - vivarium_research_prl.alpha - INFO - Code block 'generate_decennial_census' took: 0.00749 m
# 2024-02-06 19:15:11,592 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> decennial_census occupies 8.645626 MB in memory
# 2024-02-06 19:15:11,593 - vivarium_research_prl.alpha - INFO - Calling function generate_social_security
# 2024-02-06 19:15:12,035 - vivarium_research_prl.alpha - INFO - Code block 'generate_social_security' took: 0.00736 m
# 2024-02-06 19:15:12,060 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> social_security occupies 7.474482 MB in memory
# 2024-02-06 19:15:12,061 - vivarium_research_prl.alpha - INFO - Calling function generate_taxes_1040
# 2024-02-06 19:15:12,665 - vivarium_research_prl.alpha - INFO - Code block 'generate_taxes_1040' took: 0.01003 m
# 2024-02-06 19:15:12,704 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> taxes_1040 occupies 8.405058 MB in memory
# 2024-02-06 19:15:12,705 - vivarium_research_prl.alpha - INFO - Calling function generate_taxes_w2_and_1099
# 2024-02-06 19:15:13,162 - vivarium_research_prl.alpha - INFO - Code block 'generate_taxes_w2_and_1099' took: 0.00758 m
# 2024-02-06 19:15:13,204 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> taxes_w2_and_1099 occupies 11.993957 MB in memory
# 2024-02-06 19:15:13,206 - vivarium_research_prl.alpha - INFO - Calling function generate_women_infants_and_children
# 2024-02-06 19:15:13,326 - vivarium_research_prl.alpha - INFO - Code block 'generate_women_infants_and_children' took: 0.00198 m
# 2024-02-06 19:15:13,329 - vivarium_research_prl.alpha - INFO - <class 'pandas.core.frame.DataFrame'> women_infants_and_children occupies 0.105794 MB in memory
# 2024-02-06 19:15:13,330 - vivarium_research_prl.alpha - INFO - Calculating total memory usage...
# 2024-02-06 19:15:13,458 - vivarium_research_prl.alpha - INFO - All generated datasets occupy 36.738154 MB in memory

# %% [markdown]
# # Make sure indices in the noised data are consecutive

# %%
{k: alpha.index_is_consecutive(df) for k, df in data.items()}
# Out:
# {'american_community_survey': True,
#  'current_population_survey': True,
#  'decennial_census': True,
#  'social_security': True,
#  'taxes_1040': True,
#  'taxes_w2_and_1099': True,
#  'women_infants_and_children': True}

# %%
{k: alpha.index_is_consecutive(df) for k, df in data0.items()}
# Out:
# {'american_community_survey': True,
#  'current_population_survey': True,
#  'decennial_census': True,
#  'social_security': True,
#  'taxes_1040': True,
#  'taxes_w2_and_1099': True,
#  'women_infants_and_children': True}

# %% [markdown]
# # Check lengths of each dataset vs. unnoised version

# %%
{k: len(df) for k, df in data.items()}
# Out:
# {'american_community_survey': 74,
#  'current_population_survey': 40,
#  'decennial_census': 10225,
#  'social_security': 16497,
#  'taxes_1040': 6518,
#  'taxes_w2_and_1099': 9903,
#  'women_infants_and_children': 140}

# %%
{k: len(df) for k, df in data0.items()}
# Out:
# {'american_community_survey': 76,
#  'current_population_survey': 51,
#  'decennial_census': 10387,
#  'social_security': 16497,
#  'taxes_1040': 6518,
#  'taxes_w2_and_1099': 9972,
#  'women_infants_and_children': 141}

# %% [markdown]
# # Find duplicated simulant IDs
#
# Hmm, looks like the duplicated rows all appear at the end of the dataframe...

# %%
duplicated_ids = data.decennial_census.simulant_id.duplicated(keep=False)
duplicates = data.decennial_census.loc[duplicated_ids]
duplicates
# Out:
#       simulant_id household_id first_name middle_initial last_name age  \
# 1960      0_19556          0_3   Benjamin              C     Allen  19
# 1964      0_19579          0_3    Brielle              L  Gonzalez  19
# 1983      0_19666          0_3       Kyle              L      Nims  19
# 1992      0_19693          0_3     Johana              M     Huang  20
# 6655      0_11994       0_4843     Lauren              H    Consul  17
# 10220     0_11994       0_8051     Lauren              H    Consul  17
# 10221     0_19693       0_6152     Johana              M     Huang  20
# 10222     0_19556       0_2064   8eniamin              F     Allen  19
# 10223     0_19579       0_1802    Brielle              L  Gonzalez  19
# 10224     0_19666        0_881       Kyle              L      Nims  19
#
#       date_of_birth street_number          street_name unit_number     city  \
# 1960     02/26/2001          8203  west farwell avenue         NaN  Anytown
# 1964     11/27/2000          8203  west farwell avenue         NaN  Anytown
# 1983     03/31/2000          8203  west farwell avenue         NaN  Anytown
# 1992     08/04/1999          8203  west farwell avenue         NaN  Anytown
# 6655     10/25/2002         10949         delaware ave         NaN  Anytown
# 10220    10/25/2002          3304      ethan allen way    unit 200  Anytown
# 10221    08/04/1999          1095             ernst st         NaN  Anytown
# 10222    Oz/26/z0o1          2002          203rd pl se         NaN  Anytown
# 10223    11/27/2000           233    saint peters road         NaN  Anytown
# 10224    03/31/2000           224         s moraine st         NaN  Anytown
#
#       state zipcode housing_type  \
# 1960     WA   00000      College
# 1964     WA   00000      College
# 1983     MS   00000      College
# 1992     WA   00000      College
# 6655     WA   00000    Household
# 10220    WA   00000    Household
# 10221    WA   00000    Household
# 10222    WA   00000    Household
# 10223    WA   00000    Household
# 10224    WA   00000    Household
#
#                      relationship_to_reference_person     sex race_ethnicity  \
# 1960   Noninstitutionalized group quarters population    Male          Black
# 1964   Noninstitutionalized group quarters population  Female         Latino
# 1983   Noninstitutionalized group quarters population    Male          White
# 1992   Noninstitutionalized group quarters population  Female          Asian
# 6655                                 Reference person  Female          White
# 10220                                  Other relative  Female          White
# 10221                                  Other relative  Female          Asian
# 10222                                  Other relative    Male          Black
# 10223                                  Other relative  Female         Latino
# 10224                                  Other relative    Male          White
#
#        year
# 1960   2020
# 1964   2020
# 1983   2020
# 1992   2020
# 6655   2020
# 10220  2020
# 10221  2020
# 10222  2020
# 10223  2020
# 10224  2020

# %%
duplicates.simulant_id.value_counts()
# Out:
# simulant_id
# 0_19556    2
# 0_19579    2
# 0_19666    2
# 0_19693    2
# 0_11994    2
# Name: count, dtype: int64

# %% [markdown]
# # Looks like duplicated simulants are still at the end of the dataframe...

# %%
data.decennial_census
# Out:
#       simulant_id household_id first_name middle_initial last_name age  \
# 0             0_2          0_7      Diana              P    Kofron  25
# 1             0_3          0_7       Anna              A    Kofron  25
# 2           0_923       0_8033     Gerald              R    Butler  76
# 3          0_2641       0_1066    Loretta              T    Carley  61
# 4          0_2801       0_1138    Richard              R     Jones  63
# ...           ...          ...        ...            ...       ...  ..
# 10220     0_11994       0_8051     Lauren              H    Consul  17
# 10221     0_19693       0_6152     Johana              M     Huang  20
# 10222     0_19556       0_2064   8eniamin              F     Allen  19
# 10223     0_19579       0_1802    Brielle              L  Gonzalez  19
# 10224     0_19666        0_881       Kyle              L      Nims  19
#
#       date_of_birth street_number        street_name unit_number     city  \
# 0        05/06/1994          5112           145th st         NaN  Anytown
# 1        09/29/1994          5112           145th st         NaN  Anytown
# 2        11/03/1943          1130         mallory ln         NaN  Anytown
# 3        07/71/1958           NaN       delacorte dr         NaN  Anytown
# 4        03/03/1947           950       caribou lane         NaN  Anytown
# ...             ...           ...                ...         ...      ...
# 10220    10/25/2002          3304    ethan allen way    unit 200  Anytown
# 10221    08/04/1999          1095           ernst st         NaN  Anytown
# 10222    Oz/26/z0o1          2002        203rd pl se         NaN  Anytown
# 10223    11/27/2000           233  saint peters road         NaN  Anytown
# 10224    03/31/2000           224       s moraine st         NaN  Anytown
#
#       state zipcode housing_type relationship_to_reference_person     sex  \
# 0        WA   00000    Household                 Reference person  Female
# 1        WA   00000    Household                   Other relative  Female
# 2        WA   00000    Household                 Reference person    Male
# 3        WA   00000    Household                 Reference person  Female
# 4        WA   00000    Household                 Reference person    Male
# ...     ...     ...          ...                              ...     ...
# 10220    WA   00000    Household                   Other relative  Female
# 10221    WA   00000    Household                   Other relative  Female
# 10222    WA   00000    Household                   Other relative    Male
# 10223    WA   00000    Household                   Other relative  Female
# 10224    WA   00000    Household                   Other relative    Male
#
#       race_ethnicity  year
# 0              White  2020
# 1              White  2020
# 2              Black  2020
# 3              White  2020
# 4              White  2020
# ...              ...   ...
# 10220          White  2020
# 10221          Asian  2020
# 10222          Black  2020
# 10223         Latino  2020
# 10224          White  2020
#
# [10225 rows x 18 columns]

# %%
data.decennial_census.index
# Out:
# RangeIndex(start=0, stop=10225, step=1)

# %% [markdown]
# # Calculate the "non-consecutiveness" of each household

# %%
data.decennial_census.household_id.nunique()
# Out:
# 4061

# %%
# People in household 0_3
in_03 = data.decennial_census.query("household_id == '0_3'")
alpha.index_is_consecutive(in_03)
# Out:
# False

# %%
len(in_03)
# Out:
# 128

# %%
def index_span_minus_size(df):
    """Calculates how far a dataframe index is
    from being consecutive.
    """
    return (df.index[-1] - df.index[0] + 1) - len(df)

index_span_minus_size(in_03)
# Out:
# 4

# %%
hh_grouping_discrepancies = data.decennial_census.groupby('household_id').apply(index_span_minus_size)
# index is household_id, values are the discrepancy for that household
hh_grouping_discrepancies
# Out:
# household_id
# 0_0       7
# 0_1       6
# 0_100     0
# 0_1000    0
# 0_1002    0
#          ..
# 0_993     0
# 0_994     0
# 0_995     0
# 0_996     0
# 0_998     0
# Length: 4061, dtype: int64

# %%
# index is the discrepancy, values are the number of households with that discrepancy
hh_grouping_discrepancies.value_counts()
# Out:
# 0       3787
# 3         45
# 2         40
# 5         33
# 1         33
# 4         32
# 6         24
# 7         17
# 8          9
# 11         9
# 10         8
# 12         5
# 14         4
# 9          4
# 13         3
# 19         1
# 6252       1
# 17         1
# 2828       1
# 18         1
# 122        1
# 7725       1
# 8857       1
# Name: count, dtype: int64

# %%
hh_grouping_discrepancies.loc[hh_grouping_discrepancies > 100]
# Out:
# household_id
# 0_1802    6252
# 0_2064    2828
# 0_6152     122
# 0_8051    7725
# 0_881     8857
# dtype: int64

# %% [markdown]
# # Sort the census and compare with the version generated above

# %%
data.decennial_census.year.unique()
# Out:
# array([2020], dtype=object)

# %%
sorted_census = data.decennial_census.sort_values(['year', 'household_id']).reset_index(drop=True)
sorted_census
# Out:
#       simulant_id household_id first_name middle_initial    last_name age  \
# 0           0_123          0_0     Angela              A     Mckinney  19
# 1           0_244          0_0     Marcus              S  Chamberlain  20
# 2           0_691          0_0     Kelvin              M      Higgins  59
# 3          0_2606          0_0    Michael              M    Scorzelli  14
# 4          0_3692          0_0     Dustin              M     Ormiston  30
# ...           ...          ...        ...            ...          ...  ..
# 10220      0_2482        0_996      Craig              S         Levi  69
# 10221      0_2483        0_996      Donna              R    Dont Know  69
# 10222      0_2487        0_998    Charles              J       Taylor  70
# 10223      0_2488        0_998    Rebecca              R       Taylor  52
# 10224      0_2489        0_998   Kimberly              S        Denny  25
#
#       date_of_birth street_number   street_name unit_number     city state  \
# 0        01/14/2001          1231  riverside dr         NaN  Anytown    WA
# 1        01/30/2000          1231  riverside dr         NaN  Anytown    WA
# 2        06/04/1960          1231  riverside dr         NaN  Anytown    WA
# 3        12/05/2005          1231  riverside dr         NaN  Anytown    WA
# 4        08/05/1989           NaN  riverside dr         NaN  Anytown    WA
# ...             ...           ...           ...         ...      ...   ...
# 10220    04/24/1950         15200   a forest st         NaN  Anytown    WA
# 10221    11/30/1950         10200   a forest st         NaN  Anytown    WA
# 10222    05/13/1949          1121       lida ct         NaN  Anytown    WA
# 10223    04/13/1967          1121       lida ct         NaN  Anytown    WA
# 10224    12/23/1994          1121       lida ct         NaN  Anytown    WA
#
#       zipcode housing_type             relationship_to_reference_person  \
# 0       00000     Carceral  Institutionalized group quarters population
# 1       00000     Carceral  Institutionalized group quarters population
# 2       00000     Carceral  Institutionalized group quarters population
# 3         NaN     Carceral  Institutionalized group quarters population
# 4       00000     Carceral  Institutionalized group quarters population
# ...       ...          ...                                          ...
# 10220   00000    Household                                       Parent
# 10221   00000    Household                                       Parent
# 10222   00000    Household                             Reference person
# 10223   00000    Household                          Opposite-sex spouse
# 10224   00000    Household                            Other nonrelative
#
#           sex        race_ethnicity  year
# 0      Female                 White  2020
# 1        Male                 White  2020
# 2        Male  Multiracial or Other  2020
# 3        Male  Multiracial or Other  2020
# 4        Male  Multiracial or Other  2020
# ...       ...                   ...   ...
# 10220    Male                 White  2020
# 10221  Female                 White  2020
# 10222    Male                 White  2020
# 10223     NaN                 White  2020
# 10224  Female                 White  2020
#
# [10225 rows x 18 columns]

# %%
sorted_census.index
# Out:
# RangeIndex(start=0, stop=10225, step=1)

# %%
dup_household_ids = sorted_census.query(f"household_id in {duplicates.household_id.to_list()}")
dup_household_ids
# Out:
#       simulant_id household_id first_name middle_initial last_name age  \
# 1263       0_4413       0_1802       John              M   Ventura  51
# 1264       0_4414       0_1802    Zachary              C   Ventura  31
# 1265       0_4415       0_1802   Sullivan              M   Ventura   6
# 1266      0_19579       0_1802    Brielle              L  Gonzalez  19
# 1746       0_5040       0_2064      Scott              T   Sanders  57
# ...           ...          ...        ...            ...       ...  ..
# 10050      0_2188        0_881   Michelle              B     Smith  45
# 10051      0_2189        0_881      David              J     Smith  45
# 10052      0_2190        0_881      Jimmy              A     Smith  14
# 10053      0_2191        0_881   Benjamin              R     Smith  10
# 10054     0_19666        0_881       Kyle              L      Nims  19
#
#       date_of_birth street_number        street_name unit_number     city  \
# 1263     04/11/1968           233  saint peters road         NaN  Anytown
# 1264     04/11/1968           233  saint peters road         NaN  Anytown
# 1265     12/06/2013           233  saint peters road         NaN  Anytown
# 1266     11/27/2000           233  saint peters road         NaN  Anytown
# 1746     05/08/1962          2002        203rd pl se         NaN  Anytown
# ...             ...           ...                ...         ...      ...
# 10050    06/13/1974           224       s moraine st         NaN  Anytown
# 10051    08/26/1974           224       s moraine st         NaN  Anytown
# 10052    01/21/2006           224       s moraine st         NaN  Anytown
# 10053    02/13/2010           224       s moraine st         NaN  Anytown
# 10054    03/31/2000           224       s moraine st         NaN  Anytown
#
#       state zipcode housing_type relationship_to_reference_person     sex  \
# 1263     WA   00000    Household                 Reference person    Male
# 1264     WA   00000    Household                 Biological child    Male
# 1265     WA   00000    Household                 Biological child    Male
# 1266     WA   00000    Household                   Other relative  Female
# 1746     WA   00000    Household                 Reference person    Male
# ...     ...     ...          ...                              ...     ...
# 10050    WA   00000    Household                 Reference person  Female
# 10051    WA   00000    Household              Opposite-sex spouse    Male
# 10052    WA     NaN    Household                 Biological child    Male
# 10053    WA   00000    Household                 Biological child    Male
# 10054    WA   00000    Household                   Other relative    Male
#
#       race_ethnicity  year
# 1263          Latino  2020
# 1264          Latino  2020
# 1265           White  2020
# 1266          Latino  2020
# 1746             NaN  2020
# ...              ...   ...
# 10050          White  2020
# 10051          White  2020
# 10052          White  2020
# 10053          White  2020
# 10054          White  2020
#
# [151 rows x 18 columns]

# %%
dup_household_ids.housing_type.value_counts()
# Out:
# housing_type
# College      127
# Household     22
# Name: count, dtype: int64

# %%
dup_household_ids.query("housing_type == 'Household'")
# Out:
#       simulant_id household_id   first_name middle_initial last_name age  \
# 1263       0_4413       0_1802         John              M   Ventura  51
# 1264       0_4414       0_1802      Zachary              C   Ventura  31
# 1265       0_4415       0_1802     Sullivan              M   Ventura   6
# 1266      0_19579       0_1802      Brielle              L  Gonzalez  19
# 1746       0_5040       0_2064        Scott              T   Sanders  57
# 1747       0_5041       0_2064       Sandra              H   Sanders  38
# 1748       0_5042       0_2064     Samantha              M   Sanders  16
# 1749       0_5043       0_2064     Kimberly              Z   Sanders  14
# 1750       0_5044       0_2064  Christopher              L   Sanders  10
# 1751      0_20285       0_2064         Evan              J   Sanders   0
# 1752      0_19556       0_2064     8eniamin              F     Allen  19
# 5608      0_11994       0_4843       Lauren              H    Consul  17
# 7398      0_15267       0_6152         Erin              J     Cheng  37
# 7400      0_15269       0_6152      Dorothy              A     Cheng  68
# 7401      0_19693       0_6152       Johana              M     Huang  20
# 9766      0_11993       0_8051       Vickie              P    Consul  65
# 9767      0_11994       0_8051       Lauren              H    Consul  17
# 10050      0_2188        0_881     Michelle              B     Smith  45
# 10051      0_2189        0_881        David              J     Smith  45
# 10052      0_2190        0_881        Jimmy              A     Smith  14
# 10053      0_2191        0_881     Benjamin              R     Smith  10
# 10054     0_19666        0_881         Kyle              L      Nims  19
#
#       date_of_birth street_number        street_name unit_number     city  \
# 1263     04/11/1968           233  saint peters road         NaN  Anytown
# 1264     04/11/1968           233  saint peters road         NaN  Anytown
# 1265     12/06/2013           233  saint peters road         NaN  Anytown
# 1266     11/27/2000           233  saint peters road         NaN  Anytown
# 1746     05/08/1962          2002        203rd pl se         NaN  Anytown
# 1747     10/29/1981          2002        203rd pl se         NaN  Anytown
# 1748     04/25/2003          2002        203rd pl se         NaN  Anytown
# 1749     02/23/2006          2002        203rd pl se         NaN  Anytown
# 1750     04/15/2009          2002        203rd pl se         NaN  Anytown
# 1751     11/15/2019          2002        203rd pl se         NaN  Anytown
# 1752     Oz/26/z0o1          2002        203rd pl se         NaN  Anytown
# 5608     10/25/2002         10949       delaware ave         NaN  Anytown
# 7398     04/25/1982          1095           ernst st         NaN  Anytown
# 7400     09/21/1951          1095           ernst st         NaN  Anytown
# 7401     08/04/1999          1095           ernst st         NaN  Anytown
# 9766     08/01/1954          3304    ethan allen way    unit 200  Anytown
# 9767     10/25/2002          3304    ethan allen way    unit 200  Anytown
# 10050    06/13/1974           224       s moraine st         NaN  Anytown
# 10051    08/26/1974           224       s moraine st         NaN  Anytown
# 10052    01/21/2006           224       s moraine st         NaN  Anytown
# 10053    02/13/2010           224       s moraine st         NaN  Anytown
# 10054    03/31/2000           224       s moraine st         NaN  Anytown
#
#       state zipcode housing_type relationship_to_reference_person     sex  \
# 1263     WA   00000    Household                 Reference person    Male
# 1264     WA   00000    Household                 Biological child    Male
# 1265     WA   00000    Household                 Biological child    Male
# 1266     WA   00000    Household                   Other relative  Female
# 1746     WA   00000    Household                 Reference person    Male
# 1747     WA   00000    Household              Opposite-sex spouse  Female
# 1748     WA   00000    Household                 Biological child  Female
# 1749     WA   00000    Household                 Biological child  Female
# 1750     WA   00000    Household                 Biological child    Male
# 1751     WA   00000    Household                       Grandchild    Male
# 1752     WA   00000    Household                   Other relative    Male
# 5608     WA   00000    Household                 Reference person  Female
# 7398     WA   00000    Household                 Reference person  Female
# 7400     WA   00000    Household                           Parent  Female
# 7401     WA   00000    Household                   Other relative  Female
# 9766     WA   00000    Household                 Reference person  Female
# 9767     WA   00000    Household                   Other relative  Female
# 10050    WA   00000    Household                 Reference person  Female
# 10051    WA   00000    Household              Opposite-sex spouse    Male
# 10052    WA     NaN    Household                 Biological child    Male
# 10053    WA   00000    Household                 Biological child    Male
# 10054    WA   00000    Household                   Other relative    Male
#
#       race_ethnicity  year
# 1263          Latino  2020
# 1264          Latino  2020
# 1265           White  2020
# 1266          Latino  2020
# 1746             NaN  2020
# 1747           Black  2020
# 1748           Black  2020
# 1749           Black  2020
# 1750           Black  2020
# 1751           Black  2020
# 1752           Black  2020
# 5608           White  2020
# 7398           Asian  2020
# 7400           Asian  2020
# 7401           Asian  2020
# 9766           White  2020
# 9767           White  2020
# 10050          White  2020
# 10051          White  2020
# 10052          White  2020
# 10053          White  2020
# 10054          White  2020

# %% [markdown]
# # Generate a census with more duplication and check household types
#
# Looks like duplicated simulants are having their relationship to reference person correctly assigned.

# %%
config = {
    'decennial_census': {
        'row_noise': {
            'duplicate_with_guardian': {
                'row_probability_in_households_under_18': 0.70,
                'row_probability_in_college_group_quarters_under_24': 0.90
            }
        },
        'column_noise': {
            'housing_type': {
                'choose_wrong_option': {'cell_probability': 0.00}
            },
            'relationship_to_reference_person': {
                'choose_wrong_option': {'cell_probability': 0.00}
            }
        }
    }
}

# %%
bad_census = psp.generate_decennial_census(config=config)
bad_census
# Out:
# 2024-02-06 19:15:14.638 | pseudopeople.configuration.validator:validate_noise_level_proportions:335 - The configured 'row_probability_in_households_under_18' noise level for row_noise 'nan' is 0.7, which is higher than the maximum possible value based on the provided data for 'decennial_census'. Noising as many rows as possible.
# 2024-02-06 19:15:14.639 | pseudopeople.configuration.validator:validate_noise_level_proportions:335 - The configured 'row_probability_in_college_group_quarters_under_24' noise level for row_noise 'nan' is 0.9, which is higher than the maximum possible value based on the provided data for 'decennial_census'. Noising as many rows as possible.
#       simulant_id household_id first_name middle_initial last_name age  \
# 0             0_2          0_7      Diana              P    Kofron  25
# 1             0_3          0_7       Anna              A    Kofron  25
# 2           0_923       0_8033     Gerald              R    Butler  76
# 3          0_2641       0_1066    Loretta              T    Carley  61
# 4          0_2801       0_1138    Richard              R     Jones  73
# ...           ...          ...        ...            ...       ...  ..
# 10350     0_19580       0_2254     Brooke              E   Morales  23
# 10351     0_19683       0_3633      James              V  Saracino  23
# 10352     0_19688       0_5554     Landon              L    Foster  22
# 10353     0_19697       0_5337    Lindsey              L     Milam  23
# 10354     0_19699       0_6277      Eryka              G   Roberts  22
#
#       date_of_birth street_number      street_name unit_number     city state  \
# 0        05/06/1994          5112         145th st         NaN  Anytown    WA
# 1        09/29/1994          5112         145th st         NaN  Anytown    WA
# 2        11/03/1943          1130       mallory ln         NaN  Anytown    WA
# 3        06/01/1958           NaN     delacorte dr         NaN  Anytown    WA
# 4        03/03/1947           950     caribou lane         NaN  Anytown    WA
# ...             ...           ...              ...         ...      ...   ...
# 10350    03/27/1996          5451  northwestrn pwy         NaN  Anytown    WA
# 10351    08/13/1996           580   breeze hill rd         NaN  Anytown    WA
# 10352    10/13/1997          3913        e long st         NaN  Anytown    WA
# 10353    12/02/1996           925       sawmill rd         NaN  Anytown    WA
# 10354    01/15/1998          2849    hackberry ave         NaN  Anytown    WA
#
#       zipcode housing_type relationship_to_reference_person     sex  \
# 0       00000    Household                 Reference person  Female
# 1       00000    Household                   Other relative  Female
# 2       00000    Household                 Reference person    Male
# 3       00000    Household                 Reference person  Female
# 4       00000    Household                 Reference person    Male
# ...       ...          ...                              ...     ...
# 10350   00000    Household                   Other relative  Female
# 10351   00000    Household                   Other relative    Male
# 10352   00000    Household                   Other relative    Male
# 10353   00000    Household                   Other relative  Female
# 10354   00000    Household                   Other relative  Female
#
#       race_ethnicity  year
# 0              White  2020
# 1              White  2020
# 2              Black  2020
# 3              White  2020
# 4              White  2020
# ...              ...   ...
# 10350         Latino  2020
# 10351          White  2020
# 10352          White  2020
# 10353          White  2020
# 10354          White  2020
#
# [10355 rows x 18 columns]

# %%
bad_dup_ids = bad_census.simulant_id.duplicated(keep=False)
bad_duplicates = bad_census.loc[bad_dup_ids]
bad_duplicates
# Out:
#       simulant_id household_id first_name middle_initial      last_name age  \
# 46         0_5337       0_2183     Dallas              Z          Lopez   5
# 47         0_5338       0_2183    Grayson              X          Lopez   3
# 83        0_17232       0_4484       Wade              J        Widmann   3
# 197        0_7454       0_3037      Kenji              Z          Kruse   2
# 687         0_180         0_78      Elmer              N  Martinez Ripa   2
# ...           ...          ...        ...            ...            ...  ..
# 10349     0_19541       0_5710      Maria              L      Woodhouse  22
# 10350     0_19580       0_2254     Brooke              E        Morales  23
# 10351     0_19683       0_3633      James              V       Saracino  23
# 10353     0_19697       0_5337    Lindsey              L          Milam  23
# 10354     0_19699       0_6277      Eryka              G        Roberts  22
#
#       date_of_birth street_number             street_name unit_number  \
# 46       02/04/2015          1613             cr ledge dr         NaN
# 47       03/15/2017          1613             cr ledge dr         NaN
# 83       07/17/2016          3303              viceroy dr         NaN
# 197      05/27/2017          6470               cr 430 rd      lot 28
# 687      07/05/2017          8300             premiere dr         NaN
# ...             ...           ...                     ...         ...
# 10349    06/11/1997         13614  burtz street northwest         NaN
# 10350    03/27/1996          5451         northwestrn pwy         NaN
# 10351    08/13/1996           580          breeze hill rd         NaN
# 10353    12/02/1996           925              sawmill rd         NaN
# 10354    01/15/1998          2849           hackberry ave         NaN
#
#           city state zipcode housing_type relationship_to_reference_person  \
# 46     Anytown    WA   00000    Household                 Biological child
# 47     Anytown    WA   00000    Household                 Biological child
# 83     Anytown    WA   00000    Household                Other nonrelative
# 197    Anytown   NaN   00000    Household                 Biological child
# 687    Anytown    WA   00000    Household                       Grandchild
# ...        ...   ...     ...          ...                              ...
# 10349  Anytown    WA   00000    Household                   Other relative
# 10350  Anytown    WA   00000    Household                   Other relative
# 10351  Anytown    WA   00000    Household                   Other relative
# 10353  Anytown    WA   00000    Household                   Other relative
# 10354  Anytown    WA   00000    Household                   Other relative
#
#           sex race_ethnicity  year
# 46       Male         Latino  2020
# 47       Male         Latino  2020
# 83       Male          White  2020
# 197      Male          White  2020
# 687      Male         Latino  2020
# ...       ...            ...   ...
# 10349  Female          Black  2020
# 10350  Female         Latino  2020
# 10351    Male          White  2020
# 10353  Female          White  2020
# 10354  Female          White  2020
#
# [264 rows x 18 columns]

# %%
bad_duplicates.housing_type.value_counts()
# Out:
# housing_type
# Household              218
# College                 32
# Nursing home             5
# Carceral                 3
# Other institutional      3
# Name: count, dtype: int64

# %%
mismatched = bad_duplicates.query("housing_type != 'Household' and relationship_to_reference_person == 'Other relative'")
mismatched
# Out:
#       simulant_id household_id first_name middle_initial last_name age  \
# 10279      0_9019       0_7064    Aaliyah              I     Mason   9
#
#       date_of_birth street_number street_name unit_number     city state  \
# 10279    02/27/2011          4444    caldwell         NaN  Anytown    WA
#
#       zipcode housing_type relationship_to_reference_person     sex  \
# 10279   00000          NaN                   Other relative  Female
#
#       race_ethnicity  year
# 10279          White  2020

# %%
bad_duplicates.query(f"simulant_id.isin({mismatched.simulant_id.to_list()})")
# Out:
#       simulant_id household_id first_name middle_initial last_name age  \
# 9295       0_9019       0_3662    Aaliyah              I     Mason   9
# 10279      0_9019       0_7064    Aaliyah              I     Mason   9
#
#       date_of_birth street_number   street_name  unit_number     city state  \
# 9295     02/27/2011          2255  vint hill rd  unit # 1013  Anytown    NJ
# 10279    02/27/2011          4444      caldwell          NaN  Anytown    WA
#
#       zipcode housing_type relationship_to_reference_person     sex  \
# 9295    00000    Household                 Biological child  Female
# 10279   00000          NaN                   Other relative  Female
#
#       race_ethnicity  year
# 9295           White  2020
# 10279          White  2020

# %% [markdown]
# # Check whether there are guardians living in group quarters
#
# Yes.

# %%
# HACK -- this only works because the duplicate rows
# appear at the end of the dataframe
n_dups = len(bad_duplicates) // 2
sim_rows = bad_duplicates.iloc[:n_dups+1]
guardian_rows = bad_duplicates.iloc[n_dups:]
assert set(sim_rows.simulant_id) == set(guardian_rows.simulant_id)
guardian_rows
# Out:
#       simulant_id household_id first_name middle_initial      last_name age  \
# 10220      0_5337       0_7824     Dallas              Z          Lopez   5
# 10221      0_5338       0_7824    Grayson              X          Lopez   3
# 10222     0_17232       0_6943       Wade              J        Widmann   3
# 10223       0_180       0_8181      Elmer              N  Martinez Ripa   2
# 10224      0_6935          0_0      Logan              D       Leftwich   6
# ...           ...          ...        ...            ...            ...  ..
# 10349     0_19541       0_5710      Maria              L      Woodhouse  22
# 10350     0_19580       0_2254     Brooke              E        Morales  23
# 10351     0_19683       0_3633      James              V       Saracino  23
# 10353     0_19697       0_5337    Lindsey              L          Milam  23
# 10354     0_19699       0_6277      Eryka              G        Roberts  22
#
#       date_of_birth street_number             street_name unit_number  \
# 10220    02/04/2015            70         independence st         NaN
# 10221    03/15/2017            70         independence st         NaN
# 10222    07/17/2016            18                  skyway         NaN
# 10223    07/05/2017           511            144th avenue         NaN
# 10224    12/05/2013          1231            riverside dr         NaN
# ...             ...           ...                     ...         ...
# 10349    06/11/1997         13614  burtz street northwest         NaN
# 10350    03/27/1996          5451         northwestrn pwy         NaN
# 10351    08/13/1996           580          breeze hill rd         NaN
# 10353    12/02/1996           925              sawmill rd         NaN
# 10354    01/15/1998          2849           hackberry ave         NaN
#
#           city state zipcode housing_type  \
# 10220  Anytown    WA   00000    Household
# 10221  Anytown    WA   00000    Household
# 10222  Anytown    WA   00000    Household
# 10223  Anytown    WA   00000    Household
# 10224  Anytown    WA   00000          NaN
# ...        ...   ...     ...          ...
# 10349  Anytown    WA   00000    Household
# 10350  Anytown    WA   00000    Household
# 10351  Anytown    WA   00000    Household
# 10353  Anytown    WA   00000    Household
# 10354  Anytown    WA   00000    Household
#
#                   relationship_to_reference_person     sex race_ethnicity  \
# 10220                               Other relative    Male         Latino
# 10221                               Other relative    Male         Latino
# 10222                               Other relative    Male          White
# 10223                               Other relative    Male         Latino
# 10224  Institutionalized group quarters population    Male          White
# ...                                            ...     ...            ...
# 10349                               Other relative  Female          Black
# 10350                               Other relative  Female         Latino
# 10351                               Other relative    Male          White
# 10353                               Other relative  Female          White
# 10354                               Other relative  Female          White
#
#        year
# 10220  2020
# 10221  2020
# 10222  2020
# 10223  2020
# 10224  2020
# ...     ...
# 10349  2020
# 10350  2020
# 10351  2020
# 10353  2020
# 10354  2020
#
# [132 rows x 18 columns]

# %%
guardian_rows.housing_type.value_counts()
# Out:
# housing_type
# Household              116
# Nursing home             5
# Carceral                 3
# Other institutional      3
# College                  3
# Name: count, dtype: int64

# %%
sim_rows.housing_type.value_counts()
# Out:
# housing_type
# Household    103
# College       29
# Name: count, dtype: int64

# %%
guardian_rows.query("housing_type != 'Household'")
# Out:
#       simulant_id household_id   first_name middle_initial      last_name age  \
# 10224      0_6935          0_0        Logan              D       Leftwich   6
# 10225      0_6936          0_0         Ella              G       Leftwich   3
# 10233      0_9820          0_1      Allison              L         Curtis   3
# 10236     0_10552          0_0         Alan              K         Revels  10
# 10258     0_18258          0_2       Carlos              M            Lee  12
# 10267      0_6450          0_2  Christopher              M    Castellanos  14
# 10276      0_9314          0_1        Alina              R        Cordova  14
# 10277      0_9315          0_1        Aiden              J        Cordova  12
# 10279      0_9019       0_7064      Aaliyah              I          Mason   9
# 10282      0_5431          0_0  Christopher              N          Yager   5
# 10286       0_729          0_3       Sophia              A      Henderson   5
# 10288     0_12782          0_1        Wyatt              M           Webb   9
# 10289       0_984          0_2       Jordan              L      Hernandez   9
# 10300     0_10423          0_1         Ella              G  Torresramirez   6
# 10313     0_13507          0_3          Ava              J       Boughton   6
# 10314     0_13508          0_3    Gabrielle              E       Boughton   5
#
#       date_of_birth street_number          street_name unit_number     city  \
# 10224    12/05/2013          1231         riverside dr         NaN  Anytown
# 10225    10/02/2016          1231         riverside dr         NaN  Anytown
# 10233    12/26/2016            34         bowen cir sw         NaN  Anytown
# 10236    12/14/2009          1231         riverside dr         NaN  Anytown
# 10258    07/01/2007          2333    westminster place         NaN  Anytown
# 10267    09/24/2005          2333    westminster place         NaN  Anytown
# 10276    04/19/2005            34         bowen cir sw         NaN  Anytown
# 10277    02/10/2008            34         bowen cir sw         NaN  Anytown
# 10279    02/27/2011          4444             caldwell         NaN  Anytown
# 10282    06/23/2014          1231         riverside dr         NaN  Anytown
# 10286    05/12/2014          8203  west farwell avenue         NaN  Anytown
# 10288    06/16/2010            34         bowen cir sw         NaN  Anytown
# 10289    12/12/2010          2333    westminster place         NaN  Anytown
# 10300    01/22/2014            34         bowen cir sw         NaN  Anytown
# 10313    06/11/2013          8203  west farwell avenue         NaN  Anytown
# 10314    07/24/2014          8203  west farwell avenue         NaN  Anytown
#
#       state zipcode         housing_type  \
# 10224    WA   00000                  NaN
# 10225    WA     NaN             Carceral
# 10233    WA   00001         Nursing home
# 10236    WA   00000             Carceral
# 10258    WA   00000  Other institutional
# 10267    WA   00000  Other institutional
# 10276    WA   00000         Nursing home
# 10277    WA   00000         Nursing home
# 10279    WA   00000                  NaN
# 10282    WA   00000             Carceral
# 10286    WA   00000              College
# 10288    WA   00000         Nursing home
# 10289    WA   00000  Other institutional
# 10300    WA   00000         Nursing home
# 10313    WA   00000              College
# 10314    WA   00000              College
#
#                      relationship_to_reference_person     sex  \
# 10224     Institutionalized group quarters population    Male
# 10225     Institutionalized group quarters population  Female
# 10233     Institutionalized group quarters population  Female
# 10236     Institutionalized group quarters population    Male
# 10258     Institutionalized group quarters population     NaN
# 10267     Institutionalized group quarters population    Male
# 10276     Institutionalized group quarters population  Female
# 10277     Institutionalized group quarters population    Male
# 10279                                  Other relative  Female
# 10282     Institutionalized group quarters population    Male
# 10286  Noninstitutionalized group quarters population  Female
# 10288     Institutionalized group quarters population    Male
# 10289     Institutionalized group quarters population  Female
# 10300     Institutionalized group quarters population  Female
# 10313  Noninstitutionalized group quarters population  Female
# 10314  Noninstitutionalized group quarters population  Female
#
#              race_ethnicity  year
# 10224                 White  2020
# 10225                 White  2020
# 10233                 White  2020
# 10236                 White  2020
# 10258                 Black  2020
# 10267                 White  2020
# 10276                Latino  2020
# 10277                Latino  2020
# 10279                 White  2020
# 10282                 White  2020
# 10286                 White  2020
# 10288  Multiracial or Other  2020
# 10289                Latino  2020
# 10300                Latino  2020
# 10313                 White  2020
# 10314                 White  2020

# %%
issubclass(psp.exceptions.DataSourceError, Exception)
# Out:
# True

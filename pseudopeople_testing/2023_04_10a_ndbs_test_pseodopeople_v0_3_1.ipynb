# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd
pd.set_option('display.max_rows', 50)

import os
# Use this to see how much memory the dataframes use
from sys import getsizeof

import yaml

import pseudopeople as pp
from pseudopeople.utilities import get_configuration
from vivarium.framework.randomness import RandomnessStream
from vivarium.config_tree import ConfigTree

from vivarium_research_prl.utils import sizemb, MappingViaAttributes
from vivarium_research_prl import datatypes
from vivarium_research_prl.noise import corruption, fake_names, noisify
from vivarium_research_prl.find_kids import datasets, noisify_data

# !date
# !whoami
# !uname -a
# !pwd
# Out:
# Mon 10 Apr 2023 03:18:35 PM PDT
# ndbs
# Linux gen-slurm-sarchive-p0154 5.4.0-135-generic #152-Ubuntu SMP Wed Nov 23 20:19:22 UTC 2022 x86_64 x86_64 x86_64 GNU/Linux
# /mnt/share/code/ndbs/vivarium_research_prl/pseudopeople_testing

# %% [markdown]
# # Find data -- let's try parquet first
#
# ```
# /mnt/team/simulation_science/priv/engineering/vivarium_census_prl_synth_pop/results/v2.0_three_censuses/united_states_of_america/2023_04_08_14_07_04/final_results/parquet/
# ```

# %%
project_dir = '/mnt/team/simulation_science/priv/engineering/vivarium_census_prl_synth_pop'
model_dir = (
    f'{project_dir}/results'
    '/v2.0_three_censuses/united_states_of_america/2023_04_08_14_07_04'
)
rhode_island_dir = f'{model_dir}/final_results/parquet/states/rhode_island'
usa_dir = f'{model_dir}/final_results/parquet/usa'

# !ls -halt $usa_dir
# Out:
# total 284K
# drwxrwsr-x  5 rmudambi IHME-Simulationscience 1.5K Apr  9 18:48 ..
# drwxrwsr-x 10 rmudambi IHME-Simulationscience 4.0K Apr  9 15:41 .
# drwxrwsr-x  2 rmudambi IHME-Simulationscience 167K Apr  9 12:21 tax_dependents_observer
# drwxrwsr-x  2 rmudambi IHME-Simulationscience 167K Apr  9 12:20 tax_1040_observer
# drwxrwsr-x  2 rmudambi IHME-Simulationscience 167K Apr  9 12:15 tax_w2_observer
# drwxrwsr-x  2 rmudambi IHME-Simulationscience 167K Apr  9 12:09 social_security_observer
# drwxrwsr-x  2 rmudambi IHME-Simulationscience 167K Apr  9 12:09 wic_observer
# drwxrwsr-x  2 rmudambi IHME-Simulationscience 167K Apr  9 12:09 household_survey_observer_cps
# drwxrwsr-x  2 rmudambi IHME-Simulationscience 167K Apr  9 12:09 household_survey_observer_acs
# drwxrwsr-x  2 rmudambi IHME-Simulationscience 167K Apr  9 12:09 decennial_census_observer

# %%
# !ls -halt $rhode_island_dir/tax_w2_observer
# Out:
# total 16G
# drwxrwsr-x 9 rmudambi IHME-Simulationscience 3.5K Apr 10 11:10 ..
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9 21:10 tax_w2_observer_9971.parquet
# drwxrwsr-x 2 rmudambi IHME-Simulationscience 167K Apr  9 21:10 .
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9 21:10 tax_w2_observer_9911.parquet
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9 21:09 tax_w2_observer_9901.parquet
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9 21:09 tax_w2_observer_99.parquet
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9 21:09 tax_w2_observer_9888.parquet
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9 21:08 tax_w2_observer_9872.parquet
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9 21:08 tax_w2_observer_9871.parquet
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9 21:08 tax_w2_observer_9859.parquet
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9 21:07 tax_w2_observer_9847.parquet
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9 21:07 tax_w2_observer_9840.parquet
# -rw-r--r-- 1 rmudambi IHME-Simulationscience  49M Apr  9
parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 966M Apr  9 11:51 tax_w2_observer_1490.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 967M Apr  9 11:51 tax_w2_observer_4950.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 965M Apr  9 11:51 tax_w2_observer_1559.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 965M Apr  9 11:51 tax_w2_observer_1483.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 967M Apr  9 11:51 tax_w2_observer_1482.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 966M Apr  9 11:51 tax_w2_observer_4561.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 966M Apr  9 11:50 tax_w2_observer_107.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 967M Apr  9 11:50 tax_w2_observer_3776.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 967M Apr  9 11:49 tax_w2_observer_1061.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 966M Apr  9 11:49 tax_w2_observer_3528.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 966M Apr  9 11:48 tax_w2_observer_3326.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 965M Apr  9 11:48 tax_w2_observer_1219.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 966M Apr  9 11:48 tax_w2_observer_3357.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 968M Apr  9 11:48 tax_w2_observer_315.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 967M Apr  9 11:48 tax_w2_observer_323.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 966M Apr  9 11:48 tax_w2_observer_3305.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 965M Apr  9 11:48 tax_w2_observer_3254.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 966M Apr  9 11:48 tax_w2_observer_3167.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 966M Apr  9 11:48 tax_w2_observer_3240.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 966M Apr  9 11:48 tax_w2_observer_3225.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 967M Apr  9 11:47 tax_w2_observer_3202.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 965M Apr  9 11:47 tax_w2_observer_3142.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 967M Apr  9 11:47 tax_w2_observer_3093.parquet
# -rw-r--r--  1 rmudambi IHME-Simulationscience 964M Apr  9 11:47 tax_w2_observer_2965.parquet

# %%
seed = 5670
ext = '.parquet'
ri_w2_dir = f'{rhode_island_dir}/tax_w2_observer'
ri_census_dir = f'{rhode_island_dir}/decennial_census_observer'
ri_acs_dir = f'{rhode_island_dir}/household_survey_observer_acs'

ri_w2_path = f'{ri_w2_dir}/tax_w2_observer_{seed}{ext}'
ri_census_path = f'{ri_census_dir}/decennial_census_observer_{seed}{ext}'
ri_acs_path = f'{ri_acs_dir}/household_survey_observer_acs_{seed}{ext}'

usa_w2_dir = f'{usa_dir}/tax_w2_observer'
usa_census_dir = f'{usa_dir}/decennial_census_observer'
usa_acs_dir = f'{usa_dir}/household_survey_observer_acs'

usa_w2_path = f'{usa_w2_dir}/tax_w2_observer_{seed}{ext}'
usa_census_path = f'{usa_census_dir}/decennial_census_observer_{seed}{ext}'
usa_acs_path = f'{usa_acs_dir}/household_survey_observer_acs_{seed}{ext}'

# %% [markdown]
# # Try loading noised W2 data for RI from parquet

# %%
ri_w2_path
# Out:
# '/mnt/team/simulation_science/priv/engineering/vivarium_census_prl_synth_pop/results/v2.0_three_censuses/united_states_of_america/2023_04_08_14_07_04/final_results/parquet/states/rhode_island/tax_w2_observer/tax_w2_observer_5670.parquet'

# %%
# %%time
df_ri_w2_noisy = pp.generate_taxes_w2_and_1099(ri_w2_path)
df_ri_w2_noisy
# Out:
# CPU times: user 17.5 s, sys: 4.81 s, total: 22.3 s
# Wall time: 22.3 s
#          mailing_address_street_name   simulant_id  \
# 645                       chell road      5670_668
# 884                   delbert avenue      5670_964
# 997                      redstone ct     5670_1082
# 1222                    n hills blvd     5670_1309
# 1223                    n hills blvd     5670_1309
# ...                              ...           ...
# 22383502                s mobile way  5670_1386266
# 22384285                 28th avenue  5670_1390271
# 22384596              state route 11  5670_1391736
# 22384731                 grace dr nw  5670_1391962
# 22384732                 grace dr nw  5670_1391963
#
#          mailing_address_unit_number mailing_address_zipcode  tax_year  \
# 645                                                    02881      2019
# 884                                                    02915      2019
# 997                                                    02864      2019
# 1222                                                   02909      2019
# 1223                                                   02909      2019
# ...                              ...                     ...       ...
# 22383502                                               02886      2040
# 22384285                                               02893      2040
# 22384596                                               02895      2040
# 22384731                                               02908      2040
# 22384732                                               02908      2040
#
#          mailing_address_street_number        date_of_birth  \
# 645                               9100  1974-09-23 00:00:00
# 884                               5525  1964-09-17 00:00:00
# 997                               1004  1960-02-03 00:00:00
# 1222                               445  1964-02-26 00:00:00
# 1223                               445  1964-02-26 00:00:00
# ...                                ...                  ...
# 22383502                           151  1986-07-10 00:00:00
# 22384285                         10700  1978-05-13 00:00:00
# 22384596                          9444  1979-06-19 00:00:00
# 22384731                          8430  2005-04-10 00:00:00
# 22384732                          8430  2004-05-31 00:00:00
#
#          employer_street_name          ssn employer_id  ...  \
# 645                  e 116 st  730-78-3410       39721  ...
# 884            westdale rd nw  889-15-3299      153658  ...
# 997                randall st  530-84-2449      340968  ...
# 1222         trinity hls lane  072-23-2212      735259  ...
# 1223           sparta oaks dr  072-23-2212     1338401  ...
# ...                       ...          ...         ...  ...
# 22383502              oaklawn  428-45-0772     1188968  ...
# 22384285            e 42nd st  187-35-0120     1307191  ...
# 22384596         sw 215th ter  842-31-6424     1703745  ...
# 22384731         s frazier st  211-04-1068     1420370  ...
# 22384732            86 street  825-91-1689      904904  ...
#
#          employer_street_number income employer_zipcode first_name age  \
# 645                       26875  16928            95835       Jose  45
# 884                         607  24677            70180       Tony  55
# 997                        1531  82625            08753      Leona  59
# 1222                       3689   9926            85713      April  55
# 1223                       5835   6134            81321      April  55
# ...                         ...    ...              ...        ...  ..
# 22383502                   <NA>  16882            17701     Robert  54
# 22384285                   4655   3064            84120    Johanna  62
# 22384596                           474            14437    Rebecca  61
# 22384731                  25515   6261            12523     Sophia  35
# 22384732                    168   4139            33056   Jeremiah  36
#
#          employer_state employer_unit_number mailing_address_city  \
# 645                  CA                                    warren
# 884                  LA                                providence
# 997                  NJ                                  cranston
# 1222                 AZ                                providence
# 1223                 CO                                providence
# ...                 ...                  ...                  ...
# 22383502             PA                              west warwick
# 22384285             UT                           south kingstown
# 22384596             NY                                providence
# 22384731             NY                                  westerly
# 22384732             FL                                  westerly
#
#          mailing_address_state middle_initial
# 645                         RI              M
# 884                         RI              P
# 997                         RI              M
# 1222                        AR              W
# 1223                        RI              W
# ...                        ...            ...
# 22383502                    RI              P
# 22384285                    RI              S
# 22384596                    RI              B
# 22384731                    RI              L
# 22384732                    RI              N
#
# [63967 rows x 25 columns]

# %%
df_ri_w2_noisy.dtypes
# Out:
# mailing_address_street_name        object
# simulant_id                      category
# mailing_address_unit_number        object
# mailing_address_zipcode            object
# tax_year                            int64
# mailing_address_street_number      object
# date_of_birth                      object
# employer_street_name               object
# ssn                                object
# employer_id                        object
# last_name                          object
# employer_city                      object
# mailing_address_po_box             object
# employer_name                      object
# tax_form                           object
# employer_street_number             object
# income                             object
# employer_zipcode                   object
# first_name                         object
# age                                object
# employer_state                     object
# employer_unit_number               object
# mailing_address_city               object
# mailing_address_state              object
# middle_initial                     object
# dtype: object

# %%
sizemb(df_ri_w2_noisy)
# Out:
# 204.441694

# %% [markdown]
# # Load unnoised W2 data for RI

# %%
# %%time
df_ri_w2 = pd.read_parquet(ri_w2_path)
df_ri_w2
# Out:
# CPU times: user 4.69 s, sys: 1.26 s, total: 5.94 s
# Wall time: 5.96 s
#          mailing_address_street_name   simulant_id  \
# 645                       chell road      5670_668
# 884                   delbert avenue      5670_964
# 997                      redstone ct     5670_1082
# 1222                    n hills blvd     5670_1309
# 1223                    n hills blvd     5670_1309
# ...                              ...           ...
# 22383502                s mobile way  5670_1386266
# 22384285                 28th avenue  5670_1390271
# 22384596              state route 11  5670_1391736
# 22384731                 grace dr nw  5670_1391962
# 22384732                 grace dr nw  5670_1391963
#
#          mailing_address_unit_number mailing_address_zipcode  tax_year  \
# 645                                                    02881      2019
# 884                                                    02915      2019
# 997                                                    02864      2019
# 1222                                                   02909      2019
# 1223                                                   02909      2019
# ...                              ...                     ...       ...
# 22383502                                               02886      2040
# 22384285                                               02893      2040
# 22384596                                               02895      2040
# 22384731                                               02908      2040
# 22384732                                               02908      2040
#
#          mailing_address_street_number date_of_birth employer_street_name  \
# 645                               9100    1974-09-23             e 116 st
# 884                               5525    1964-09-17       westdale rd nw
# 997                               1004    1960-02-03           randall st
# 1222                               445    1964-02-26     trinity hls lane
# 1223                               445    1964-02-26       sparta oaks dr
# ...                                ...           ...                  ...
# 22383502                           151    1986-07-10              oaklawn
# 22384285                         10700    1978-05-13            e 42nd st
# 22384596                          9444    1979-06-19         sw 215th ter
# 22384731                          8430    2005-04-10         s frazier st
# 22384732                          8430    2004-05-31            86 street
#
#                   ssn  employer_id  ... employer_street_number income  \
# 645       730-78-3410        39721  ...                  26875  16928
# 884       889-15-3299       153658  ...                    607  24677
# 997       530-84-2449       340968  ...                   1531  82625
# 1222      072-23-2212       735259  ...                   3689   9926
# 1223      072-23-2212      1338401  ...                   5835   6134
# ...               ...          ...  ...                    ...    ...
# 22383502  428-45-0772      1188968  ...                     24  16882
# 22384285  187-35-0120      1307191  ...                   4655   3064
# 22384596  842-31-6424      1703745  ...                           474
# 22384731  211-04-1068      1420370  ...                   2555   6261
# 22384732  825-91-1689       904904  ...                    168   4139
#
#           employer_zipcode first_name age employer_state  \
# 645                  95835       Jose  45             CA
# 884                  70080       Tony  55             LA
# 997                  08753      Leona  59             NJ
# 1222                 85713      April  55             AZ
# 1223                 81321      April  55             CO
# ...                    ...        ...  ..            ...
# 22383502             17701     Robert  54             PA
# 22384285             84120    Johanna  62             UT
# 22384596             14437    Rebecca  61             NY
# 22384731             12523     Sophia  35             NY
# 22384732             33056   Jeremiah  36             FL
#
#           employer_unit_number mailing_address_city mailing_address_state  \
# 645                                          warren                    RI
# 884                                      providence                    RI
# 997                                        cranston                    RI
# 1222                                     providence                    RI
# 1223                                     providence                    RI
# ...                        ...                  ...                   ...
# 22383502                               west warwick                    RI
# 22384285                            south kingstown                    RI
# 22384596                                 providence                    RI
# 22384731                                   westerly                    RI
# 22384732                                   westerly                    RI
#
#           middle_initial
# 645                    M
# 884                    P
# 997                    M
# 1222                   W
# 1223                   W
# ...                  ...
# 22383502               P
# 22384285               S
# 22384596               B
# 22384731               L
# 22384732               N
#
# [63967 rows x 25 columns]

# %%
df_ri_w2.dtypes
# Out:
# mailing_address_street_name            category
# simulant_id                            category
# mailing_address_unit_number            category
# mailing_address_zipcode                category
# tax_year                                  int64
# mailing_address_street_number          category
# date_of_birth                    datetime64[ns]
# employer_street_name                   category
# ssn                                    category
# employer_id                               int64
# last_name                              category
# employer_city                          category
# mailing_address_po_box                    int64
# employer_name                          category
# tax_form                               category
# employer_street_number                 category
# income                                    int64
# employer_zipcode                       category
# first_name                             category
# age                                       int64
# employer_state                         category
# employer_unit_number                   category
# mailing_address_city                   category
# mailing_address_state                  category
# middle_initial                         category
# dtype: object

# %%
sizemb(df_ri_w2)
# Out:
# 579.203098

# %%
sizemb(df_ri_w2.ssn)
# Out:
# 127.17426

# %%
sizemb(df_ri_w2_noisy.ssn)
# Out:
# 6.957732

# %%
sizemb(df_ri_w2_noisy.simulant_id)
# Out:
# 114.383364

# %%
sizemb(df_ri_w2_noisy.employer_id)
# Out:
# 4.966405

# %%
sizemb(df_ri_w2_noisy.employer_name)
# Out:
# 7.880263

# %% [markdown]
# # Load unnoised W2 data for USA

# %%
usa_w2_path
# Out:
# '/mnt/team/simulation_science/priv/engineering/vivarium_census_prl_synth_pop/results/v2.0_three_censuses/united_states_of_america/2023_04_08_14_07_04/final_results/parquet/usa/tax_w2_observer/tax_w2_observer_5670.parquet'

# %%
# %%time
df_usa_w2 = pd.read_parquet(usa_w2_path)
df_usa_w2
# Out:
# CPU times: user 10.9 s, sys: 5.28 s, total: 16.2 s
# Wall time: 18.2 s
#          mailing_address_street_name   simulant_id  \
# 0                    northview dr ne        5670_0
# 1                    northview dr ne        5670_0
# 2                          tivoli ln        5670_2
# 3                          tivoli ln        5670_3
# 4                         oakview ln        5670_4
# ...                              ...           ...
# 22384735           old nat'l highway  5670_1391966
# 22384736                    n 4th st  5670_1391970
# 22384737             watervliet avnu  5670_1391971
# 22384738             watervliet avnu  5670_1391972
# 22384739                  main ave n  5670_1391973
#
#          mailing_address_unit_number mailing_address_zipcode  tax_year  \
# 0                                                      17013      2019
# 1                                                      17013      2019
# 2                                                      91601      2019
# 3                                                      91601      2019
# 4                                                      30005      2019
# ...                              ...                     ...       ...
# 22384735                                               27603      2040
# 22384736                                               33401      2040
# 22384737                                               60612      2040
# 22384738                                               60612      2040
# 22384739                                               26651      2040
#
#          mailing_address_street_number date_of_birth   employer_street_name  \
# 0                                  235    1953-01-19           edgecliff ct
# 1                                  235    1953-01-19              n 52nd st
# 2                                  118    1979-01-30            skyview ter
# 3                                  118    1979-04-10                ince dr
# 4                                         2001-01-21         stoney crk cir
# ...                                ...           ...                    ...
# 22384735                          8011    2005-05-18    west lexington stre
# 22384736                            49    1999-07-03            s oriole av
# 22384737                           105    2007-09-23    n browns station dr
# 22384738                           105    2011-11-05  southeast 22nd street
# 22384739                            51    1963-12-20          9th street ne
#
#                   ssn  employer_id  ... employer_street_number income  \
# 0         863-79-9332       923417  ...                         28043
# 1         863-79-9332      1258181  ...                    309  12141
# 2         801-14-2038      1631549  ...                   1960  13517
# 3         801-14-2038      1358821  ...                      e  13952
# 4         509-76-7953            1  ...                           222
# ...               ...          ...  ...                    ...    ...
# 22384735  466-41-2227        27816  ...                   1507   2195
# 22384736  476-71-8945      1350023  ...                   1116  12961
# 22384737  229-73-1457       372782  ...                    115  15346
# 22384738  075-82-5964       432807  ...                   3388   1101
# 22384739  062-30-4713       237182  ...                   4922  13057
#
#           employer_zipcode first_name age employer_state  \
# 0                    93101    Phyllis  66             CA
# 1                    37013    Phyllis  66             TN
# 2                    85308    Rebecca  40             AZ
# 3                    85006    Richard  40             AZ
# 4                    45459       Owen  18             OH
# ...                    ...        ...  ..            ...
# 22384735             37909     Robert  35             TN
# 22384736             89506    Meaghan  41             NV
# 22384737             33308    Anthony  33             FL
# 22384738             21755     Elijah  29             MD
# 22384739             11224      Terry  77             NY
#
#           employer_unit_number mailing_address_city mailing_address_state  \
# 0                                        harrisburg                    PA
# 1                                        harrisburg                    PA
# 2                     unit 170              visalia                    CA
# 3                                           visalia                    CA
# 4                                       johns creek                    GA
# ...                        ...                  ...                   ...
# 22384735                                mooresville                    NC
# 22384736                               lehigh acres                    FL
# 22384737                              lawrenceville                    IL
# 22384738                              lawrenceville                    IL
# 22384739                                 morgantown                    WV
#
#           middle_initial
# 0                      D
# 1                      D
# 2                      C
# 3                      D
# 4                      C
# ...                  ...
# 22384735               K
# 22384736               C
# 22384737               J
# 22384738               E
# 22384739               K
#
# [22384740 rows x 25 columns]

# %%
df_usa_w2.dtypes
# Out:
# mailing_address_street_name            category
# simulant_id                            category
# mailing_address_unit_number            category
# mailing_address_zipcode                category
# tax_year                                  int64
# mailing_address_street_number          category
# date_of_birth                    datetime64[ns]
# employer_street_name                   category
# ssn                                    category
# employer_id                               int64
# last_name                              category
# employer_city                          category
# mailing_address_po_box                    int64
# employer_name                          category
# tax_form                               category
# employer_street_number                 category
# income                                    int64
# employer_zipcode                       category
# first_name                             category
# age                                       int64
# employer_state                         category
# employer_unit_number                   category
# mailing_address_city                   category
# mailing_address_state                  category
# middle_initial                         category
# dtype: object

# %%
sizemb(df_usa_w2) # 2.8 GB for the unnoised USA W2 data
# Out:
# 2810.76879

# %%
2.8*334
# Out:
# 935.1999999999999

# %%
type(df_usa_w2)
# Out:
# pandas.core.frame.DataFrame

# %%
sizemb(df_usa_w2.first_name)
# Out:
# 45.809479

# %%
# %time sizemb(df_usa_w2.simulant_id)
# Out:
# CPU times: user 171 ms, sys: 7.7 ms, total: 179 ms
# Wall time: 178 ms
# 201.041272

# %%
# %time sizemb(df_usa_w2.simulant_id.astype(str))
# Out:
# CPU times: user 6.13 s, sys: 2.64 s, total: 8.77 s
# Wall time: 8.76 s
# 1521.30808

# %% [markdown]
# # Generate noised W2 data for USA

# %%
# %%time
df_usa_w2_noisy = pp.generate_taxes_w2_and_1099(usa_w2_path)
df_usa_w2_noisy
# Out:
# CPU times: user 9min 43s, sys: 1min 58s, total: 11min 41s
# Wall time: 11min 32s
#          mailing_address_street_name   simulant_id  \
# 0                    northview dr ne        5670_0
# 1                    northview dr ne        5670_0
# 2                          tivoli ln        5670_2
# 3                          tivoli ln        5670_3
# 4                         oakview ln        5670_4
# ...                              ...           ...
# 22384735           old nat'l highway  5670_1391966
# 22384736                    n 4th st  5670_1391970
# 22384737             watervliet avnu  5670_1391971
# 22384738             watervliet avnu  5670_1391972
# 22384739                  main ave n  5670_1391973
#
#          mailing_address_unit_number mailing_address_zipcode  tax_year  \
# 0                                                       <NA>      2019
# 1                                                      17013      2019
# 2                                                      91601      2019
# 3                                                      91601      2019
# 4                                                      30005      2019
# ...                              ...                     ...       ...
# 22384735                                               27603      2040
# 22384736                                               33401      2040
# 22384737                                               60612      2040
# 22384738                                               60612      2040
# 22384739                                               26651      2040
#
#          mailing_address_street_number        date_of_birth  \
# 0                                  235  1953-01-19 00:00:00
# 1                                  235  1953-01-19 00:00:00
# 2                                  118  1979-01-30 00:00:00
# 3                                  118  1979-04-10 00:00:00
# 4                                       2001-01-21 00:00:00
# ...                                ...                  ...
# 22384735                          8011  2005-05-18 00:00:00
# 22384736                            49  1999-07-03 00:00:00
# 22384737                           105  2007-09-23 00:00:00
# 22384738                           105  2011-11-05 00:00:00
# 22384739                            51  1963-12-20 00:00:00
#
#            employer_street_name          ssn employer_id  ...  \
# 0                  edgecliff ct  863-79-9332      923417  ...
# 1                     n 52nd st  863-79-9332     1258181  ...
# 2                   skyview ter  801-14-2038     1631549  ...
# 3                       ince dr  801-14-2038     1358821  ...
# 4                stoney crk cir  509-76-7953           1  ...
# ...                         ...          ...         ...  ...
# 22384735                   <NA>  466-41-2227       27816  ...
# 22384736            s oriole av  476-71-8945     1350023  ...
# 22384737    n browns station dr  229-73-1457      372782  ...
# 22384738  southeast 22nd street  075-82-5964      432807  ...
# 22384739          9th street ne  062-30-4713      237182  ...
#
#          employer_street_number income employer_zipcode first_name age  \
# 0                                28043            93101    Phyllis  66
# 1                           309  12141            37013    Phyllis  66
# 2                          1960  13517            85308    Rebecca  40
# 3                             e  13952            85006    Richard  40
# 4                                  222            45459       Owen  18
# ...                         ...    ...              ...        ...  ..
# 22384735                   1507   2195            37909     Robert  35
# 22384736                   1116  12961            89506    Meaghan  41
# 22384737                    115  15346            33308    Anthony  33
# 22384738                   3388   1101            21755     Elijah  29
# 22384739                   4922  13057            11224      Terry  77
#
#          employer_state employer_unit_number mailing_address_city  \
# 0                    CA                                harrisburg
# 1                    TN                                harrisburg
# 2                    AZ             unit 170              visalia
# 3                    AZ                                   visalia
# 4                    OH                               johns creek
# ...                 ...                  ...                  ...
# 22384735             TN                               mooresville
# 22384736             NV                              lehigh acres
# 22384737             FL                             lawrenceville
# 22384738             MD                             lawrenceville
# 22384739             NY                                morgantown
#
#          mailing_address_state middle_initial
# 0                           PA              D
# 1                           PA              D
# 2                           CA              C
# 3                           CA              D
# 4                         <NA>              C
# ...                        ...            ...
# 22384735                    NC              K
# 22384736                    FL              C
# 22384737                    IL              J
# 22384738                    IL              E
# 22384739                    WV              K
#
# [22384740 rows x 25 columns]

# %%
df_usa_w2_noisy.dtypes
# Out:
# mailing_address_street_name        object
# simulant_id                      category
# mailing_address_unit_number        object
# mailing_address_zipcode            object
# tax_year                            int64
# mailing_address_street_number      object
# date_of_birth                      object
# employer_street_name               object
# ssn                                object
# employer_id                        object
# last_name                          object
# employer_city                      object
# mailing_address_po_box             object
# employer_name                      object
# tax_form                           object
# employer_street_number             object
# income                             object
# employer_zipcode                   object
# first_name                         object
# age                                object
# employer_state                     object
# employer_unit_number               object
# mailing_address_city               object
# mailing_address_state              object
# middle_initial                     object
# dtype: object

# %%
# %%time
sizemb(df_usa_w2_noisy) # 31.7 GB for the noised USA W2 data
# Out:
# CPU times: user 52.1 s, sys: 3.25 s, total: 55.4 s
# Wall time: 55.2 s
# 31691.982976

# %%
# %time sizemb(df_usa_w2_noisy.simulant_id)
# Out:
# CPU times: user 163 ms, sys: 19.6 ms, total: 182 ms
# Wall time: 181 ms
# 201.041272

# %%
# %time sizemb(df_usa_w2_noisy.employer_id)
# Out:
# CPU times: user 3.24 s, sys: 159 ms, total: 3.4 s
# Wall time: 3.37 s
# 818.948468

# %%
# %time sizemb(df_usa_w2_noisy.first_name)
# Out:
# CPU times: user 3.25 s, sys: 70.8 ms, total: 3.32 s
# Wall time: 3.3 s
# 1404.080518

# %% [markdown]
# # Check configuration

# %%
config = get_configuration()
config.taxes_w2_and_1099
# Out:
# omission:
#     base: 0.0
#         source: initial data
# duplication:
#     base: 0.05
#         source: initial data
# age:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     age_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         possible_perturbations:
#             1:
#                 base: 0.5
#                     source: initial data
#             -1:
#                 base: 0.5
#                     source: initial data
# date_of_birth:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     numeric_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
# employer_city:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
# employer_id:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     numeric_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
# employer_name:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
# employer_state:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     incorrect_selection:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
# employer_street_name:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
# employer_street_number:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     numeric_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
# employer_unit_number:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     numeric_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
# employer_zipcode:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     zipcode_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         first_two_digits_noise_level:
#             base: 0.04
#                 source: initial data
#         middle_digit_noise_level:
#             base: 0.2
#                 source: initial data
#         last_two_digits_noise_level:
#             base: 0.36
#                 source: initial data
# first_name:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     fake_names:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
# income:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     numeric_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
# last_name:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     fake_names:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
# mailing_address_city:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
# mailing_address_state:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     incorrect_selection:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
# mailing_address_street_name:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
# mailing_address_street_number:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     numeric_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
# mailing_address_unit_number:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     numeric_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
# mailing_address_po_box:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     numeric_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
# mailing_address_zipcode:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     zipcode_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         first_two_digits_noise_level:
#             base: 0.04
#                 source: initial data
#         middle_digit_noise_level:
#             base: 0.2
#                 source: initial data
#         last_two_digits_noise_level:
#             base: 0.36
#                 source: initial data
# middle_initial:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
# ssn:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     typographic:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
#         include_original_token_level:
#             base: 0.1
#                 source: initial data
#     numeric_miswriting:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#         token_noise_level:
#             base: 0.1
#                 source: initial data
# tax_form:
#     missing_data:
#         row_noise_level:
#             base: 0.01
#                 source: initial data
#     incorrect_selection:
#         row_noise_level:
#             base: 0.01
#                 source: initial data

# %%
[
    k for k, v  in config.taxes_w2_and_1099.items()
    if k not in ['omission', 'duplication']
    and 'typographic' in v
]
# Out:
# ['age',
#  'date_of_birth',
#  'employer_city',
#  'employer_id',
#  'employer_name',
#  'employer_street_name',
#  'employer_street_number',
#  'employer_unit_number',
#  'employer_zipcode',
#  'first_name',
#  'income',
#  'last_name',
#  'mailing_address_city',
#  'mailing_address_street_name',
#  'mailing_address_street_number',
#  'mailing_address_unit_number',
#  'mailing_address_po_box',
#  'mailing_address_zipcode',
#  'middle_initial',
#  'ssn']

# %% [markdown]
# # Try generating USA W2 data with all noise except typographic

# %%
config.taxes_w2_and_1099.income
# Out:
# missing_data:
#     row_noise_level:
#         base: 0.01
#             source: initial data
# typographic:
#     row_noise_level:
#         base: 0.01
#             source: initial data
#     token_noise_level:
#         base: 0.1
#             source: initial data
#     include_original_token_level:
#         base: 0.1
#             source: initial data
# numeric_miswriting:
#     row_noise_level:
#         base: 0.01
#             source: initial data
#     token_noise_level:
#         base: 0.1
#             source: initial data

# %%
w2_config = config.taxes_w2_and_1099.to_dict()
cols_with_typos = [
    k for k, col_config  in w2_config.items()
    if k not in ['omission', 'duplication']
    and 'typographic' in col_config
]
print(cols_with_typos)
for col in cols_with_typos:
    w2_config[col]['typographic']['row_noise_level'] = 0
w2_config
# Out:
# ['age', 'date_of_birth', 'employer_city', 'employer_id', 'employer_name', 'employer_street_name', 'employer_street_number', 'employer_unit_number', 'employer_zipcode', 'first_name', 'income', 'last_name', 'mailing_address_city', 'mailing_address_street_name', 'mailing_address_street_number', 'mailing_address_unit_number', 'mailing_address_po_box', 'mailing_address_zipcode', 'middle_initial', 'ssn']
# {'omission': 0.0,
#  'duplication': 0.05,
#  'age': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'age_miswriting': {'row_noise_level': 0.01,
#    'token_noise_level': 0.1,
#    'possible_perturbations': {1: 0.5, -1: 0.5}}},
#  'date_of_birth': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'numeric_miswriting': {'row_noise_level': 0.01, 'token_noise_level': 0.1}},
#  'employer_city': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1}},
#  'employer_id': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'numeric_miswriting': {'row_noise_level': 0.01, 'token_noise_level': 0.1}},
#  'employer_name': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1}},
#  'employer_state': {'missing_data': {'row_noise_level': 0.01},
#   'incorrect_selection': {'row_noise_level': 0.01}},
#  'employer_street_name': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1}},
#  'employer_street_number': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'numeric_miswriting': {'row_noise_level': 0.01, 'token_noise_level': 0.1}},
#  'employer_unit_number': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'numeric_miswriting': {'row_noise_level': 0.01, 'token_noise_level': 0.1}},
#  'employer_zipcode': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'zipcode_miswriting': {'row_noise_level': 0.01,
#    'first_two_digits_noise_level': 0.04,
#    'middle_digit_noise_level': 0.2,
#    'last_two_digits_noise_level': 0.36}},
#  'first_name': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'fake_names': {'row_noise_level': 0.01}},
#  'income': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'numeric_miswriting': {'row_noise_level': 0.01, 'token_noise_level': 0.1}},
#  'last_name': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'fake_names': {'row_noise_level': 0.01}},
#  'mailing_address_city': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1}},
#  'mailing_address_state': {'missing_data': {'row_noise_level': 0.01},
#   'incorrect_selection': {'row_noise_level': 0.01}},
#  'mailing_address_street_name': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1}},
#  'mailing_address_street_number': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'numeric_miswriting': {'row_noise_level': 0.01, 'token_noise_level': 0.1}},
#  'mailing_address_unit_number': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'numeric_miswriting': {'row_noise_level': 0.01, 'token_noise_level': 0.1}},
#  'mailing_address_po_box': {'missing_data': {'row_noise_level': 0.01,
#    'token_noise_level': 0.1},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'numeric_miswriting': {'row_noise_level': 0.01, 'token_noise_level': 0.1}},
#  'mailing_address_zipcode': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'zipcode_miswriting': {'row_noise_level': 0.01,
#    'first_two_digits_noise_level': 0.04,
#    'middle_digit_noise_level': 0.2,
#    'last_two_digits_noise_level': 0.36}},
#  'middle_initial': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1}},
#  'ssn': {'missing_data': {'row_noise_level': 0.01},
#   'typographic': {'row_noise_level': 0,
#    'token_noise_level': 0.1,
#    'include_original_token_level': 0.1},
#   'numeric_miswriting': {'row_noise_level': 0.01, 'token_noise_level': 0.1}},
#  'tax_form': {'missing_data': {'row_noise_level': 0.01},
#   'incorrect_selection': {'row_noise_level': 0.01}}}

# %%
# %%time
df_usa_w2_noisy_no_typos = pp.generate_taxes_w2_and_1099(
    usa_w2_path,
    configuration={'taxes_w2_and_1099': w2_config}
)
df_usa_w2_noisy_no_typos
# Out:
# CPU times: user 5min 27s, sys: 1min 50s, total: 7min 18s
# Wall time: 7min 17s
#          mailing_address_street_name   simulant_id  \
# 0                    northview dr ne        5670_0
# 1                    northview dr ne        5670_0
# 2                          tivoli ln        5670_2
# 3                          tivoli ln        5670_3
# 4                         oakview ln        5670_4
# ...                              ...           ...
# 22384735           old nat'l highway  5670_1391966
# 22384736                    n 4th st  5670_1391970
# 22384737             watervliet avnu  5670_1391971
# 22384738             watervliet avnu  5670_1391972
# 22384739                  main ave n  5670_1391973
#
#          mailing_address_unit_number mailing_address_zipcode  tax_year  \
# 0                                                       <NA>      2019
# 1                                                      17013      2019
# 2                                                      91601      2019
# 3                                                      91601      2019
# 4                                                      30005      2019
# ...                              ...                     ...       ...
# 22384735                                               27603      2040
# 22384736                                               33401      2040
# 22384737                                               60612      2040
# 22384738                                               60612      2040
# 22384739                                               26651      2040
#
#          mailing_address_street_number        date_of_birth  \
# 0                                  235  1953-01-19 00:00:00
# 1                                  235  1953-01-19 00:00:00
# 2                                  118  1979-01-30 00:00:00
# 3                                  118  1979-04-10 00:00:00
# 4                                       2001-01-21 00:00:00
# ...                                ...                  ...
# 22384735                          8011  2005-05-18 00:00:00
# 22384736                            49  1999-07-03 00:00:00
# 22384737                           105  2007-09-23 00:00:00
# 22384738                           105  2011-11-05 00:00:00
# 22384739                            51  1963-12-20 00:00:00
#
#            employer_street_name          ssn employer_id  ...  \
# 0                  edgecliff ct  863-79-9332      923417  ...
# 1                     n 52nd st  863-79-9332     1258181  ...
# 2                   skyview ter  801-14-2038     1631549  ...
# 3                       ince dr  801-14-2038     1358821  ...
# 4                stoney crk cir  509-76-7953           1  ...
# ...                         ...          ...         ...  ...
# 22384735                   <NA>  466-41-2227       27816  ...
# 22384736            s oriole av  476-71-8945     1350023  ...
# 22384737    n browns station dr  229-73-1457      372782  ...
# 22384738  southeast 22nd street  075-82-5964      432807  ...
# 22384739          9th street ne  062-30-4713      237182  ...
#
#          employer_street_number income employer_zipcode first_name age  \
# 0                                28043            93101    Phyllis  66
# 1                           309  12141            37013    Phyllis  66
# 2                          1960  13517            85308    Rebecca  40
# 3                             e  13952            85006    Richard  40
# 4                                  222            45459       Owen  18
# ...                         ...    ...              ...        ...  ..
# 22384735                   1507   2195            37909     Robert  35
# 22384736                   1116  12961            89506    Meaghan  41
# 22384737                    115  15346            33308    Anthony  33
# 22384738                   3388   1101            21755     Elijah  29
# 22384739                   4922  13057            11224      Terry  77
#
#          employer_state employer_unit_number mailing_address_city  \
# 0                    CA                                harrisburg
# 1                    TN                                harrisburg
# 2                    AZ             unit 170              visalia
# 3                    AZ                                   visalia
# 4                    OH                               johns creek
# ...                 ...                  ...                  ...
# 22384735             TN                               mooresville
# 22384736             NV                              lehigh acres
# 22384737             FL                             lawrenceville
# 22384738             MD                             lawrenceville
# 22384739             NY                                morgantown
#
#          mailing_address_state middle_initial
# 0                           PA              D
# 1                           PA              D
# 2                           CA              C
# 3                           CA              D
# 4                         <NA>              C
# ...                        ...            ...
# 22384735                    NC              K
# 22384736                    FL              C
# 22384737                    IL              J
# 22384738                    IL              E
# 22384739                    WV              K
#
# [22384740 rows x 25 columns]

# %% [markdown]
# # Look for missing values in original USA W2 data

# %%
# %%time
df_usa_w2.isna().sum()
# Out:
# CPU times: user 987 ms, sys: 336 ms, total: 1.32 s
# Wall time: 1.32 s
# mailing_address_street_name      0
# simulant_id                      0
# mailing_address_unit_number      0
# mailing_address_zipcode          0
# tax_year                         0
# mailing_address_street_number    0
# date_of_birth                    0
# employer_street_name             0
# ssn                              0
# employer_id                      0
# last_name                        0
# employer_city                    0
# mailing_address_po_box           0
# employer_name                    0
# tax_form                         0
# employer_street_number           0
# income                           0
# employer_zipcode                 0
# first_name                       0
# age                              0
# employer_state                   0
# employer_unit_number             0
# mailing_address_city             0
# mailing_address_state            0
# middle_initial                   0
# dtype: int64

# %%
# %%time
(df_usa_w2 == '').sum()
# Out:
# CPU times: user 1.22 s, sys: 127 ms, total: 1.35 s
# Wall time: 1.34 s
# mailing_address_street_name        715542
# simulant_id                             0
# mailing_address_unit_number      20930578
# mailing_address_zipcode                 0
# tax_year                                0
# mailing_address_street_number     1913238
# date_of_birth                           0
# employer_street_name                    0
# ssn                                     0
# employer_id                             0
# last_name                               0
# employer_city                           0
# mailing_address_po_box                  0
# employer_name                           0
# tax_form                                0
# employer_street_number            1357412
# income                                  0
# employer_zipcode                        0
# first_name                              0
# age                                     0
# employer_state                          0
# employer_unit_number             21157859
# mailing_address_city                    0
# mailing_address_state                   0
# middle_initial                          0
# dtype: int64

# %%
seed
# Out:
# 5670

# %%
# %%time
(df_usa_w2 != df_usa_w2_noisy).sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/arraylike.py:46, in OpsMixin.__ne__(self, other)
#      44 @unpack_zerodim_and_defer("__ne__")
#      45 def __ne__(self, other):
# ---> 46     return self._cmp_method(other, operator.ne)
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/frame.py:7571, in DataFrame._cmp_method(self, other, op)
#    7568 self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    7570 # See GH#4537 for discussion of scalar op behavior
# -> 7571 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7572 return self._construct_result(new_data)
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/frame.py:7622, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7616     # TODO: The previous assertion `assert right._indexed_same(self)`
#    7617     #  fails in cases with empty columns reached via
#    7618     #  _frame_arith_method_with_reindex
#    7619
#    7620     # TODO operate_blockwise expects a manager of the same type
#    7621     with np.errstate(all="ignore"):
# -> 7622         bm = self._mgr.operate_blockwise(
#    7623             # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    7624             # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7625             # "ArrayManager"
#    7626             # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    7627             # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7628             # "BlockManager"
#    7629             right._mgr,  # type: ignore[arg-type]
#    7630             array_op,
#    7631         )
#    7632     return self._constructor(bm)
#    7634 elif isinstance(right, Series) and axis == 1:
#    7635     # axis=1 means we want to operate row-by-row
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/internals/managers.py:1565, in BlockManager.operate_blockwise(self, other, array_op)
#    1561 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1562     """
#    1563     Apply array_op blockwise with another (aligned) BlockManager.
#    1564     """
# -> 1565     return operate_blockwise(self, other, array_op)
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/internals/ops.py:66, in operate_blockwise(left, right, array_op)
#      64 if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      65     res_values = res_values.reshape(1, -1)
# ---> 66 nbs = rblk._split_op_result(res_values)
#      68 # Assertions are disabled for performance, but should hold:
#      69 # if right_ea or left_ea:
#      70 #    assert len(nbs) == 1
#      71 # else:
#      72 #    assert res_values.shape == lvals.shape, (res_values.shape, lvals.shape)
#      74 _reset_block_mgr_locs(nbs, locs)
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/internals/blocks.py:379, in Block._split_op_result(self, result)
#     376 @final
#     377 def _split_op_result(self, result: ArrayLike) -> list[Block]:
#     378     # See also: split_and_operate
# --> 379     if result.ndim > 1 and isinstance(result.dtype, ExtensionDtype):
#     380         # TODO(EA2D): unnecessary with 2D EAs
#     381         # if we get a 2D ExtensionArray, we need to split it into 1D pieces
#     382         nbs = []
#     383         for i, loc in enumerate(self._mgr_locs):
#
# AttributeError: 'bool' object has no attribute 'ndim'

# %%
# %%time
df_usa_w2.employer_id == df_usa_w2_noisy.employer_id
# Out:
# CPU times: user 10.4 ms, sys: 8.57 ms, total: 18.9 ms
# Wall time: 18.2 ms
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 22384735    False
# 22384736    False
# 22384737    False
# 22384738    False
# 22384739    False
# Name: employer_id, Length: 22384740, dtype: bool

# %%
pd.concat([df_usa_w2.employer_id, df_usa_w2_noisy.employer_id], axis=1)
# Out:
#          employer_id employer_id
# 0             923417      923417
# 1            1258181     1258181
# 2            1631549     1631549
# 3            1358821     1358821
# 4                  1           1
# ...              ...         ...
# 22384735       27816       27816
# 22384736     1350023     1350023
# 22384737      372782      372782
# 22384738      432807      432807
# 22384739      237182      237182
#
# [22384740 rows x 2 columns]

# %%
df_usa_w2.dtypes
# Out:
# mailing_address_street_name            category
# simulant_id                            category
# mailing_address_unit_number            category
# mailing_address_zipcode                category
# tax_year                                  int64
# mailing_address_street_number          category
# date_of_birth                    datetime64[ns]
# employer_street_name                   category
# ssn                                    category
# employer_id                               int64
# last_name                              category
# employer_city                          category
# mailing_address_po_box                    int64
# employer_name                          category
# tax_form                               category
# employer_street_number                 category
# income                                    int64
# employer_zipcode                       category
# first_name                             category
# age                                       int64
# employer_state                         category
# employer_unit_number                   category
# mailing_address_city                   category
# mailing_address_state                  category
# middle_initial                         category
# dtype: object

# %%
df_usa_w2_noisy.dtypes
# Out:
# mailing_address_street_name        object
# simulant_id                      category
# mailing_address_unit_number        object
# mailing_address_zipcode            object
# tax_year                            int64
# mailing_address_street_number      object
# date_of_birth                      object
# employer_street_name               object
# ssn                                object
# employer_id                        object
# last_name                          object
# employer_city                      object
# mailing_address_po_box             object
# employer_name                      object
# tax_form                           object
# employer_street_number             object
# income                             object
# employer_zipcode                   object
# first_name                         object
# age                                object
# employer_state                     object
# employer_unit_number               object
# mailing_address_city               object
# mailing_address_state              object
# middle_initial                     object
# dtype: object

# %%
df_usa_w2.dtypes.loc[df_usa_w2.dtypes != 'category']
# Out:
# tax_year                           int64
# date_of_birth             datetime64[ns]
# employer_id                        int64
# mailing_address_po_box             int64
# income                             int64
# age                                int64
# dtype: object

# %%
# %%time
# %time df_usa_w2_noisy_cat = df_usa_w2_noisy.copy()
# %time datatypes.convert_dtypes(df_usa_w2_noisy_cat)
df_usa_w2_noisy_cat.dtypes
# Out:
# CPU times: user 27.1 s, sys: 14.8 s, total: 41.9 s
# Wall time: 41.8 s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed eval>:1
#
# File /mnt/share/code/ndbs/vivarium_research_prl/src/vivarium_research_prl/datatypes.py:137, in convert_dtypes(df, use_categorical)
#     135 for col in columns:
#     136     if col in df:
# --> 137         df[col] = df[col].astype(dtype)
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/internals/managers.py:445, in BaseBlockManager.astype(self, dtype, copy, errors)
#     444 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 445     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/internals/managers.py:347, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     345         applied = b.apply(f, **kwargs)
#     346     else:
# --> 347         applied = getattr(b, f)(**kwargs)
#     348 except (TypeError, NotImplementedError):
#     349     if not ignore_failures:
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# TypeError: float() argument must be a string or a number, not 'NAType'
# CPU times: user 3min 49s, sys: 1min 4s, total: 4min 54s
# Wall time: 4min 53s
# mailing_address_street_name      category
# simulant_id                        object
# mailing_address_unit_number      category
# mailing_address_zipcode          category
# tax_year                         category
# mailing_address_street_number    category
# date_of_birth                    category
# employer_street_name             category
# ssn                                object
# employer_id                        object
# last_name                        category
# employer_city                    category
# mailing_address_po_box           category
# employer_name                    category
# tax_form                         category
# employer_street_number           category
# income                             object
# employer_zipcode                 category
# first_name                       category
# age                                object
# employer_state                   category
# employer_unit_number             category
# mailing_address_city             category
# mailing_address_state            category
# middle_initial                   category
# dtype: object

# %%
df_usa_w2_noisy.loc[df_usa_w2_noisy.employer_name.isna(), 'employer_name']
# Out:
# 119         <NA>
# 159         <NA>
# 284         <NA>
# 322         <NA>
# 323         <NA>
#             ...
# 22383756    <NA>
# 22383849    <NA>
# 22383946    <NA>
# 22384041    <NA>
# 22384282    <NA>
# Name: employer_name, Length: 222917, dtype: object

# %%
df_usa_w2_noisy.employer_name.astype(str)
# Out:
# 0                                   Jam CLT Cell
# 1                          East End Times Square
# 2                               Dewdney Car care
# 3                   Hickory Station 55 South Bay
# 4                                       Military
#                             ...
# 22384735                 Fair City Vision Center
# 22384736                          Golden's Paint
# 22384737                  Tunxis Hill Counseling
# 22384738                             Robert E DC
# 22384739    Alan T And Care Clinic Cancer Center
# Name: employer_name, Length: 22384740, dtype: object

# %%
[(k, v.iloc[0]) for k,v in df_usa_w2.items()]
# Out:
# [('mailing_address_street_name', 'northview dr ne'),
#  ('simulant_id', '5670_0'),
#  ('mailing_address_unit_number', ''),
#  ('mailing_address_zipcode', '17013'),
#  ('tax_year', 2019),
#  ('mailing_address_street_number', '235'),
#  ('date_of_birth', Timestamp('1953-01-19 00:00:00')),
#  ('employer_street_name', 'edgecliff ct'),
#  ('ssn', '863-79-9332'),
#  ('employer_id', 923417),
#  ('last_name', 'Jones'),
#  ('employer_city', 'berkeley'),
#  ('mailing_address_po_box', 0),
#  ('employer_name', 'Jam CLT Cell'),
#  ('tax_form', 'W2'),
#  ('employer_street_number', ''),
#  ('income', 28043),
#  ('employer_zipcode', '93101'),
#  ('first_name', 'Phyllis'),
#  ('age', 66),
#  ('employer_state', 'CA'),
#  ('employer_unit_number', ''),
#  ('mailing_address_city', 'harrisburg'),
#  ('mailing_address_state', 'PA'),
#  ('middle_initial', 'D')]

# %%
# %%time
def convert_col_to_str_if_cat(colname, df):
    dtype = df.dtypes[colname]
    return df[colname].astype(str) if dtype == 'category' else df[colname]

# %time new_cols = [convert_col_to_str_if_cat(colname, df_usa_w2) for colname in df_usa_w2]
# %time df_usa_w2_str = pd.concat(new_cols, axis=1)
df_usa_w2_str.dtypes
# Out:
# CPU times: user 1min 21s, sys: 1min 12s, total: 2min 34s
# Wall time: 2min 33s
# CPU times: user 21.8 s, sys: 9.55 s, total: 31.4 s
# Wall time: 31.3 s
# CPU times: user 1min 43s, sys: 1min 22s, total: 3min 5s
# Wall time: 3min 5s
# mailing_address_street_name              object
# simulant_id                              object
# mailing_address_unit_number              object
# mailing_address_zipcode                  object
# tax_year                                  int64
# mailing_address_street_number            object
# date_of_birth                    datetime64[ns]
# employer_street_name                     object
# ssn                                      object
# employer_id                               int64
# last_name                                object
# employer_city                            object
# mailing_address_po_box                    int64
# employer_name                            object
# tax_form                                 object
# employer_street_number                   object
# income                                    int64
# employer_zipcode                         object
# first_name                               object
# age                                       int64
# employer_state                           object
# employer_unit_number                     object
# mailing_address_city                     object
# mailing_address_state                    object
# middle_initial                           object
# dtype: object

# %%
# %%time
(df_usa_w2_str != df_usa_w2_noisy).sum()
# Out:
# CPU times: user 1min 6s, sys: 12.1 s, total: 1min 18s
# Wall time: 1min 18s
# mailing_address_street_name        358541
# simulant_id                             0
# mailing_address_unit_number         35982
# mailing_address_zipcode            469564
# tax_year                                0
# mailing_address_street_number      471128
# date_of_birth                      665653
# employer_street_name               369739
# ssn                                494609
# employer_id                      22384740
# last_name                          553057
# employer_city                      352521
# mailing_address_po_box           22384740
# employer_name                      408523
# tax_form                           335557
# employer_street_number             482809
# income                           22384740
# employer_zipcode                   469398
# first_name                         547088
# age                              22384740
# employer_state                     442794
# employer_unit_number                30357
# mailing_address_city               351495
# mailing_address_state              442576
# middle_initial                     245760
# dtype: int64

# %%
df_usa_w2_noisy.income.astype(float) == df_usa_w2_str.income
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [86], line 1
# ----> 1 df_usa_w2_noisy.income.astype(float) == df_usa_w2_str.income
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/internals/managers.py:445, in BaseBlockManager.astype(self, dtype, copy, errors)
#     444 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 445     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/internals/managers.py:347, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     345         applied = b.apply(f, **kwargs)
#     346     else:
# --> 347         applied = getattr(b, f)(**kwargs)
#     348 except (TypeError, NotImplementedError):
#     349     if not ignore_failures:
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/miniconda3/envs/prlpy38/lib/python3.8/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# TypeError: float() argument must be a string or a number, not 'NAType'

# %%
# %%time
df_usa_w2_noisy.income.loc[df_usa_w2_noisy.income.notna()].str.isdigit().sum()
# Out:
# CPU times: user 20.5 s, sys: 917 ms, total: 21.4 s
# Wall time: 21.4 s
# 219063

# %%
# %%time
df_usa_w2_noisy.income.loc[df_usa_w2_noisy.income.notna()].str.isdigit().all()
# Out:
# CPU times: user 19.9 s, sys: 728 ms, total: 20.7 s
# Wall time: 20.7 s
# False

# %%
# %%time
df_usa_w2_str2 = df_usa_w2.astype(str)
df_usa_w2_str2.dtypes
# Out:
# CPU times: user 2min 7s, sys: 1min 16s, total: 3min 23s
# Wall time: 3min 23s
# mailing_address_street_name      object
# simulant_id                      object
# mailing_address_unit_number      object
# mailing_address_zipcode          object
# tax_year                         object
# mailing_address_street_number    object
# date_of_birth                    object
# employer_street_name             object
# ssn                              object
# employer_id                      object
# last_name                        object
# employer_city                    object
# mailing_address_po_box           object
# employer_name                    object
# tax_form                         object
# employer_street_number           object
# income                           object
# employer_zipcode                 object
# first_name                       object
# age                              object
# employer_state                   object
# employer_unit_number             object
# mailing_address_city             object
# mailing_address_state            object
# middle_initial                   object
# dtype: object

# %%
df_usa_w2_noisy.columns.to_list()
# Out:
# ['mailing_address_street_name',
#  'simulant_id',
#  'mailing_address_unit_number',
#  'mailing_address_zipcode',
#  'tax_year',
#  'mailing_address_street_number',
#  'date_of_birth',
#  'employer_street_name',
#  'ssn',
#  'employer_id',
#  'last_name',
#  'employer_city',
#  'mailing_address_po_box',
#  'employer_name',
#  'tax_form',
#  'employer_street_number',
#  'income',
#  'employer_zipcode',
#  'first_name',
#  'age',
#  'employer_state',
#  'employer_unit_number',
#  'mailing_address_city',
#  'mailing_address_state',
#  'middle_initial']

# %%
# %%time
new_cols = [df_usa_w2_noisy[colname] for colname in df_usa_w2_noisy]
for i, col in enumerate(new_cols):
    if col.name in ['simulant_id', 'tax_year']:
        new_cols[i] = col.astype(str)
df_usa_w2_noisy_str = pd.concat(new_cols, axis=1)
df_usa_w2_noisy_str.dtypes
# Out:
# CPU times: user 19.1 s, sys: 9.94 s, total: 29.1 s
# Wall time: 29 s
# mailing_address_street_name      object
# simulant_id                      object
# mailing_address_unit_number      object
# mailing_address_zipcode          object
# tax_year                         object
# mailing_address_street_number    object
# date_of_birth                    object
# employer_street_name             object
# ssn                              object
# employer_id                      object
# last_name                        object
# employer_city                    object
# mailing_address_po_box           object
# employer_name                    object
# tax_form                         object
# employer_street_number           object
# income                           object
# employer_zipcode                 object
# first_name                       object
# age                              object
# employer_state                   object
# employer_unit_number             object
# mailing_address_city             object
# mailing_address_state            object
# middle_initial                   object
# dtype: object

# %%
def percent_different_in_columns(df1, df2):
    return 100 * (df1 != df2).sum() / len(df1)

def percent_of_rows_with_difference(df1, df2):
    return 100 * (df1 != df2).any(axis=1).sum() / len(df1)

# %%
def compare_columns(df1, df2, colname, notna=False):
    if notna:
        notna = df1[colname].notna() & df2[colname].notna()
        return df1[colname].loc[notna].compare(df2[colname].loc[notna])
    else:
        return df1[colname].compare(df2[colname])

# %%
# %%time
percent_different_in_columns(df_usa_w2_noisy_str, df_usa_w2_str2)
# Out:
# CPU times: user 46.6 s, sys: 9.64 s, total: 56.2 s
# Wall time: 56.1 s
# mailing_address_street_name        1.601721
# simulant_id                        0.000000
# mailing_address_unit_number        0.160743
# mailing_address_zipcode            2.097697
# tax_year                           0.000000
# mailing_address_street_number      2.104684
# date_of_birth                    100.000000
# employer_street_name               1.651746
# ssn                                2.209581
# employer_id                       99.294430
# last_name                          2.470688
# employer_city                      1.574827
# mailing_address_po_box            99.117023
# employer_name                      1.825007
# tax_form                           1.499044
# employer_street_number             2.156867
# income                            99.408856
# employer_zipcode                   2.096955
# first_name                         2.444022
# age                               99.208702
# employer_state                     1.978107
# employer_unit_number               0.135615
# mailing_address_city               1.570244
# mailing_address_state              1.977133
# middle_initial                     1.097891
# dtype: float64

# %% [markdown]
# # For some reason, dates are formatted differently in the noised and unnoised versions

# %%
df_usa_w2_str2.date_of_birth.compare(df_usa_w2_noisy_str.date_of_birth)
# Out:
#                 self                other
# 0         1953-01-19  1953-01-19 00:00:00
# 1         1953-01-19  1953-01-19 00:00:00
# 2         1979-01-30  1979-01-30 00:00:00
# 3         1979-04-10  1979-04-10 00:00:00
# 4         2001-01-21  2001-01-21 00:00:00
# ...              ...                  ...
# 22384735  2005-05-18  2005-05-18 00:00:00
# 22384736  1999-07-03  1999-07-03 00:00:00
# 22384737  2007-09-23  2007-09-23 00:00:00
# 22384738  2011-11-05  2011-11-05 00:00:00
# 22384739  1963-12-20  1963-12-20 00:00:00
#
# [22384740 rows x 2 columns]

# %%
df_usa_w2_noisy.date_of_birth
# Out:
# 0           1953-01-19 00:00:00
# 1           1953-01-19 00:00:00
# 2           1979-01-30 00:00:00
# 3           1979-04-10 00:00:00
# 4           2001-01-21 00:00:00
#                    ...
# 22384735    2005-05-18 00:00:00
# 22384736    1999-07-03 00:00:00
# 22384737    2007-09-23 00:00:00
# 22384738    2011-11-05 00:00:00
# 22384739    1963-12-20 00:00:00
# Name: date_of_birth, Length: 22384740, dtype: object

# %%
df_usa_w2_noisy.date_of_birth[0]
# Out:
# Timestamp('1953-01-19 00:00:00')

# %%
df_usa_w2.date_of_birth
# Out:
# 0          1953-01-19
# 1          1953-01-19
# 2          1979-01-30
# 3          1979-04-10
# 4          2001-01-21
#               ...
# 22384735   2005-05-18
# 22384736   1999-07-03
# 22384737   2007-09-23
# 22384738   2011-11-05
# 22384739   1963-12-20
# Name: date_of_birth, Length: 22384740, dtype: datetime64[ns]

# %%
df_usa_w2.date_of_birth[0]
# Out:
# Timestamp('1953-01-19 00:00:00')

# %%
compare_columns(df_usa_w2_str2, df_usa_w2_noisy_str, 'income', notna=False)
# Out:
#            self  other
# 0         28043  28043
# 1         12141  12141
# 2         13517  13517
# 3         13952  13952
# 4           222    222
# ...         ...    ...
# 22384735   2195   2195
# 22384736  12961  12961
# 22384737  15346  15346
# 22384738   1101   1101
# 22384739  13057  13057
#
# [22252414 rows x 2 columns]

# %%
compare_columns(df_usa_w2_str2, df_usa_w2_noisy_str, 'income', notna=False).loc[0]
# Out:
# self     28043
# other    28043
# Name: 0, dtype: object

# %%
df_usa_w2_str2.loc[0, 'income']
# Out:
# '28043'

# %%
df_usa_w2_noisy_str.loc[0, 'income']
# Out:
# 28043

# %%
same = df_usa_w2_str2.income == df_usa_w2_noisy_str.income
df_usa_w2_str2.loc[same, 'income']
# Out:
# 364         428731
# 387          30712
# 406          20692
# 466         133355
# 575          49253
#              ...
# 22383594     16463
# 22384130      5383
# 22384188     11129
# 22384588      3551
# 22384706     19027
# Name: income, Length: 132326, dtype: object

# %%
df_usa_w2_str2.loc[364, 'income']
# Out:
# '428731'

# %%
df_usa_w2_noisy_str.loc[364, 'income']
# Out:
# '428731'

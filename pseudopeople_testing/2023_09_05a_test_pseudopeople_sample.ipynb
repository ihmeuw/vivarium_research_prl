# %%
import pseudopeople as psp
import pandas as pd, numpy as np

from vivarium_research_prl.utils import sizemb, MappingViaAttributes, build_full_address
from vivarium_research_prl import alpha

# !date
# !whoami
# !uname -a
# !python --version
# !pwd
# Out:
# Tue 05 Sep 2023 02:23:00 PM PDT
# ndbs
# Linux long-slurm-sarchive-p0005 5.4.0-135-generic #152-Ubuntu SMP Wed Nov 23 20:19:22 UTC 2022 x86_64 x86_64 x86_64 GNU/Linux
# Python 3.10.12
# /mnt/share/code/ndbs/vivarium_research_prl/pseudopeople_testing

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Generate all sample datasets and list columns in each

# %%
# %%time
data = alpha.generate_datasets()
data.keylist()
# Out:
# CPU times: user 14.7 s, sys: 211 ms, total: 14.9 s
# Wall time: 15.1 s
# ['american_community_survey',
#  'current_population_survey',
#  'decennial_census',
#  'social_security',
#  'taxes_1040',
#  'taxes_w2_and_1099',
#  'women_infants_and_children']

# %%
{name: df.dtypes for name, df in data.items()}
# Out:
# {'american_community_survey': simulant_id                                 object
#  household_id                                object
#  survey_date                         datetime64[ns]
#  first_name                                  object
#  middle_initial                              object
#  last_name                                   object
#  age                                         object
#  date_of_birth                               object
#  street_number                               object
#  street_name                                 object
#  unit_number                                 object
#  city                                        object
#  state                                     category
#  zipcode                                     object
#  housing_type                                object
#  relationship_to_reference_person          category
#  sex                                       category
#  race_ethnicity                            category
#  dtype: object,
#  'current_population_survey': simulant_id               object
#  household_id              object
#  survey_date       datetime64[ns]
#  first_name                object
#  middle_initial            object
#  last_name                 object
#  age                       object
#  date_of_birth             object
#  street_number             object
#  street_name               object
#  unit_number               object
#  city                      object
#  state                   category
#  zipcode                   object
#  sex                     category
#  race_ethnicity          category
#  dtype: object,
#  'decennial_census': simulant_id                           object
#  household_id                          object
#  first_name                            object
#  middle_initial                        object
#  last_name                             object
#  age                                   object
#  date_of_birth                         object
#  street_number                         object
#  street_name                           object
#  unit_number                           object
#  city                                  object
#  state                               category
#  zipcode                               object
#  housing_type                          object
#  relationship_to_reference_person    category
#  sex                                 category
#  race_ethnicity                      category
#  year                                  object
#  dtype: object,
#  'social_security': simulant_id        object
#  ssn                object
#  first_name         object
#  middle_name        object
#  last_name          object
#  date_of_birth      object
#  sex              category
#  event_type       category
#  event_date         object
#  dtype: object,
#  'taxes_1040': simulant_id                        object
#  household_id                       object
#  first_name                         object
#  middle_initial                     object
#  last_name                          object
#  ssn                                object
#  mailing_address_street_number      object
#  mailing_address_street_name        object
#  mailing_address_unit_number        object
#  mailing_address_po_box             object
#  mailing_address_city               object
#  mailing_address_state            category
#  mailing_address_zipcode            object
#  spouse_first_name                  object
#  spouse_middle_initial              object
#  spouse_last_name                   object
#  spouse_ssn                         object
#  dependent_1_first_name             object
#  dependent_1_last_name              object
#  dependent_1_ssn                    object
#  dependent_2_first_name             object
#  dependent_2_last_name              object
#  dependent_2_ssn                    object
#  dependent_3_first_name             object
#  dependent_3_last_name              object
#  dependent_3_ssn                    object
#  dependent_4_first_name             object
#  dependent_4_last_name              object
#  dependent_4_ssn                    object
#  tax_year                           object
#  dtype: object,
#  'taxes_w2_and_1099': simulant_id                        object
#  household_id                       object
#  employer_id                        object
#  ssn                                object
#  wages                              object
#  employer_name                      object
#  employer_street_number             object
#  employer_street_name               object
#  employer_unit_number               object
#  employer_city                      object
#  employer_state                   category
#  employer_zipcode                   object
#  first_name                         object
#  middle_initial                     object
#  last_name                          object
#  mailing_address_street_number      object
#  mailing_address_street_name        object
#  mailing_address_unit_number        object
#  mailing_address_po_box             object
#  mailing_address_city               object
#  mailing_address_state            category
#  mailing_address_zipcode            object
#  tax_form                         category
#  tax_year                           object
#  dtype: object,
#  'women_infants_and_children': simulant_id         object
#  household_id        object
#  first_name          object
#  middle_initial      object
#  last_name           object
#  date_of_birth       object
#  street_number       object
#  street_name         object
#  unit_number         object
#  city                object
#  state             category
#  zipcode             object
#  sex               category
#  race_ethnicity    category
#  year                object
#  dtype: object}

# %% [markdown]
# # Check whether pseudopeople errors are now `Exception`s instead of `BaseException`s
#
# Yes. Good.

# %%
issubclass(psp.exceptions.DataSourceError, Exception)
# Out:
# True

# %% [markdown]
# # Get a default configuration

# %%
config = psp.get_config()
config.keys()
# Out:
# dict_keys(['decennial_census', 'american_community_survey', 'current_population_survey', 'women_infants_and_children', 'social_security', 'taxes_w2_and_1099', 'taxes_1040'])

# %%
config['taxes_w2_and_1099']
# Out:
# {'row_noise': {'omit_row': {'row_probability': 0.005}},
#  'column_noise': {'ssn': {'leave_blank': {'cell_probability': 0.01},
#    'copy_from_household_member': {'cell_probability': 0.0},
#    'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'wages': {'leave_blank': {'cell_probability': 0.01},
#    'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'employer_name': {'leave_blank': {'cell_probability': 0.01},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'employer_street_number': {'leave_blank': {'cell_probability': 0.01},
#    'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'employer_street_name': {'leave_blank': {'cell_probability': 0.01},
#    'make_phonetic_errors': {'cell_probability': 0.01,
#     'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'employer_unit_number': {'leave_blank': {'cell_probability': 0.01},
#    'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'employer_city': {'leave_blank': {'cell_probability': 0.01},
#    'make_phonetic_errors': {'cell_probability': 0.01,
#     'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'employer_state': {'leave_blank': {'cell_probability': 0.01},
#    'choose_wrong_option': {'cell_probability': 0.01}},
#   'employer_zipcode': {'leave_blank': {'cell_probability': 0.01},
#    'write_wrong_zipcode_digits': {'cell_probability': 0.01,
#     'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'first_name': {'leave_blank': {'cell_probability': 0.01},
#    'use_nickname': {'cell_probability': 0.01},
#    'use_fake_name': {'cell_probability': 0.01},
#    'make_phonetic_errors': {'cell_probability': 0.01,
#     'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'middle_initial': {'leave_blank': {'cell_probability': 0.01},
#    'make_phonetic_errors': {'cell_probability': 0.01,
#     'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'last_name': {'leave_blank': {'cell_probability': 0.01},
#    'use_fake_name': {'cell_probability': 0.01},
#    'make_phonetic_errors': {'cell_probability': 0.01,
#     'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'mailing_address_street_number': {'leave_blank': {'cell_probability': 0.01},
#    'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'mailing_address_street_name': {'leave_blank': {'cell_probability': 0.01},
#    'make_phonetic_errors': {'cell_probability': 0.01,
#     'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'mailing_address_unit_number': {'leave_blank': {'cell_probability': 0.01},
#    'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'mailing_address_po_box': {'leave_blank': {'cell_probability': 0.01},
#    'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'mailing_address_city': {'leave_blank': {'cell_probability': 0.01},
#    'make_phonetic_errors': {'cell_probability': 0.01,
#     'token_probability': 0.1},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'mailing_address_state': {'leave_blank': {'cell_probability': 0.01},
#    'choose_wrong_option': {'cell_probability': 0.01}},
#   'mailing_address_zipcode': {'leave_blank': {'cell_probability': 0.01},
#    'write_wrong_zipcode_digits': {'cell_probability': 0.01,
#     'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#    'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#    'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#   'tax_form': {'leave_blank': {'cell_probability': 0.01},
#    'choose_wrong_option': {'cell_probability': 0.01}}}}

# %% [markdown]
# # Write a function to flatten the config dictionary

# %%
# def find(key, d):
#     instances = []
#     def _find(key, d):
#         if d == key:

# %%
def f():
    x = 4
    def g():
        nonlocal x
        print(x)
        if x >= 6:
            return
        x += 1
        g()
    g()

f()
# Out:
# 4
# 5
# 6

# %%
def keys_to_tuples(d):
    """Flattens a nested dictionary into single dictionary with tuples for keys."""
    new_dict = {}
    current_tuple = []
    def _keys_to_tuples(dict_or_val):
        if not isinstance(dict_or_val, dict):
            new_dict[tuple(current_tuple)] = dict_or_val
            return

        for key, val in dict_or_val.items():
            current_tuple.append(key)
            _keys_to_tuples(val)
            current_tuple.pop()

    _keys_to_tuples(d)
    return new_dict

# %%
flattened = keys_to_tuples(config['taxes_w2_and_1099'])
len(flattened)
# Out:
# 128

# %%
set(len(k) for k in flattened)
# Out:
# {3, 4}

# %%
[k for k in flattened]
# Out:
# [('row_noise', 'omit_row', 'row_probability'),
#  ('column_noise', 'ssn', 'leave_blank', 'cell_probability'),
#  ('column_noise', 'ssn', 'copy_from_household_member', 'cell_probability'),
#  ('column_noise', 'ssn', 'write_wrong_digits', 'cell_probability'),
#  ('column_noise', 'ssn', 'write_wrong_digits', 'token_probability'),
#  ('column_noise', 'ssn', 'make_ocr_errors', 'cell_probability'),
#  ('column_noise', 'ssn', 'make_ocr_errors', 'token_probability'),
#  ('column_noise', 'ssn', 'make_typos', 'cell_probability'),
#  ('column_noise', 'ssn', 'make_typos', 'token_probability'),
#  ('column_noise', 'wages', 'leave_blank', 'cell_probability'),
#  ('column_noise', 'wages', 'write_wrong_digits', 'cell_probability'),
#  ('column_noise', 'wages', 'write_wrong_digits', 'token_probability'),
#  ('column_noise', 'wages', 'make_ocr_errors', 'cell_probability'),
#  ('column_noise', 'wages', 'make_ocr_errors', 'token_probability'),
#  ('column_noise', 'wages', 'make_typos', 'cell_probability'),
#  ('column_noise', 'wages', 'make_typos', 'token_probability'),
#  ('column_noise', 'employer_name', 'leave_blank', 'cell_probability'),
#  ('column_noise', 'employer_name', 'make_ocr_errors', 'cell_probability'),
#  ('column_noise', 'employer_name', 'make_ocr_errors', 'token_probability'),
#  ('column_noise', 'employer_name', 'make_typos', 'cell_probability'),
#  ('column_noise', 'employer_name', 'make_typos', 'token_probability'),
#  ('column_noise', 'employer_street_number', 'leave_blank', 'cell_probability'),
#  ('column_noise',
#   'employer_street_number',
#   'write_wrong_digits',
#   'cell_probability'),
#  ('column_noise',
#   'employer_street_number',
#   'write_wrong_digits',
#   'token_probability'),
#  ('column_noise',
#   'employer_street_number',
#   'make_ocr_errors',
#   'cell_probability'),
#  ('column_noise',
#   'employer_street_number',
#   'make_ocr_errors',
#   'token_probability'),
#  ('column_noise', 'employer_street_number', 'make_typos', 'cell_probability'),
#  ('column_noise', 'employer_street_number', 'make_typos', 'token_probability'),
#  ('column_noise', 'employer_street_name', 'leave_blank', 'cell_probability'),
#  ('column_noise',
#   'employer_street_name',
#   'make_phonetic_errors',
#   'cell_probability'),
#  ('column_noise',
#   'employer_street_name',
#   'make_phonetic_errors',
#   'token_probability'),
#  ('column_noise',
#   'employer_street_name',
#   'make_ocr_errors',
#   'cell_probability'),
#  ('column_noise',
#   'employer_street_name',
#   'make_ocr_errors',
#   'token_probability'),
#  ('column_noise', 'employer_street_name', 'make_typos', 'cell_probability'),
#  ('column_noise', 'employer_street_name', 'make_typos', 'token_probability'),
#  ('column_noise', 'employer_unit_number', 'leave_blank', 'cell_probability'),
#  ('column_noise',
#   'employer_unit_number',
#   'write_wrong_digits',
#   'cell_probability'),
#  ('column_noise',
#   'employer_unit_number',
#   'write_wrong_digits',
#   'token_probability'),
#  ('column_noise',
#   'employer_unit_number',
#   'make_ocr_errors',
#   'cell_probability'),
#  ('column_noise',
#   'employer_unit_number',
#   'make_ocr_errors',
#   'token_probability'),
#  ('column_noise', 'employer_unit_number', 'make_typos', 'cell_probability'),
#  ('column_noise', 'employer_unit_number', 'make_typos', 'token_probability'),
#  ('column_noise', 'employer_city', 'leave_blank', 'cell_probability'),
#  ('column_noise', 'employer_city', 'make_phonetic_errors', 'cell_probability'),
#  ('column_noise',
#   'employer_city',
#   'make_phonetic_errors',
#   'token_probability'),
#  ('column_noise', 'employer_city', 'make_ocr_errors', 'cell_probability'),
#  ('column_noise', 'employer_city', 'make_ocr_errors', 'token_probability'),
#  ('column_noise', 'employer_city', 'make_typos', 'cell_probability'),
#  ('column_noise', 'employer_city', 'make_typos', 'token_probability'),
#  ('column_noise', 'employer_state', 'leave_blank', 'cell_probability'),
#  ('column_noise', 'employer_state', 'choose_wrong_option', 'cell_probability'),
#  ('column_noise', 'employer_zipcode', 'leave_blank', 'cell_probability'),
#  ('column_noise',
#   'employer_zipcode',
#   'write_wrong_zipcode_digits',
#   'cell_probability'),
#  ('column_noise',
#   'employer_zipcode',
#   'write_wrong_zipcode_digits',
#   'digit_probabilities'),
#  ('column_noise', 'employer_zipcode', 'make_ocr_errors', 'cell_probability'),
#  ('column_noise', 'employer_zipcode', 'make_ocr_errors', 'token_probability'),
#  ('column_noise', 'employer_zipcode', 'make_typos', 'cell_probability'),
#  ('column_noise', 'employer_zipcode', 'make_typos', 'token_probability'),
#  ('column_noise', 'first_name', 'leave_blank', 'cell_probability'),
#  ('column_noise', 'first_name', 'use_nickname', 'cell_probability'),
#  ('column_noise', 'first_name', 'use_fake_name', 'cell_probability'),
#  ('column_noise', 'first_name', 'make_phonetic_errors', 'cell_probability'),
#  ('column_noise', 'first_name', 'make_phonetic_errors', 'token_probability'),
#  ('column_noise', 'first_name', 'make_ocr_errors', 'cell_probability'),
#  ('column_noise', 'first_name', 'make_ocr_errors', 'token_probability'),
#  ('column_noise', 'first_name', 'make_typos', 'cell_probability'),
#  ('column_noise', 'first_name', 'make_typos', 'token_probability'),
#  ('column_noise', 'middle_initial', 'leave_blank', 'cell_probability'),
#  ('column_noise',
#   'middle_initial',
#   'make_phonetic_errors',
#   'cell_probability'),
#  ('column_noise',
#   'middle_initial',
#   'make_phonetic_errors',
#   'token_probability'),
#  ('column_noise', 'middle_initial', 'make_ocr_errors', 'cell_probability'),
#  ('column_noise', 'middle_initial', 'make_ocr_errors', 'token_probability'),
#  ('column_noise', 'middle_initial', 'make_typos', 'cell_probability'),
#  ('column_noise', 'middle_initial', 'make_typos', 'token_probability'),
#  ('column_noise', 'last_name', 'leave_blank', 'cell_probability'),
#  ('column_noise', 'last_name', 'use_fake_name', 'cell_probability'),
#  ('column_noise', 'last_name', 'make_phonetic_errors', 'cell_probability'),
#  ('column_noise', 'last_name', 'make_phonetic_errors', 'token_probability'),
#  ('column_noise', 'last_name', 'make_ocr_errors', 'cell_probability'),
#  ('column_noise', 'last_name', 'make_ocr_errors', 'token_probability'),
#  ('column_noise', 'last_name', 'make_typos', 'cell_probability'),
#  ('column_noise', 'last_name', 'make_typos', 'token_probability'),
#  ('column_noise',
#   'mailing_address_street_number',
#   'leave_blank',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_street_number',
#   'write_wrong_digits',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_street_number',
#   'write_wrong_digits',
#   'token_probability'),
#  ('column_noise',
#   'mailing_address_street_number',
#   'make_ocr_errors',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_street_number',
#   'make_ocr_errors',
#   'token_probability'),
#  ('column_noise',
#   'mailing_address_street_number',
#   'make_typos',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_street_number',
#   'make_typos',
#   'token_probability'),
#  ('column_noise',
#   'mailing_address_street_name',
#   'leave_blank',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_street_name',
#   'make_phonetic_errors',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_street_name',
#   'make_phonetic_errors',
#   'token_probability'),
#  ('column_noise',
#   'mailing_address_street_name',
#   'make_ocr_errors',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_street_name',
#   'make_ocr_errors',
#   'token_probability'),
#  ('column_noise',
#   'mailing_address_street_name',
#   'make_typos',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_street_name',
#   'make_typos',
#   'token_probability'),
#  ('column_noise',
#   'mailing_address_unit_number',
#   'leave_blank',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_unit_number',
#   'write_wrong_digits',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_unit_number',
#   'write_wrong_digits',
#   'token_probability'),
#  ('column_noise',
#   'mailing_address_unit_number',
#   'make_ocr_errors',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_unit_number',
#   'make_ocr_errors',
#   'token_probability'),
#  ('column_noise',
#   'mailing_address_unit_number',
#   'make_typos',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_unit_number',
#   'make_typos',
#   'token_probability'),
#  ('column_noise', 'mailing_address_po_box', 'leave_blank', 'cell_probability'),
#  ('column_noise',
#   'mailing_address_po_box',
#   'write_wrong_digits',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_po_box',
#   'write_wrong_digits',
#   'token_probability'),
#  ('column_noise',
#   'mailing_address_po_box',
#   'make_ocr_errors',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_po_box',
#   'make_ocr_errors',
#   'token_probability'),
#  ('column_noise', 'mailing_address_po_box', 'make_typos', 'cell_probability'),
#  ('column_noise', 'mailing_address_po_box', 'make_typos', 'token_probability'),
#  ('column_noise', 'mailing_address_city', 'leave_blank', 'cell_probability'),
#  ('column_noise',
#   'mailing_address_city',
#   'make_phonetic_errors',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_city',
#   'make_phonetic_errors',
#   'token_probability'),
#  ('column_noise',
#   'mailing_address_city',
#   'make_ocr_errors',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_city',
#   'make_ocr_errors',
#   'token_probability'),
#  ('column_noise', 'mailing_address_city', 'make_typos', 'cell_probability'),
#  ('column_noise', 'mailing_address_city', 'make_typos', 'token_probability'),
#  ('column_noise', 'mailing_address_state', 'leave_blank', 'cell_probability'),
#  ('column_noise',
#   'mailing_address_state',
#   'choose_wrong_option',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_zipcode',
#   'leave_blank',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_zipcode',
#   'write_wrong_zipcode_digits',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_zipcode',
#   'write_wrong_zipcode_digits',
#   'digit_probabilities'),
#  ('column_noise',
#   'mailing_address_zipcode',
#   'make_ocr_errors',
#   'cell_probability'),
#  ('column_noise',
#   'mailing_address_zipcode',
#   'make_ocr_errors',
#   'token_probability'),
#  ('column_noise', 'mailing_address_zipcode', 'make_typos', 'cell_probability'),
#  ('column_noise',
#   'mailing_address_zipcode',
#   'make_typos',
#   'token_probability'),
#  ('column_noise', 'tax_form', 'leave_blank', 'cell_probability'),
#  ('column_noise', 'tax_form', 'choose_wrong_option', 'cell_probability')]

# %% [markdown]
# # Convert the flattened config into a Series with a MultiIndex

# %%
s = pd.Series(flattened)
s
# Out:
# row_noise     omit_row                 row_probability               0.005
# column_noise  ssn                      leave_blank                    0.01
#                                        copy_from_household_member      0.0
#                                        write_wrong_digits             0.01
#                                        write_wrong_digits              0.1
#                                                                      ...
#               mailing_address_zipcode  make_ocr_errors                 0.1
#                                        make_typos                     0.01
#                                        make_typos                      0.1
#               tax_form                 leave_blank                    0.01
#                                        choose_wrong_option            0.01
# Length: 128, dtype: object

# %%
s.index.nlevels
# Out:
# 3

# %%
cdict = {t: val for t, val in flattened.items() if 'column_noise' in t}
len(cdict)
# Out:
# 127

# %%
cs = pd.Series(cdict)
cs
# Out:
# column_noise  ssn                      leave_blank                 cell_probability     0.01
#                                        copy_from_household_member  cell_probability      0.0
#                                        write_wrong_digits          cell_probability     0.01
#                                                                    token_probability     0.1
#                                        make_ocr_errors             cell_probability     0.01
#                                                                                         ...
#               mailing_address_zipcode  make_ocr_errors             token_probability     0.1
#                                        make_typos                  cell_probability     0.01
#                                                                    token_probability     0.1
#               tax_form                 leave_blank                 cell_probability     0.01
#                                        choose_wrong_option         cell_probability     0.01
# Length: 127, dtype: object

# %%
cs.filter(like='household')
# Out:
# column_noise  ssn  copy_from_household_member  cell_probability    0.0
# dtype: object

# %% [markdown]
# # Find all the places with copy-from-household-member noise
#
# First I'll need to deal with the fact that we have keys of differng lengths, since converting the entire dict to a Series will truncate keys to the shortest length.

# %%
flat_config = keys_to_tuples(config)
len(flat_config)
# Out:
# 735

# %%
set(len(k) for k in flat_config)
# Out:
# {4, 5, 6}

# %%
key_series = pd.Series(flat_config.keys())
key_series.map(len).value_counts()
# Out:
# 5    716
# 6     12
# 4      7
# dtype: int64

# %% [markdown]
# ## Which keys have length 6?
#
# Hmm, `misreport_age`, because my function also flattened the `possible_age_differences` dictionary. I don't see an easy way to avoid that when using recursion. The only foolproof way I see to avoid this is to explicitly specify the levels we're flattening in nested for loops.

# %%
{k:v for k,v in flat_config.items() if len(k) == 6}
# Out:
# {('decennial_census',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   -2): 0.1,
#  ('decennial_census',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   -1): 0.4,
#  ('decennial_census',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   1): 0.4,
#  ('decennial_census',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   2): 0.1,
#  ('american_community_survey',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   -2): 0.1,
#  ('american_community_survey',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   -1): 0.4,
#  ('american_community_survey',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   1): 0.4,
#  ('american_community_survey',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   2): 0.1,
#  ('current_population_survey',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   -2): 0.1,
#  ('current_population_survey',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   -1): 0.4,
#  ('current_population_survey',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   1): 0.4,
#  ('current_population_survey',
#   'column_noise',
#   'age',
#   'misreport_age',
#   'possible_age_differences',
#   2): 0.1}

# %%
config['decennial_census']['column_noise']['age']['misreport_age']
# Out:
# {'cell_probability': 0.01,
#  'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}}

# %% [markdown]
# ## Which keys have length 4?
#
# Good, it looks like it's precisely the `row_noise` keys.

# %%
{k:v for k,v in flat_config.items() if len(k) == 4}
# Out:
# {('decennial_census',
#   'row_noise',
#   'do_not_respond',
#   'row_probability'): 0.0145,
#  ('american_community_survey',
#   'row_noise',
#   'do_not_respond',
#   'row_probability'): 0.0145,
#  ('current_population_survey',
#   'row_noise',
#   'do_not_respond',
#   'row_probability'): 0.2905,
#  ('women_infants_and_children',
#   'row_noise',
#   'omit_row',
#   'row_probability'): 0.0,
#  ('social_security', 'row_noise', 'omit_row', 'row_probability'): 0.0,
#  ('taxes_w2_and_1099', 'row_noise', 'omit_row', 'row_probability'): 0.005,
#  ('taxes_1040', 'row_noise', 'omit_row', 'row_probability'): 0.0}

# %% [markdown]
# # Filter to keys of length 5, and find instances of copy-from-household-member noise

# %%
config_depth_5 = {k:v for k,v in flat_config.items() if len(k) == 5}
col_config = pd.Series(config_depth_5)
col_config
# Out:
# decennial_census  column_noise  first_name       leave_blank           cell_probability     0.01
#                                                  use_nickname          cell_probability     0.01
#                                                  use_fake_name         cell_probability     0.01
#                                                  make_phonetic_errors  cell_probability     0.01
#                                                                        token_probability     0.1
#                                                                                             ...
# taxes_1040        column_noise  dependent_4_ssn  write_wrong_digits    token_probability     0.1
#                                                  make_ocr_errors       cell_probability     0.01
#                                                                        token_probability     0.1
#                                                  make_typos            cell_probability     0.01
#                                                                        token_probability     0.1
# Length: 716, dtype: object

# %%
col_config.index.nlevels
# Out:
# 5

# %%
col_config.filter(like='household')
# Out:
# decennial_census            column_noise  age              copy_from_household_member  cell_probability    0.01
#                                           date_of_birth    copy_from_household_member  cell_probability    0.01
# american_community_survey   column_noise  age              copy_from_household_member  cell_probability    0.01
#                                           date_of_birth    copy_from_household_member  cell_probability    0.01
# current_population_survey   column_noise  age              copy_from_household_member  cell_probability    0.01
#                                           date_of_birth    copy_from_household_member  cell_probability    0.01
# women_infants_and_children  column_noise  date_of_birth    copy_from_household_member  cell_probability    0.01
# social_security             column_noise  ssn              copy_from_household_member  cell_probability     0.0
#                                           date_of_birth    copy_from_household_member  cell_probability    0.01
# taxes_w2_and_1099           column_noise  ssn              copy_from_household_member  cell_probability     0.0
# taxes_1040                  column_noise  ssn              copy_from_household_member  cell_probability    0.01
#                                           spouse_ssn       copy_from_household_member  cell_probability    0.01
#                                           dependent_1_ssn  copy_from_household_member  cell_probability    0.01
#                                           dependent_2_ssn  copy_from_household_member  cell_probability    0.01
#                                           dependent_3_ssn  copy_from_household_member  cell_probability    0.01
#                                           dependent_4_ssn  copy_from_household_member  cell_probability    0.01
# dtype: object

# %% [markdown]
# # See what happens when we request a large probability of copy_from_household_member noise
#
# It silently noises a smaller fraction, because we haven't implemented the user warning for when the requested fraction is not possible.

# %%
override_copy_noise = {'social_security': {'column_noise': {'ssn' : {'copy_from_household_member': {'cell_probability':0.95}}}}}
ssa_noisy = psp.generate_social_security(config=override_copy_noise)
ssa_noisy
# Out:
#       simulant_id          ssn first_name middle_name   last_name  \
# 0         0_19979  786-77-6454     Evelyn       Nancy       Hines
# 1          0_6846  688-88-6377     George      Robert     Dickens
# 2         0_19983  651-33-9561   Beatrice      Jennie     Fackler
# 3           0_262  448-43-1664       Eura      Nadine      Crusen
# 4         0_12473  875-10-2359    Roberta        Ruth  Muilenburg
# ...           ...          ...        ...         ...         ...
# 16492     0_20687  183-90-0619    Matthew     Michael    Phillips
# 16493     0_20686  803-81-8527     Jermey       Tyler      Wimmer
# 16494     0_20692  446-63-2138  Brittanie      Lauren        Thao
# 16495     0_20662  702-65-5925     Marcus      Jasper      Murphy
# 16496     0_20673  857-83-6064     Analia     Brielle      Kynard
#
#       date_of_birth     sex event_type event_date
# 0          19191204  Female   creation   19191204
# 1          19211606    Male   creation   19210616
# 2          19220113  Female   creation   19220113
# 3          19220305  Female   creation   19220305
# 4          19420306  Female   creation   19220306
# ...             ...     ...        ...        ...
# 16492      19800224    Male   creation   20201229
# 16493      19860415    Male   creation   20201229
# 16494      19950118  Female   creation   20201229
# 16495      20201230    Male   creation   20201230
# 16496      20201231  Female   creation   20201231
#
# [16497 rows x 9 columns]

# %%
ssa_nonoise = psp.generate_social_security(config=psp.NO_NOISE)
ssa_nonoise
# Out:
#       simulant_id          ssn first_name middle_name   last_name  \
# 0         0_19979  786-77-6454     Evelyn       Nancy       Hines
# 1          0_6846  688-88-6377     George      Robert     Dickens
# 2         0_19983  651-33-9561   Beatrice      Jennie     Fackler
# 3           0_262  665-25-7858       Eura      Nadine      Crusen
# 4         0_12473  875-10-2359    Roberta        Ruth  Muilenburg
# ...           ...          ...        ...         ...         ...
# 16492     0_20687  183-90-0619    Matthew     Michael    Phillips
# 16493     0_20686  803-81-8527     Jermey       Tyler      Wimmer
# 16494     0_20692  170-62-5253  Brittanie      Lauren        Thao
# 16495     0_20662  281-88-9330     Marcus      Jasper      Murphy
# 16496     0_20673  547-99-7034     Analia     Brielle      Kynard
#
#       date_of_birth     sex event_type event_date
# 0          19191204  Female   creation   19191204
# 1          19210616    Male   creation   19210616
# 2          19220113  Female   creation   19220113
# 3          19220305  Female   creation   19220305
# 4          19220306  Female   creation   19220306
# ...             ...     ...        ...        ...
# 16492      19800224    Male   creation   20201229
# 16493      19860415    Male   creation   20201229
# 16494      19950118  Female   creation   20201229
# 16495      20201230    Male   creation   20201230
# 16496      20201231  Female   creation   20201231
#
# [16497 rows x 9 columns]

# %%
ssa_noisy.ssn.compare(ssa_nonoise.ssn)
# Out:
#               self        other
# 3      448-43-1664  665-25-7858
# 6      134-68-8831  102-60-0838
# 12     881-81-1306  047-34-5906
# 14     580-70-8826  765-44-4521
# 15     209-06-3951  136-85-7371
# ...            ...          ...
# 16487  361-66-9187  885-72-7577
# 16489  833-17-4847  161-06-9252
# 16494  446-63-2138  170-62-5253
# 16495  702-65-5925  281-88-9330
# 16496  857-83-6064  547-99-7034
#
# [9235 rows x 2 columns]

# %%
9235 / len(ssa_nonoise) # Looks like the maximum fraction of noise-able rows was 56%
# Out:
# 0.559798751288113

# %% [markdown]
# # See what the path is to the sample data
#
# The directory is called `sample_datasets`, whereas with our updated terminology, it would be more appropriate to call it `sample_population`.

# %%
psp.constants.paths.SAMPLE_DATA_ROOT
# Out:
# PosixPath('/mnt/share/code/ndbs/pseudopeople/src/pseudopeople/data/sample_datasets')

# %%
data.american_community_survey.dtypes
# Out:
# simulant_id                                 object
# household_id                                object
# survey_date                         datetime64[ns]
# first_name                                  object
# middle_initial                              object
# last_name                                   object
# age                                         object
# date_of_birth                               object
# street_number                               object
# street_name                                 object
# unit_number                                 object
# city                                        object
# state                                     category
# zipcode                                     object
# housing_type                                object
# relationship_to_reference_person          category
# sex                                       category
# race_ethnicity                            category
# dtype: object

# %% [markdown]
# # Check whether survey datasets have a `survey_date` column, and what the dtype and date format are

# %%
data.current_population_survey.dtypes
# Out:
# simulant_id               object
# household_id              object
# survey_date       datetime64[ns]
# first_name                object
# middle_initial            object
# last_name                 object
# age                       object
# date_of_birth             object
# street_number             object
# street_name               object
# unit_number               object
# city                      object
# state                   category
# zipcode                   object
# sex                     category
# race_ethnicity          category
# dtype: object

# %%
col_config.filter(like='survey')
# Out:
# american_community_survey  column_noise  first_name      leave_blank           cell_probability     0.01
#                                                          use_nickname          cell_probability     0.01
#                                                          use_fake_name         cell_probability     0.01
#                                                          make_phonetic_errors  cell_probability     0.01
#                                                                                token_probability     0.1
#                                                                                                     ...
# current_population_survey  column_noise  zipcode         make_typos            token_probability     0.1
#                                          sex             leave_blank           cell_probability     0.01
#                                                          choose_wrong_option   cell_probability     0.01
#                                          race_ethnicity  leave_blank           cell_probability     0.01
#                                                          choose_wrong_option   cell_probability     0.01
# Length: 166, dtype: object

# %%
col_config.xs('american_community_survey')
# Out:
# column_noise  first_name                        leave_blank           cell_probability     0.01
#                                                 use_nickname          cell_probability     0.01
#                                                 use_fake_name         cell_probability     0.01
#                                                 make_phonetic_errors  cell_probability     0.01
#                                                                       token_probability     0.1
#                                                                                            ...
#               relationship_to_reference_person  choose_wrong_option   cell_probability     0.01
#               sex                               leave_blank           cell_probability     0.01
#                                                 choose_wrong_option   cell_probability     0.01
#               race_ethnicity                    leave_blank           cell_probability     0.01
#                                                 choose_wrong_option   cell_probability     0.01
# Length: 85, dtype: object

# %% [markdown]
# ## Also check whether `survey_date` column is noise-able
#
# Looks like it's not. According to Abie and Zeb, we are treating this as metadata, similar to year or tax year in the other datasets.

# %%
col_config.xs('american_community_survey').filter(like='survey')
# Out:
# Series([], dtype: object)

# %%
data.american_community_survey
# Out:
#    simulant_id household_id survey_date first_name middle_initial  last_name  \
# 0      0_12123       0_4898  2020-10-06      Jajes              N     Valdez
# 1      0_12124       0_4898  2020-10-06    Raymond              J     Valdez
# 2      0_20535       0_4898  2020-10-06      Ronin              K     Valdez
# 3       0_8831       0_3589  2020-03-24     Edward              J     Hayden
# 4        0_727          0_3  2020-04-21       Kari            NaN     Cannon
# ..         ...          ...         ...        ...            ...        ...
# 69     0_19709          0_3  2020-04-21       Erik              G  Underwood
# 70     0_19779          0_3  2020-04-21       Eric              B     Murphy
# 71     0_20082          0_3  2020-04-21     Eugene              G         Wu
# 72     0_20329          0_3  2020-04-21    Zachary              J     Walker
# 73      0_2896       0_1179  2020-12-01    Katelyn              A     Nelson
#
#    age date_of_birth street_number          street_name unit_number     city  \
# 0   43    07/04/1977           820         cameron road         NaN  Anytown
# 1   16    10/22/2003           820         cameron road         NaN  Anytown
# 2    0    08/04/2020           820         cameron road         NaN  Anytown
# 3   58    12/23/1961            20         oakbridge py         NaN  Anytown
# 4   36    05/05/1983          8203  west farwell avenue         NaN  Anytown
# ..  ..           ...           ...                  ...         ...      ...
# 69  23    09/21/1996          8203  west farwdll avenye         NaN  Anytown
# 70  40    08/10/1979          8203  west farwell avenue         NaN  Anytown
# 71  19    10/12/2000          8203  west farwell avenue         NaN  Anytown
# 72  17    01/20/2003          8203  west farwell avenue         NaN  Anyfown
# 73  30    12/04/1989        111-24          gonzalez dr  apt # 5002  Anytown
#
#    state zipcode housing_type                relationship_to_reference_person  \
# 0     WA   00000    Household                             Opposite-sex spouse
# 1     WA   00000    Household                                Biological child
# 2     WA   00000    Household                                Biological child
# 3     WA   00000    Household                                Reference person
# 4     WA   00000      College  Noninstitutionalized group quarters population
# ..   ...     ...          ...                                             ...
# 69    WA   00000      College  Noninstitutionalized group quarters population
# 70    WA   00000      College  Noninstitutionalized group quarters population
# 71    WA   00000      College  Noninstitutionalized group quarters population
# 72    WA   00000      College  Noninstitutionalized group quarters population
# 73    WA   00000    Household                             Opposite-sex spouse
#
#        sex race_ethnicity
# 0   Female          Asian
# 1     Male          Asian
# 2     Male          Asian
# 3      NaN          White
# 4   Female          White
# ..     ...            ...
# 69    Male          White
# 70    Male          Black
# 71    Male          Asian
# 72    Male          White
# 73  Female          White
#
# [74 rows x 18 columns]

# %%
data.current_population_survey
# Out:
#    simulant_id household_id survey_date   first_name middle_initial  \
# 0      0_16607       0_6703  2020-05-19      Delores              P
# 1       0_5893       0_2394  2020-01-28      Cameron              J
# 2       0_5894       0_2394  2020-01-28         Lois              M
# 3       0_9229       0_3752  2020-02-25         Greg              J
# 4      0_15857       0_6402  2020-02-25       Doreen              M
# 5      0_15858       0_6402  2020-02-25       Samuel              P
# 6       0_5055       0_2070  2020-03-24      Carolyn              V
# 7       0_5056       0_2070  2020-03-24          Zoe              A
# 8       0_5057       0_2070  2020-03-24        Steve              R
# 9      0_12893       0_5190  2020-03-24       Randal              W
# 10     0_12894       0_5190  2020-03-24         Teri              K
# 11      0_5040       0_2064  2020-05-19        Scott              T
# 12      0_5043       0_2064  2020-05-19     Kimberly              Z
# 13      0_5044       0_2064  2020-05-19  Christopher              L
# 14     0_14580       0_5872  2020-05-19         Anna              A
# 15     0_17192       0_6927  2020-05-19     Victoria              N
# 16     0_10742       0_4366  2020-06-16       Philip              W
# 17      0_4666       0_1905  2020-06-16         Mark              E
# 18      0_5047       0_2065  2020-06-16        Drake              M
# 19      0_6537       0_2660  2020-06-16        Brady              W
# 20     0_16816       0_6777  2020-06-16       Philip              W
# 21     0_16818       0_6777  2020-06-16    Madeleine              B
# 22     0_11447       0_4630  2020-07-14         Paul              F
# 23     0_18994       0_7639  2020-07-14     Jeremiah              T
# 24      0_3471       0_1411  2020-08-11         Paul              R
# 25      0_6231       0_2537  2020-09-08        Scott              M
# 26      0_6233       0_2537  2020-09-08       Pierce              E
# 27      0_5401       0_2206  2020-10-06        Keith              C
# 28     0_18278       0_7350  2020-10-06       Thomas              J
# 29     0_18280       0_7350  2020-10-06       Hannah              K
# 30     0_20520       0_3267  2020-11-03     Victoria              C
# 31     0_13467       0_5419  2020-11-03        Aaron              J
# 32      0_3235       0_1314  2020-12-01     Lawrence              T
# 33      0_3236       0_1314  2020-12-01       Melody              S
# 34      0_3237       0_1314  2020-12-01        Ellie              M
# 35      0_2225        0_897  2020-12-29        Laura              C
# 36      0_2737       0_1109  2020-12-29         Kali              A
# 37      0_2738       0_1109  2020-12-29         Kane              J
# 38     0_14560       0_5865  2020-12-29      Melissa              J
# 39     0_14561       0_5865  2020-12-29      Raymond              M
#
#           last_name  age date_of_birth street_number          street_name  \
# 0           Maholtz   84    10/08/1935          2100      hvn harbour way
# 1              Duff   83    01/25/1936          3256         mclaurin cir
# 2              Duff   81    12/03/1938          3256         mclaurin cir
# 3            Schick   69    03/14/1950         14375       wagon train dr
# 4             Mason   78    09/08/1941          1048          revuelta ct
# 5             Mason   81    09/07/1938          1048          revuelta ct
# 6             Teske   63    09/01/1956           430          hagenson st
# 7             Tecke   18    12/04/2001           430          hagenson st
# 8             Teske   62    07/23/1957           430          hagenson st
# 9           Grigsby   66    02/24/1954          2430      pleasant avenue
# 10          Grigsby   48    12/17/1971          2430      pleasant avenue
# 11          Johnson   57    05/08/1962          2002          203rd pl se
# 12          Johnson   14    02/23/2006          2002                  NaN
# 13          Johnson   11    04/15/2009          2002          203rd pl se
# 14         Bosworth   36    08/26/1983           307       west winona st
# 15        Greenland   48    04/23/1971          3221           detroit st
# 16             Egan  NaN    04/26/1957          4410          goiddust rx
# 17            Bruce   61    08/27/1958          5651  northeast park lane
# 18            Lopez   19    11/28/2000          4337  so e fairfax street
# 19          Demaree   31    01/15/1989          1102            41st st w
# 20       Villarreal   49    08/07/1970          8106            47 street
# 21       Villarreal   15    08/10/2004          8106            47 street
# 22            Jones   75    07/18/1944          2727         17th fairwav
# 23  Aguilar-Pineiro   43    01/28/1977           948        warren common
# 24            Spada   62    03/30/1958           278    s george mason dr
# 25             Nord   34    02/21/1986           426              buck ct
# 26             Nord    7    04/08/2013           426              buck ct
# 27            Lopez   43    08/08/1977          1171      via campania st
# 28            Parra   19    05/02/2001         10376        w columbus st
# 29            Parra    6           NaN         10376        w columbus st
# 30         Gonzalez   53    11/17/1966          5482     westminster road
# 31           Jacobs   21    02/06/1999         18381        arlington ave
# 32             Muse   48    08/22/1972            41             e 272 st
# 33             Muse   44    08/24/1976            41             e 272 st
# 34             Muse   16    02/16/2004            41             e 272 st
# 35           Warren   61    12/06/1958           124         woodward ave
# 36           Bascom    3    08/22/2017          1290            cntrl ave
# 37           Bascom    2    09/12/2018          1290            cntrl ave
# 38            Meeks   52    07/17/1968          1431           liberty st
# 39            Meeks   54    06/18/1966          1431           liberty st
#
#    unit_number     city state zipcode     sex        race_ethnicity
# 0          NaN  Anytown    WA   00000  Female                 White
# 1          NaN  Anytown    WA   00000    Male                 White
# 2          NaN   Anyton    WA   00000  Female                 White
# 3          NaN  Anytown    WA   00000    Male                 White
# 4          NaN  Anytown    WA   00000  Female                 White
# 5          NaN  Anytown    WA   00000    Male                 White
# 6          NaN  Anytown    WA   00000  Female                 White
# 7          NaN  Anytown    WA   00000  Female                 White
# 8          NaN  Anytown    WA   00000    Male                 White
# 9          NaN  Anytown    WA   00000    Male  Multiracial or Other
# 10         NaN  Anytown    WA   00000  Female  Multiracial or Other
# 11         NaN  Anytown    WA   00000    Male                 Black
# 12         NaN  Anytown    WA   00000  Female                 Black
# 13         NaN  Anytown   NaN   00000    Male                 Black
# 14         NaN  Anytown    WA   00000  Female                 White
# 15         NaN  Anytown   NaN   00000  Female                  AIAN
# 16         NaN  Anytown    WA   00000    Male                 White
# 17         NaN  Anytown    WA   00000    Male                 White
# 18         NaN  Anytown    WA   00000    Male                Latino
# 19         NaN  Anytown    WA   00000    Male                 White
# 20         NaN  Anytown    WA   00000    Male                 White
# 21         NaN  Anytown    WA   00000  Female                 White
# 22         NaN  Anytown    WA   00000    Male                 White
# 23         NaN  Anytown    WA   00000    Male                Latino
# 24         NaN  Anytown    WA   00000    Male                 White
# 25         NaN  Anytown    WA   00000    Male                 White
# 26         NaN  Anytown    WA   00000    Male                 White
# 27      apt 99  Anytown    WA   00000    Male                Latino
# 28         NaN  Anytown    WA   00000    Male                Latino
# 29         NaN  Anytown    WA   00000    Male                Latino
# 30         NaN  Anytown    WA   00000  Female                 White
# 31         NaN  Anytown    WA   00000    Male                 White
# 32         NaN  Anytown    WA   00000    Male                 White
# 33         NaN  Anytown    WA   00000  Female                 White
# 34         NaN  Anytown    WA   00000  Female                 White
# 35         NaN  Anytown    WA   00000  Female                 White
# 36         NaN  Anytown    WA   00000  Female                 White
# 37         NaN  Anytown    WA   00000    Male                 White
# 38         NaN  Anytown    WA   O0000  Female                 White
# 39         NaN  Anytown    WA   00000    Male                 White

# %%
data.american_community_survey.survey_date.dt.strftime("%d-%m-%Y")
# Out:
# 0     06-10-2020
# 1     06-10-2020
# 2     06-10-2020
# 3     24-03-2020
# 4     21-04-2020
#          ...
# 69    21-04-2020
# 70    21-04-2020
# 71    21-04-2020
# 72    21-04-2020
# 73    01-12-2020
# Name: survey_date, Length: 74, dtype: object

# %%
data.american_community_survey.survey_date.dt.strftime("%d-%m-%Y").map(type).unique()
# Out:
# array([<class 'str'>], dtype=object)

# %%
type(data.american_community_survey.survey_date.iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(data.current_population_survey.survey_date.iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
data.american_community_survey.survey_date
# Out:
# 0    2020-10-06
# 1    2020-10-06
# 2    2020-10-06
# 3    2020-03-24
# 4    2020-04-21
#         ...
# 69   2020-04-21
# 70   2020-04-21
# 71   2020-04-21
# 72   2020-04-21
# 73   2020-12-01
# Name: survey_date, Length: 74, dtype: datetime64[ns]

# %%
isinstance(data.current_population_survey.survey_date.iloc[0], pd.Timestamp)
# Out:
# True

# %%
t = data.current_population_survey.survey_date.iloc[0]
t
# Out:
# Timestamp('2020-05-19 00:00:00')

# %% [markdown]
# # Check what happens when we request SSA data for different years
#
# You can request years farther in the future than the end of the sim, but not too much farther. If you request years before the first record, you get the expected `ValueError` because there is no data. Or you may get a `ValueError` because the time is too far into the future or the past, raising an `OutOfBoundsDatetime` when attempting to convert to a Timestamp object.

# %%
psp.generate_social_security(year=1930)
# Out:
#     simulant_id          ssn first_name middle_name   last_name date_of_birth  \
# 0       0_19979  786-77-6454     Evelyn       Nancy       Hines      19191204
# 1        0_6846  688-88-6377     George      Robert     Dickens      19210616
# 2       0_19983  651-33-9561       Wife      Jennie     Fackler      19220113
# 3         0_262  665-25-7858       Eura      Nadine      Crusen      19220305
# 4       0_12473  875-10-2359    Roberta        Ruth  Muilenburg      19220306
# ..          ...          ...        ...         ...         ...           ...
# 134      0_5123  384-46-7224   Beatrice      Jennie       Makar      19300922
# 135     0_12683  567-54-2095     Norman     Charles       Adult      19300929
# 136     0_10201  613-15-1140      Betty   Priscilla     Kennedy      19301007
# 137      0_4377  519-55-9356    Shirley     Barbara    Mcdonald      19301112
# 138      0_3050  626-48-7965    Charles       Billy       Riley      19301202
#
#         sex event_type event_date
# 0    Female   creation   19191204
# 1      Male   creation   19210616
# 2    Female   creation   19220113
# 3    Female   creation   19220305
# 4    Female   creation   19220306
# ..      ...        ...        ...
# 134  Female   creation   19300922
# 135    Male   creation   19300929
# 136  Female   creation   19301007
# 137  Female   creation   19301112
# 138    Male   creation   19301202
#
# [139 rows x 9 columns]

# %%
psp.generate_social_security(year=2040)
# Out:
#       simulant_id          ssn first_name middle_name   last_name  \
# 0         0_19979  786-77-6454     Evelyn       Nancy       Hines
# 1          0_6846  688-88-6377     George      Robert     Dickens
# 2         0_19983  651-33-9561   Beatrice      Jennie     Fackler
# 3           0_262  665-25-7858       Eura      Nadine      Crusen
# 4         0_12473  875-10-2359    Roberta        Ruth  Muilenburg
# ...           ...          ...        ...         ...         ...
# 24066     0_27230  356-58-9816     Mariah       Lydia       Cline
# 24067     0_27218  576-40-3082     Claire     Cecilia      Bhakta
# 24068     0_27217  496-15-1541    Matilda    Isabella     Johnson
# 24069     0_27216  212-20-8121   Giovanni       Moshe        Home
# 24070     0_27215  634-45-3767    Oaklynn       Blima        Oddo
#
#       date_of_birth     sex event_type event_date
# 0          19191204  Female   creation   1919|204
# 1          19210616    Male   creation   19210616
# 2          19220113  Female   creation   19220115
# 3          19220305  Female   creation   19220305
# 4          19220306  Female   creation   19220306
# ...             ...     ...        ...        ...
# 24066      20381218  Female   creation   20401204
# 24067      20401206  Female   creation   20401206
# 24068      20401217  Female   creation   20401217
# 24069      20401219    Male   creation   20401219
# 24070      20401224  Female   creation   20401224
#
# [24071 rows x 9 columns]

# %%
psp.generate_social_security(year=2041)
# Out:
#       simulant_id          ssn first_name middle_name      last_name  \
# 0         0_19979  786-77-6454     Evelyn       Nancy          Hines
# 1          0_6846  688-88-6377     George      Robert        Dickens
# 2         0_19983  651-33-9561   Beatrice      Jennie        Fackler
# 3           0_262  665-25-7858       Eura      Nadine         Crusen
# 4         0_12473  875-10-2359    Roberta        Ruth     Muilenburg
# ...           ...          ...        ...         ...            ...
# 24200      0_7196  085-58-1731       Tony     Timothy             Ni
# 24201      0_2554  506-80-3608      Kevin         NaN           Cook
# 24202     0_16187  059-96-9698    Jeffrey     Brannon            Fox
# 24203     0_14782  714-38-0891   Jennifer     Jessica         Arthur
# 24204      0_4231  316-98-8999   Jonathan    Benjamin  Cando Chenery
#
#       date_of_birth     sex event_type event_date
# 0          19191204  Female   creation   19191204
# 1          19210616    Male   creation   19210616
# 2          19220113  Female   creation   19220113
# 3          19220305  Female   creation   19220305
# 4          19220306  Female   creation   19220306
# ...             ...     ...        ...        ...
# 24200      19620912    Male      death   20410521
# 24201      19630319    Male      death        NaN
# 24202      19691219    Male      death   20410521
# 24203      19800909  Female      death   20410521
# 24204      20000923    Male      death   20410521
#
# [24205 rows x 9 columns]

# %%
psp.generate_social_security(year=2042)
# Out:
#       simulant_id          ssn first_name middle_name      last_name  \
# 0         0_19979  786-77-6454     Evelyn       Nancy          Hines
# 1          0_6846  688-88-6377     George      Robert        Dickens
# 2         0_19983  651-33-9561   Beatrice      Jennie        Fackler
# 3           0_262  665-25-7858       Eura      Nadine         Crusen
# 4         0_12473  875-10-2359    Roberta        Ruth    Muiilenburg
# ...           ...          ...        ...         ...            ...
# 24200      0_7196  085-58-1731       Tony     Timothy             Ni
# 24201      0_2554  506-80-3608      Kevin     Charlie           Cook
# 24202     0_16187  059-96-9698    Jeffrey     Brannon            Fox
# 24203     0_14782  714-38-0891   Hwnnifer     Jessica         Arthur
# 24204      0_4231  316-98-8999   Jonathan    Benjamin  Cando Chenery
#
#       date_of_birth     sex event_type event_date
# 0          19191204  Female   creation   19191204
# 1          19210616    Male   creation   19210616
# 2          19220113  Female   creation   19220113
# 3          19220305  Female   creation   19220305
# 4          19220306  Female   creation   19220306
# ...             ...     ...        ...        ...
# 24200      19620912    Male      death   z04105Z|
# 24201      19630319    Male      death   20410521
# 24202      19691219    Male      death   20410521
# 24203      19800909  Female      death   20410521
# 24204      20000923    Male      death   20410521
#
# [24205 rows x 9 columns]

# %%
psp.generate_social_security(year=2050)
# Out:
#       simulant_id          ssn first_name middle_name      last_name  \
# 0         0_19979  786-77-6454     Evelyn       Nancy          Hines
# 1          0_6846  688-88-6377     George      Robert        Dickens
# 2         0_19983  651-33-9561   Beatrice      Jennie        Fackler
# 3           0_262  665-25-7858       Eura      Nadine         Crusen
# 4         0_12473  875-10-2359    Roberta      Female     Muilenburg
# ...           ...          ...        ...         ...            ...
# 24200      0_7196  085-58-1731    Anthony     Timothy             Ni
# 24201      0_2554  506-80-3608      Kevin     Charlie           Cook
# 24202     0_16187  059-96-9698    Jeffrey     Brannon            Fox
# 24203     0_14782  714-38-0891   Jennifer     Jessica         Arthur
# 24204      0_4231  316-98-8999        NaN    Benjamin  Cando Chenery
#
#       date_of_birth     sex event_type event_date
# 0          19191204  Female   creation   19191204
# 1          19210616    Male   creation   19210616
# 2          19221301  Female   creation   19220113
# 3          19220305  Female   creation   19220305
# 4          19220306  Female   creation   19220306
# ...             ...     ...        ...        ...
# 24200      19620912    Male      death   20410521
# 24201      19630319    Male      death        NaN
# 24202      19691219    Male      death   20410521
# 24203      19800909  Female        NaN   20410521
# 24204      20000923    Male      death   20410521
#
# [24205 rows x 9 columns]

# %%
psp.generate_social_security(year=1919)
# Out:
#   simulant_id          ssn first_name middle_name last_name date_of_birth  \
# 0     0_19979  786-77-6454     Evelyn       Nancy     Hines      19191204
#
#       sex event_type event_date
# 0  Female   creation   19191204

# %%
psp.generate_social_security(year=1918)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 psp.generate_social_security(year=1918)
#
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:430, in generate_social_security(source, seed, config, year, verbose)
#     428         raise ValueError(f"Invalid year provided: '{year}'")
#     429     seed = seed * 10_000 + year
# --> 430 return _generate_dataset(DATASETS.ssa, source, seed, config, user_filters, verbose)
#
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:85, in _generate_dataset(dataset, source, seed, config, user_filters, verbose)
#      83 # Check if all shards for the dataset are empty
#      84 if len(noised_dataset) == 0:
# ---> 85     raise ValueError(
#      86         "Invalid value provided for 'state' or 'year'. No data found with "
#      87         f"the user provided 'state' or 'year' filters at {data_path}."
#      88     )
#      89 noised_dataset = pd.concat(noised_dataset, ignore_index=True)
#      91 # Known pandas bug: pd.concat does not preserve category dtypes so we coerce
#      92 # again after concat (https://github.com/pandas-dev/pandas/issues/51362)
#
# ValueError: Invalid value provided for 'state' or 'year'. No data found with the user provided 'state' or 'year' filters at /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/data/sample_datasets/social_security/social_security.parquet.

# %%
psp.generate_social_security(year=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:424, in generate_social_security(source, seed, config, year, verbose)
#     419 try:
#     420     user_filters.append(
#     421         (
#     422             DATASETS.ssa.date_column_name,
#     423             "<=",
# --> 424             pd.Timestamp(year=year, month=12, day=31),
#     425         )
#     426     )
#     427 except (pd.errors.OutOfBoundsDatetime, ValueError):
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyx:1667, in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# ValueError: year 0 is out of range
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 psp.generate_social_security(year=0)
#
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:428, in generate_social_security(source, seed, config, year, verbose)
#     420         user_filters.append(
#     421             (
#     422                 DATASETS.ssa.date_column_name,
#    (...)
#     425             )
#     426         )
#     427     except (pd.errors.OutOfBoundsDatetime, ValueError):
# --> 428         raise ValueError(f"Invalid year provided: '{year}'")
#     429     seed = seed * 10_000 + year
#     430 return _generate_dataset(DATASETS.ssa, source, seed, config, user_filters, verbose)
#
# ValueError: Invalid year provided: '0'

# %%
psp.generate_social_security(year=1)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:424, in generate_social_security(source, seed, config, year, verbose)
#     419 try:
#     420     user_filters.append(
#     421         (
#     422             DATASETS.ssa.date_column_name,
#     423             "<=",
# --> 424             pd.Timestamp(year=year, month=12, day=31),
#     425         )
#     426     )
#     427 except (pd.errors.OutOfBoundsDatetime, ValueError):
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyx:1698, in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:299, in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:391, in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/np_datetime.pyx:212, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1-12-31 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 psp.generate_social_security(year=1)
#
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:428, in generate_social_security(source, seed, config, year, verbose)
#     420         user_filters.append(
#     421             (
#     422                 DATASETS.ssa.date_column_name,
#    (...)
#     425             )
#     426         )
#     427     except (pd.errors.OutOfBoundsDatetime, ValueError):
# --> 428         raise ValueError(f"Invalid year provided: '{year}'")
#     429     seed = seed * 10_000 + year
#     430 return _generate_dataset(DATASETS.ssa, source, seed, config, user_filters, verbose)
#
# ValueError: Invalid year provided: '1'

# %%
psp.generate_social_security(year=1800)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 psp.generate_social_security(year=1800)
#
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:430, in generate_social_security(source, seed, config, year, verbose)
#     428         raise ValueError(f"Invalid year provided: '{year}'")
#     429     seed = seed * 10_000 + year
# --> 430 return _generate_dataset(DATASETS.ssa, source, seed, config, user_filters, verbose)
#
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:85, in _generate_dataset(dataset, source, seed, config, user_filters, verbose)
#      83 # Check if all shards for the dataset are empty
#      84 if len(noised_dataset) == 0:
# ---> 85     raise ValueError(
#      86         "Invalid value provided for 'state' or 'year'. No data found with "
#      87         f"the user provided 'state' or 'year' filters at {data_path}."
#      88     )
#      89 noised_dataset = pd.concat(noised_dataset, ignore_index=True)
#      91 # Known pandas bug: pd.concat does not preserve category dtypes so we coerce
#      92 # again after concat (https://github.com/pandas-dev/pandas/issues/51362)
#
# ValueError: Invalid value provided for 'state' or 'year'. No data found with the user provided 'state' or 'year' filters at /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/data/sample_datasets/social_security/social_security.parquet.

# %%
psp.generate_social_security(year=50)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:424, in generate_social_security(source, seed, config, year, verbose)
#     419 try:
#     420     user_filters.append(
#     421         (
#     422             DATASETS.ssa.date_column_name,
#     423             "<=",
# --> 424             pd.Timestamp(year=year, month=12, day=31),
#     425         )
#     426     )
#     427 except (pd.errors.OutOfBoundsDatetime, ValueError):
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyx:1698, in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:299, in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:391, in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/np_datetime.pyx:212, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 50-12-31 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 psp.generate_social_security(year=50)
#
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:428, in generate_social_security(source, seed, config, year, verbose)
#     420         user_filters.append(
#     421             (
#     422                 DATASETS.ssa.date_column_name,
#    (...)
#     425             )
#     426         )
#     427     except (pd.errors.OutOfBoundsDatetime, ValueError):
# --> 428         raise ValueError(f"Invalid year provided: '{year}'")
#     429     seed = seed * 10_000 + year
#     430 return _generate_dataset(DATASETS.ssa, source, seed, config, user_filters, verbose)
#
# ValueError: Invalid year provided: '50'

# %%
psp.generate_social_security(year=5000)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:424, in generate_social_security(source, seed, config, year, verbose)
#     419 try:
#     420     user_filters.append(
#     421         (
#     422             DATASETS.ssa.date_column_name,
#     423             "<=",
# --> 424             pd.Timestamp(year=year, month=12, day=31),
#     425         )
#     426     )
#     427 except (pd.errors.OutOfBoundsDatetime, ValueError):
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyx:1698, in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:299, in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:391, in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/np_datetime.pyx:212, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 5000-12-31 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 psp.generate_social_security(year=5000)
#
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:428, in generate_social_security(source, seed, config, year, verbose)
#     420         user_filters.append(
#     421             (
#     422                 DATASETS.ssa.date_column_name,
#    (...)
#     425             )
#     426         )
#     427     except (pd.errors.OutOfBoundsDatetime, ValueError):
# --> 428         raise ValueError(f"Invalid year provided: '{year}'")
#     429     seed = seed * 10_000 + year
#     430 return _generate_dataset(DATASETS.ssa, source, seed, config, user_filters, verbose)
#
# ValueError: Invalid year provided: '5000'

# %%
psp.generate_social_security(year=3000)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:424, in generate_social_security(source, seed, config, year, verbose)
#     419 try:
#     420     user_filters.append(
#     421         (
#     422             DATASETS.ssa.date_column_name,
#     423             "<=",
# --> 424             pd.Timestamp(year=year, month=12, day=31),
#     425         )
#     426     )
#     427 except (pd.errors.OutOfBoundsDatetime, ValueError):
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyx:1698, in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:299, in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:391, in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/np_datetime.pyx:212, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 3000-12-31 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 psp.generate_social_security(year=3000)
#
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:428, in generate_social_security(source, seed, config, year, verbose)
#     420         user_filters.append(
#     421             (
#     422                 DATASETS.ssa.date_column_name,
#    (...)
#     425             )
#     426         )
#     427     except (pd.errors.OutOfBoundsDatetime, ValueError):
# --> 428         raise ValueError(f"Invalid year provided: '{year}'")
#     429     seed = seed * 10_000 + year
#     430 return _generate_dataset(DATASETS.ssa, source, seed, config, user_filters, verbose)
#
# ValueError: Invalid year provided: '3000'

# %%
psp.generate_social_security(year=2100)
# Out:
#       simulant_id          ssn first_name middle_name      last_name  \
# 0         0_19979  786-77-6454     Evelyn       Nancy          Hines
# 1          0_6846  688-88-6377     George      Robert        Dickens
# 2         0_19983  651-33-9561   Beatrice      Jennie        Fackler
# 3           0_262  665-25-7858       Eura      Nadine         Crusen
# 4         0_12473  875-10-2359    Roberta        Ruth     Muilenburg
# ...           ...          ...        ...         ...            ...
# 24200      0_7196  085-58-1731       Tony     Timothy             Ni
# 24201      0_2554  506-80-3608      Kevin     Charlie           Cook
# 24202     0_16187  059-96-9698    Jeffrey     Brannon            Fox
# 24203     0_14782  714-38-0891   Jennifer     Jessica         Arthur
# 24204      0_4231  316-98-8999   Jonathan    Benjamin  Cando Chenery
#
#       date_of_birth     sex event_type event_date
# 0          19191204  Female   creation   19191204
# 1          19210616    Male   creation   19210616
# 2          19220113  Female   creation   19220113
# 3          19220503  Female   creation   19220305
# 4          19220306  Female   creation   19220306
# ...             ...     ...        ...        ...
# 24200      19620912    Male      death   20410521
# 24201      19630319    Male      death   20410521
# 24202      19691219    Male      death   20410521
# 24203      19800909  Female      death   20410521
# 24204      20000923    Male      death   20410521
#
# [24205 rows x 9 columns]

# %%
psp.generate_social_security(year=2300)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:424, in generate_social_security(source, seed, config, year, verbose)
#     419 try:
#     420     user_filters.append(
#     421         (
#     422             DATASETS.ssa.date_column_name,
#     423             "<=",
# --> 424             pd.Timestamp(year=year, month=12, day=31),
#     425         )
#     426     )
#     427 except (pd.errors.OutOfBoundsDatetime, ValueError):
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyx:1698, in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:299, in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:391, in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/np_datetime.pyx:212, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 2300-12-31 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 psp.generate_social_security(year=2300)
#
# File /mnt/share/code/ndbs/pseudopeople/src/pseudopeople/interface.py:428, in generate_social_security(source, seed, config, year, verbose)
#     420         user_filters.append(
#     421             (
#     422                 DATASETS.ssa.date_column_name,
#    (...)
#     425             )
#     426         )
#     427     except (pd.errors.OutOfBoundsDatetime, ValueError):
# --> 428         raise ValueError(f"Invalid year provided: '{year}'")
#     429     seed = seed * 10_000 + year
#     430 return _generate_dataset(DATASETS.ssa, source, seed, config, user_filters, verbose)
#
# ValueError: Invalid year provided: '2300'

# %%
psp.generate_social_security(year=2200)
# Out:
#       simulant_id          ssn first_name middle_name      last_name  \
# 0         0_19979  786-77-6454     Evelyn       Nancy          Hines
# 1          0_6846  688-88-6377     George      Robert        Dickens
# 2         0_19983  651-33-9561   Beatrice      Jennie        Fackler
# 3           0_262  665-25-7858       Eura      Nadine         Crusen
# 4         0_12473  875-10-2359    Roberta        Ruth     Muilenburg
# ...           ...          ...        ...         ...            ...
# 24200      0_7196  085-58-1731       Tony     Timothy             Ni
# 24201      0_2554  506-80-3608      Kevin     Charlie           Cook
# 24202     0_16187  059-96-9698    Jeffrey     Brannon            Fox
# 24203     0_14782  714-38-0891   Jennifer     Jessica         Arthur
# 24204      0_4231  316-98-8999   Jonathan    Benjamin  Cando Chenery
#
#       date_of_birth     sex event_type event_date
# 0          19191204  Female   creation   19191204
# 1          19210616    Male   creation   19210616
# 2          19220113  Female   creation   19220113
# 3          19220305  Female   creation   19220305
# 4          19220306  Female   creation   19220306
# ...             ...     ...        ...        ...
# 24200      19620912    Male      death   20410521
# 24201      19630319    Male      death   20410521
# 24202      19691219    Male      death   20410521
# 24203      19800909  Female      death   20410521
# 24204      20000923    Male      death   20410521
#
# [24205 rows x 9 columns]

# %%
type(None)
# Out:
# NoneType

# %%
type(True)
# Out:
# bool

# %%
isinstance(None, type(None))
# Out:
# True

# %%
pd.Timestamp('2003-02-05')
# Out:
# Timestamp('2003-02-05 00:00:00')

# %%
pd.Timestamp('0003-02-05')
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 pd.Timestamp('0003-02-05')
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyx:1698, in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:249, in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:523, in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:506, in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# File ~/miniconda3/envs/pppl310/lib/python3.10/site-packages/pandas/_libs/tslibs/np_datetime.pyx:212, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 3-02-05 00:00:00

# %% [markdown]
# # Write a function to pad the tuples in the flattened config dictionary

# %%
def pad_tuples(tuples, pad_val=np.nan):
    max_len = max(map(len, tuples))
    new_tuples = ((*t, *((max_len - len(t)) * [pad_val])) for t in tuples)
    return new_tuples

# %%
pad_tuples(flat_config.keys())
# Out:
# <generator object pad_tuples.<locals>.<genexpr> at 0x7fc238cdc900>

# %%
list(pad_tuples(flat_config.keys()))[:5]
# Out:
# [('decennial_census',
#   'row_noise',
#   'do_not_respond',
#   'row_probability',
#   nan,
#   nan),
#  ('decennial_census',
#   'column_noise',
#   'first_name',
#   'leave_blank',
#   'cell_probability',
#   nan),
#  ('decennial_census',
#   'column_noise',
#   'first_name',
#   'use_nickname',
#   'cell_probability',
#   nan),
#  ('decennial_census',
#   'column_noise',
#   'first_name',
#   'use_fake_name',
#   'cell_probability',
#   nan),
#  ('decennial_census',
#   'column_noise',
#   'first_name',
#   'make_phonetic_errors',
#   'cell_probability',
#   nan)]

# %% [markdown]
# # Write a function to create a new dictionary with padded tuples as keys

# %%
def pad_flattened_dict(d, pad_val=np.nan):
    max_len = max(map(len, d.keys()))
    def pad_tuple(t):
        return (*t, *((max_len - len(t)) * [pad_val]))
    new_dict = {pad_tuple(key): val for key, val in d.items()}
    return new_dict

# %%
padded_flat_config = pad_flattened_dict(flat_config)
flat_config_series = pd.Series(padded_flat_config)
flat_config_series
# Out:
# decennial_census  row_noise     do_not_respond   row_probability       NaN                NaN    0.0145
#                   column_noise  first_name       leave_blank           cell_probability   NaN      0.01
#                                                  use_nickname          cell_probability   NaN      0.01
#                                                  use_fake_name         cell_probability   NaN      0.01
#                                                  make_phonetic_errors  cell_probability   NaN      0.01
#                                                                                                   ...
# taxes_1040        column_noise  dependent_4_ssn  write_wrong_digits    token_probability  NaN       0.1
#                                                  make_ocr_errors       cell_probability   NaN      0.01
#                                                                        token_probability  NaN       0.1
#                                                  make_typos            cell_probability   NaN      0.01
#                                                                        token_probability  NaN       0.1
# Length: 735, dtype: object

# %%
flat_config_series.filter(like='row')
# Out:
# decennial_census            row_noise  do_not_respond  row_probability  NaN  NaN    0.0145
# american_community_survey   row_noise  do_not_respond  row_probability  NaN  NaN    0.0145
# current_population_survey   row_noise  do_not_respond  row_probability  NaN  NaN    0.2905
# women_infants_and_children  row_noise  omit_row        row_probability  NaN  NaN       0.0
# social_security             row_noise  omit_row        row_probability  NaN  NaN       0.0
# taxes_w2_and_1099           row_noise  omit_row        row_probability  NaN  NaN     0.005
# taxes_1040                  row_noise  omit_row        row_probability  NaN  NaN       0.0
# dtype: object

# %%
flat_config_series.filter(items=['decennial_census'])
# Out:
# decennial_census    NaN
# dtype: object

# %%
flat_config_series.filter(items=['do_not_respond'])
# Out:
# Series([], dtype: object)

# %%
flat_config_series.loc['decennial_census']
# Out:
# row_noise     do_not_respond                    row_probability       NaN               NaN    0.0145
# column_noise  first_name                        leave_blank           cell_probability  NaN      0.01
#                                                 use_nickname          cell_probability  NaN      0.01
#                                                 use_fake_name         cell_probability  NaN      0.01
#                                                 make_phonetic_errors  cell_probability  NaN      0.01
#                                                                                                 ...
#               relationship_to_reference_person  choose_wrong_option   cell_probability  NaN      0.01
#               sex                               leave_blank           cell_probability  NaN      0.01
#                                                 choose_wrong_option   cell_probability  NaN      0.01
#               race_ethnicity                    leave_blank           cell_probability  NaN      0.01
#                                                 choose_wrong_option   cell_probability  NaN      0.01
# Length: 90, dtype: object

# %%
flat_config_series.xs('row_noise', level=1)
# Out:
# decennial_census            do_not_respond  row_probability  NaN  NaN    0.0145
# american_community_survey   do_not_respond  row_probability  NaN  NaN    0.0145
# current_population_survey   do_not_respond  row_probability  NaN  NaN    0.2905
# women_infants_and_children  omit_row        row_probability  NaN  NaN       0.0
# social_security             omit_row        row_probability  NaN  NaN       0.0
# taxes_w2_and_1099           omit_row        row_probability  NaN  NaN     0.005
# taxes_1040                  omit_row        row_probability  NaN  NaN       0.0
# dtype: object

# %%
pd.Series(pad_flattened_dict(flat_config, pad_val=...))
# Out:
# decennial_census  row_noise     do_not_respond   row_probability       Ellipsis           Ellipsis    0.0145
#                   column_noise  first_name       leave_blank           cell_probability   Ellipsis      0.01
#                                                  use_nickname          cell_probability   Ellipsis      0.01
#                                                  use_fake_name         cell_probability   Ellipsis      0.01
#                                                  make_phonetic_errors  cell_probability   Ellipsis      0.01
#                                                                                                        ...
# taxes_1040        column_noise  dependent_4_ssn  write_wrong_digits    token_probability  Ellipsis       0.1
#                                                  make_ocr_errors       cell_probability   Ellipsis      0.01
#                                                                        token_probability  Ellipsis       0.1
#                                                  make_typos            cell_probability   Ellipsis      0.01
#                                                                        token_probability  Ellipsis       0.1
# Length: 735, dtype: object

# %%
pd.Series(pad_flattened_dict(flat_config, pad_val=''))
# Out:
# decennial_census  row_noise     do_not_respond   row_probability                              0.0145
#                   column_noise  first_name       leave_blank           cell_probability         0.01
#                                                  use_nickname          cell_probability         0.01
#                                                  use_fake_name         cell_probability         0.01
#                                                  make_phonetic_errors  cell_probability         0.01
#                                                                                                ...
# taxes_1040        column_noise  dependent_4_ssn  write_wrong_digits    token_probability         0.1
#                                                  make_ocr_errors       cell_probability         0.01
#                                                                        token_probability         0.1
#                                                  make_typos            cell_probability         0.01
#                                                                        token_probability         0.1
# Length: 735, dtype: object

# %% [markdown]
# # Test functions after copying to module

# %%
pd.Series(alpha.pad_flattened_dict(alpha.flatten(config), pad_val=np.nan))
# Out:
# decennial_census  row_noise     do_not_respond   row_probability       NaN                NaN    0.0145
#                   column_noise  first_name       leave_blank           cell_probability   NaN      0.01
#                                                  use_nickname          cell_probability   NaN      0.01
#                                                  use_fake_name         cell_probability   NaN      0.01
#                                                  make_phonetic_errors  cell_probability   NaN      0.01
#                                                                                                   ...
# taxes_1040        column_noise  dependent_4_ssn  write_wrong_digits    token_probability  NaN       0.1
#                                                  make_ocr_errors       cell_probability   NaN      0.01
#                                                                        token_probability  NaN       0.1
#                                                  make_typos            cell_probability   NaN      0.01
#                                                                        token_probability  NaN       0.1
# Length: 735, dtype: object

# %%
pd.Series(alpha.pad_flattened_dict(alpha.flatten(config, pad_after={'row_noise': np.nan})))
# Out:
# decennial_census  row_noise     NaN              do_not_respond        row_probability    NaN    0.0145
#                   column_noise  first_name       leave_blank           cell_probability   NaN      0.01
#                                                  use_nickname          cell_probability   NaN      0.01
#                                                  use_fake_name         cell_probability   NaN      0.01
#                                                  make_phonetic_errors  cell_probability   NaN      0.01
#                                                                                                   ...
# taxes_1040        column_noise  dependent_4_ssn  write_wrong_digits    token_probability  NaN       0.1
#                                                  make_ocr_errors       cell_probability   NaN      0.01
#                                                                        token_probability  NaN       0.1
#                                                  make_typos            cell_probability   NaN      0.01
#                                                                        token_probability  NaN       0.1
# Length: 735, dtype: object

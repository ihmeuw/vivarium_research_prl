# %%
import pseudopeople as psp
import pandas as pd, numpy as np

from vivarium_research_prl.utils import sizemb, MappingViaAttributes, build_full_address
from vivarium_research_prl import alpha

# !date
# !whoami
# !uname -a
# !python --version
# !pwd
# Out:
# Wed 09 Aug 2023 05:42:39 PM PDT
# ndbs
# Linux long-slurm-sarchive-p0046 5.4.0-135-generic #152-Ubuntu SMP Wed Nov 23 20:19:22 UTC 2022 x86_64 x86_64 x86_64 GNU/Linux
# Python 3.10.12
# /mnt/share/code/ndbs/vivarium_research_prl/pseudopeople_testing

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Write a function to load all dataframes

# %%
dir(psp)
# Out:
# ['NO_NOISE',
#  '__about__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__copyright__',
#  '__doc__',
#  '__email__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__summary__',
#  '__title__',
#  '__uri__',
#  '__version__',
#  'column_getters',
#  'configuration',
#  'constants',
#  'data',
#  'entity_types',
#  'exceptions',
#  'generate_american_community_survey',
#  'generate_current_population_survey',
#  'generate_decennial_census',
#  'generate_social_security',
#  'generate_taxes_1040',
#  'generate_taxes_w2_and_1099',
#  'generate_women_infants_and_children',
#  'get_config',
#  'interface',
#  'loader',
#  'noise',
#  'noise_entities',
#  'noise_functions',
#  'noise_scaling',
#  'schema_entities',
#  'utilities']

# %%
[x for x in dir(psp) if 'generate' in x]
# Out:
# ['generate_american_community_survey',
#  'generate_current_population_survey',
#  'generate_decennial_census',
#  'generate_social_security',
#  'generate_taxes_1040',
#  'generate_taxes_w2_and_1099',
#  'generate_women_infants_and_children']

# %%
getattr(psp, 'generate_american_community_survey')
# Out:
# <function pseudopeople.interface.generate_american_community_survey(source: Union[pathlib.Path, str] = None, seed: int = 0, config: Union[pathlib.Path, str, Dict[str, Dict]] = None, year: Optional[int] = 2020, state: Optional[str] = None, verbose: bool = False) -> pandas.core.frame.DataFrame>

# %%
dir(getattr(psp, 'generate_american_community_survey'))
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
getattr(psp, 'generate_american_community_survey').__name__
# Out:
# 'generate_american_community_survey'

# %%
'generate_american_community_survey'.replace('generate_', '')
# Out:
# 'american_community_survey'

# %% [markdown]
# ## Function to generate all datasets

# %%
def generate_data(*args, **kwargs):
    generation_fns = (getattr(psp, name) for name in dir(psp) if 'generate' in name)
    data = {f.__name__.replace('generate_', ''): f(*args, **kwargs) for f in generation_fns}
    return MappingViaAttributes(data)

# %%
# %%time
data = generate_data()
data.keylist()
# Out:
# CPU times: user 40.9 s, sys: 338 ms, total: 41.3 s
# Wall time: 41.4 s
# ['american_community_survey',
#  'current_population_survey',
#  'decennial_census',
#  'social_security',
#  'taxes_1040',
#  'taxes_w2_and_1099',
#  'women_infants_and_children']

# %%
sum(sizemb(df) for df in data.values())
# Out:
# 64.26209399999999

# %%
{name: sizemb(df) for name, df in data.items()}
# Out:
# {'american_community_survey': 0.071779,
#  'current_population_survey': 0.052471,
#  'decennial_census': 14.722564,
#  'social_security': 9.158109,
#  'taxes_1040': 15.988987,
#  'taxes_w2_and_1099': 24.044507,
#  'women_infants_and_children': 0.223677}

# %% [markdown]
# # Display columns in all datasets

# %%
{name: df.dtypes for name, df in data.items()}
# Out:
# {'american_community_survey': simulant_id                                 object
#  household_id                                object
#  survey_date                         datetime64[ns]
#  first_name                                  object
#  middle_initial                              object
#  last_name                                   object
#  age                                         object
#  date_of_birth                               object
#  street_number                               object
#  street_name                                 object
#  unit_number                                 object
#  city                                        object
#  state                                     category
#  zipcode                                     object
#  relationship_to_reference_person          category
#  sex                                       category
#  race_ethnicity                            category
#  dtype: object,
#  'current_population_survey': simulant_id               object
#  household_id              object
#  survey_date       datetime64[ns]
#  first_name                object
#  middle_initial            object
#  last_name                 object
#  age                       object
#  date_of_birth             object
#  street_number             object
#  street_name               object
#  unit_number               object
#  city                      object
#  state                   category
#  zipcode                   object
#  sex                     category
#  race_ethnicity          category
#  dtype: object,
#  'decennial_census': simulant_id                           object
#  household_id                          object
#  first_name                            object
#  middle_initial                        object
#  last_name                             object
#  age                                   object
#  date_of_birth                         object
#  street_number                         object
#  street_name                           object
#  unit_number                           object
#  city                                  object
#  state                               category
#  zipcode                               object
#  relationship_to_reference_person    category
#  sex                                 category
#  race_ethnicity                      category
#  year                                  object
#  dtype: object,
#  'social_security': simulant_id        object
#  first_name         object
#  middle_name        object
#  last_name          object
#  date_of_birth      object
#  sex              category
#  ssn                object
#  event_type       category
#  event_date         object
#  dtype: object,
#  'taxes_1040': simulant_id                        object
#  household_id                       object
#  first_name                         object
#  middle_initial                     object
#  last_name                          object
#  mailing_address_street_number      object
#  mailing_address_street_name        object
#  mailing_address_unit_number        object
#  mailing_address_po_box             object
#  mailing_address_city               object
#  mailing_address_state            category
#  mailing_address_zipcode            object
#  ssn                                object
#  tax_year                           object
#  spouse_first_name                  object
#  spouse_middle_initial              object
#  spouse_last_name                   object
#  spouse_ssn                         object
#  dependent_1_first_name             object
#  dependent_1_last_name              object
#  dependent_1_ssn                    object
#  dependent_2_first_name             object
#  dependent_2_last_name              object
#  dependent_2_ssn                    object
#  dependent_3_first_name             object
#  dependent_3_last_name              object
#  dependent_3_ssn                    object
#  dependent_4_first_name             object
#  dependent_4_last_name              object
#  dependent_4_ssn                    object
#  dtype: object,
#  'taxes_w2_and_1099': simulant_id                        object
#  household_id                       object
#  first_name                         object
#  middle_initial                     object
#  last_name                          object
#  age                                object
#  date_of_birth                      object
#  mailing_address_street_number      object
#  mailing_address_street_name        object
#  mailing_address_unit_number        object
#  mailing_address_po_box             object
#  mailing_address_city               object
#  mailing_address_state            category
#  mailing_address_zipcode            object
#  ssn                                object
#  wages                              object
#  employer_id                        object
#  employer_name                      object
#  employer_street_number             object
#  employer_street_name               object
#  employer_unit_number               object
#  employer_city                      object
#  employer_state                   category
#  employer_zipcode                   object
#  tax_form                         category
#  tax_year                           object
#  dtype: object,
#  'women_infants_and_children': simulant_id         object
#  household_id        object
#  first_name          object
#  middle_initial      object
#  last_name           object
#  date_of_birth       object
#  street_number       object
#  street_name         object
#  unit_number         object
#  city                object
#  state             category
#  zipcode             object
#  sex               category
#  race_ethnicity    category
#  year                object
#  dtype: object}

# %% [markdown]
# # Check which datasets have certain columns

# %%
[name for name in data if 'sex' in data[name]]
# Out:
# ['american_community_survey',
#  'current_population_survey',
#  'decennial_census',
#  'social_security',
#  'women_infants_and_children']

# %%
[name for name in data if 'relationship_to_reference_person' in data[name]]
# Out:
# ['american_community_survey', 'decennial_census']

# %%
[name for name in data if 'middle_name' in data[name]]
# Out:
# ['social_security']

# %%
[name for name in data if not data[name].filter(regex='po_box').columns.empty]
# Out:
# ['taxes_1040', 'taxes_w2_and_1099']

# %%
[name for name in data if not data[name].filter(regex='year').columns.empty]
# Out:
# ['decennial_census',
#  'taxes_1040',
#  'taxes_w2_and_1099',
#  'women_infants_and_children']

# %% [markdown]
# # Get default config

# %%
config = psp.get_config()
config
# Out:
# {'decennial_census': {'row_noise': {'do_not_respond': {'row_probability': 0.0145}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'misreport_age': {'cell_probability': 0.01,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'swap_month_and_day': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'zipcode': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.01,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'relationship_to_reference_person': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'sex': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}}}},
#  'american_community_survey': {'row_noise': {'do_not_respond': {'row_probability': 0.0145}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'misreport_age': {'cell_probability': 0.01,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'swap_month_and_day': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'zipcode': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.01,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'relationship_to_reference_person': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'sex': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}}}},
#  'current_population_survey': {'row_noise': {'do_not_respond': {'row_probability': 0.2905}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'misreport_age': {'cell_probability': 0.01,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'swap_month_and_day': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'zipcode': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.01,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'sex': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}}}},
#  'women_infants_and_children': {'row_noise': {'omit_row': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'swap_month_and_day': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'zipcode': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.01,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'sex': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}}}},
#  'social_security': {'row_noise': {'omit_row': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'middle_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'swap_month_and_day': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'sex': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'ssn': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'event_type': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'event_date': {'leave_blank': {'cell_probability': 0.01},
#     'swap_month_and_day': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}}}},
#  'taxes_w2_and_1099': {'row_noise': {'omit_row': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'misreport_age': {'cell_probability': 0.01,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'swap_month_and_day': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_street_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_street_name': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_unit_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_po_box': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_city': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_state': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'mailing_address_zipcode': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.01,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'ssn': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'wages': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'employer_name': {'leave_blank': {'cell_probability': 0.01},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'employer_street_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'employer_street_name': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'employer_unit_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'employer_city': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'employer_state': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'employer_zipcode': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.01,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'tax_form': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}}}},
#  'taxes_1040': {'row_noise': {'omit_row': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_street_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_street_name': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_unit_number': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_po_box': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_city': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'mailing_address_state': {'leave_blank': {'cell_probability': 0.01},
#     'choose_wrong_option': {'cell_probability': 0.01}},
#    'mailing_address_zipcode': {'leave_blank': {'cell_probability': 0.01},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.01,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'ssn': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'spouse_first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'spouse_middle_initial': {'leave_blank': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'spouse_last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'spouse_ssn': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_1_first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_1_last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_1_ssn': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_2_first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_2_last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_2_ssn': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_3_first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_3_last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_3_ssn': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_4_first_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_nickname': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_4_last_name': {'leave_blank': {'cell_probability': 0.01},
#     'use_fake_name': {'cell_probability': 0.01},
#     'make_phonetic_errors': {'cell_probability': 0.01,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}},
#    'dependent_4_ssn': {'leave_blank': {'cell_probability': 0.01},
#     'copy_from_household_member': {'cell_probability': 0.01},
#     'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}}}}}

# %% [markdown]
# # Get a config with no noise

# %%
nonoise = psp.get_config(user_config=psp.NO_NOISE)
nonoise
# Out:
# {'decennial_census': {'row_noise': {'do_not_respond': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'misreport_age': {'cell_probability': 0.0,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'swap_month_and_day': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'zipcode': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'relationship_to_reference_person': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'sex': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}}}},
#  'american_community_survey': {'row_noise': {'do_not_respond': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'misreport_age': {'cell_probability': 0.0,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'swap_month_and_day': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'zipcode': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'relationship_to_reference_person': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'sex': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}}}},
#  'current_population_survey': {'row_noise': {'do_not_respond': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'misreport_age': {'cell_probability': 0.0,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'swap_month_and_day': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'zipcode': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'sex': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}}}},
#  'women_infants_and_children': {'row_noise': {'omit_row': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'swap_month_and_day': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'zipcode': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'sex': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}}}},
#  'social_security': {'row_noise': {'omit_row': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'middle_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'swap_month_and_day': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'sex': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'ssn': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'event_type': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'event_date': {'leave_blank': {'cell_probability': 0.0},
#     'swap_month_and_day': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}}}},
#  'taxes_w2_and_1099': {'row_noise': {'omit_row': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'misreport_age': {'cell_probability': 0.0,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'swap_month_and_day': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_street_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_street_name': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_unit_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_po_box': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_city': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_state': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'mailing_address_zipcode': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'ssn': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'wages': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'employer_name': {'leave_blank': {'cell_probability': 0.0},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'employer_street_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'employer_street_name': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'employer_unit_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'employer_city': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'employer_state': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'employer_zipcode': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'tax_form': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}}}},
#  'taxes_1040': {'row_noise': {'omit_row': {'row_probability': 0.0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_street_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_street_name': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_unit_number': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_po_box': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_city': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'mailing_address_state': {'leave_blank': {'cell_probability': 0.0},
#     'choose_wrong_option': {'cell_probability': 0.0}},
#    'mailing_address_zipcode': {'leave_blank': {'cell_probability': 0.0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0.0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'ssn': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'spouse_first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'spouse_middle_initial': {'leave_blank': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'spouse_last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'spouse_ssn': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_1_first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_1_last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_1_ssn': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_2_first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_2_last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_2_ssn': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_3_first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_3_last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_3_ssn': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_4_first_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_nickname': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_4_last_name': {'leave_blank': {'cell_probability': 0.0},
#     'use_fake_name': {'cell_probability': 0.0},
#     'make_phonetic_errors': {'cell_probability': 0.0,
#      'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}},
#    'dependent_4_ssn': {'leave_blank': {'cell_probability': 0.0},
#     'copy_from_household_member': {'cell_probability': 0.0},
#     'write_wrong_digits': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0.0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0.0, 'token_probability': 0.1}}}}}

# %% [markdown]
# # Find which datasets have omission noise turned on
#
# Nothing has simple omission turned on by default. The census and surveys have 'do not respond' omission set to nonzero values.

# %%
[x for x in config]
# Out:
# ['decennial_census',
#  'american_community_survey',
#  'current_population_survey',
#  'women_infants_and_children',
#  'social_security',
#  'taxes_w2_and_1099',
#  'taxes_1040']

# %%
{name: config[name]['row_noise'] for name in config}
# Out:
# {'decennial_census': {'do_not_respond': {'row_probability': 0.0145}},
#  'american_community_survey': {'do_not_respond': {'row_probability': 0.0145}},
#  'current_population_survey': {'do_not_respond': {'row_probability': 0.2905}},
#  'women_infants_and_children': {'omit_row': {'row_probability': 0.0}},
#  'social_security': {'omit_row': {'row_probability': 0.0}},
#  'taxes_w2_and_1099': {'omit_row': {'row_probability': 0.0}},
#  'taxes_1040': {'omit_row': {'row_probability': 0.0}}}

# %% [markdown]
# # Check whether the index is always consecutive, particularly for datasets with rows omitted

# %%
data.decennial_census
# Out:
#       simulant_id household_id first_name middle_initial     last_name age  \
# 0             0_0          0_6     Gerald              R       Sorrell  70
# 1             0_1          0_6    Earline              R       Sorrell  63
# 2             0_2          0_7      Diana              P         Kellv  25
# 3             0_3          0_7       Anna              A           NaN  25
# 4             0_4          0_8       Eric              R  Stark Lozano  38
# ...           ...          ...        ...            ...           ...  ..
# 19819     0_20449       0_6619    Bridget              L          Ford  22
# 19820     0_20450        0_383   Jonathan              M        Morgan  38
# 19821     0_20451       0_8366     Dennis              D        Aagard  58
# 19822     0_20452       0_8366       Lisa              S        Aagard  55
# 19823     0_20453       0_8367      Danny              J      Vanduzer  60
#
#       date_of_birth street_number        street_name unit_number  \
# 0        01/18/1950           NaN        barbara cir         NaN
# 1        12/23/1956           NaN        barbara cir         NaN
# 2        05/06/1994          5112           145th st         NaN
# 3        09/69/1994          5174           145th st         NaN
# 4        05/29/1981          1501    interlake ave n         NaN
# ...             ...           ...                ...         ...
# 19819    08/13/1997           100         milling st         NaN
# 19820    09/18/1981         20430    autumn ridge dr         NaN
# 19821    09/24/1961          1894      nrte 103rd st         NaN
# 19822    08/05/1964          1894      nrte 103rd st         NaN
# 19823           NaN           520  n gambel quail tr         NaN
#
#                city state zipcode relationship_to_reference_person     sex  \
# 0      williamsburg    VA   22802                 Reference person    Male
# 1      williamsburg    VA   22802                   Opp-sex spouse  Female
# 2          portland    OR   97601                 Reference person  Female
# 3          portland    OR   97601                   Other relative  Female
# 4         bradenton    FL   33174                 Reference person    Male
# ...             ...   ...     ...                              ...     ...
# 19819  reynoldsburg    OH   45242                Other nonrelative  Female
# 19820   bella vista    AR   72704                          Sibling    Male
# 19821      goose cr    SC   29625                 Reference person    Male
# 19822      goose cr    FL   29625                   Opp-sex spouse  Female
# 19823   river grove    IL   60154                 Reference person    Male
#
#       race_ethnicity  year
# 0              White  2020
# 1              White  2020
# 2              White  2020
# 3              White  2020
# 4             Latino  2020
# ...              ...   ...
# 19819          White  2020
# 19820         Latino  2020
# 19821          White  2020
# 19822          White  2020
# 19823          White  2020
#
# [19824 rows x 17 columns]

# %%
index = data.decennial_census.index
(index == pd.Series(range(len(index)))).all()
# Out:
# True

# %%
index = data.american_community_survey.index
(index == pd.Series(range(len(index)))).all()
# Out:
# True

# %%
index = data.current_population_survey.index
(index == pd.Series(range(len(index)))).all()
# Out:
# True

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# ## Write a function to check for consecutive index

# %%
def index_is_consecutive(df):
    index = df.index
    return (index == np.arange(len(index))).all()

# %%
all(index_is_consecutive(df) for df in data.values())
# Out:
# True

# %% [markdown]
# # Try generating a dataset with more missing rows and see if index is still consecutive
#
# Yes, it is.

# %%
data.social_security
# Out:
#       simulant_id first_name middle_name   last_name date_of_birth     sex  \
# 0         0_19979     Evelyn       Nancy       Hines      19191204  Female
# 1          0_6846     George      Robert     Dickens      19210616    Male
# 2         0_19983   Beatrice      Jennie     Fackler      19220113  Female
# 3           0_262       Eura      Nadine      Crusen      19220305  Female
# 4         0_12473    Roberta        Ruth  Muilenburg      19220306  Female
# ...           ...        ...         ...         ...           ...     ...
# 20289     0_20687    Matthew     Michael    Phillips      19800224    Male
# 20290     0_20686     Jermey       Tyler      Wimmer      19860415    Male
# 20291     0_20692  Brittanie      Lauren        Thao      19950118  Female
# 20292     0_20662     Marcus      Jasper      Murphy      20201230    Male
# 20293     0_20673     Analia     Brielle      Kynard      20201231  Female
#
#                ssn event_type event_date
# 0      786-77-6454   creation   19191204
# 1      688-88-6377   creation   19210616
# 2      651-33-9561   creation   19220113
# 3      665-25-7858   creation   19220305
# 4      875-10-2359   creation   19220306
# ...            ...        ...        ...
# 20289  183-90-0619   creation   20201229
# 20290  803-81-8527   creation   20201229
# 20291  170-62-5253   creation   20201229
# 20292  281-88-9330   creation   20201230
# 20293  547-99-7034   creation   20200334
#
# [20294 rows x 9 columns]

# %%
missing_config = {'social_security': {'row_noise': {'omit_row': {'row_probability': 0.5}}}}

# %%
ssa_missing = psp.generate_social_security(config=missing_config)
ssa_missing
# Out:
#       simulant_id first_name middle_name     last_name date_of_birth     sex  \
# 0         0_19979     Evelyn       Nancy         Hines      19191204  Female
# 1         0_19983   Beatrice      Jennie       Fackler      19220113  Female
# 2         0_19941      Betty        Mary           Bee      19220307  Female
# 3          0_7141      Betty       Rhoda       Stutler      19220508  Female
# 4         0_18338       Lois        Mary  Dewispelaere      19220710  Female
# ...           ...        ...         ...           ...           ...     ...
# 10142      0_8740        Jay     Stephen   Chamberlain      19570606    Male
# 10143     0_20688     Efrain        Paul      Harrison      19590520    Male
# 10144     0_19726      David      Harvey       Coffman      19651221    Male
# 10145     0_20690   Jeremiah      Carlos        Gooden      19800105    Male
# 10146     0_20662     Marcus      Jasper        Murphy      20201230    Male
#
#                ssn event_type event_date
# 0      786-77-6454   creation   19191204
# 1      651-33-9561   creation   19220113
# 2      420-19-3737      death   19220307
# 3      494-11-1947   creation   19220508
# 4      325-04-6183   creation   19220710
# ...            ...        ...        ...
# 10142  404-84-1009      death   20201229
# 10143  161-06-9252   creation        NaN
# 10144  112-13-5339      death   20201229
# 10145  438-57-6936   creation   20201229
# 10146  281-88-9330   creation   20201230
#
# [10147 rows x 9 columns]

# %%
index_is_consecutive(ssa_missing)
# Out:
# True

# %%
data.social_security.merge(ssa_missing, on=['simulant_id'], how='left')
# Out:
#       simulant_id first_name_x middle_name_x last_name_x date_of_birth_x  \
# 0         0_19979       Evelyn         Nancy       Hines        19191204
# 1          0_6846       George        Robert     Dickens        19210616
# 2         0_19983     Beatrice        Jennie     Fackler        19220113
# 3         0_19983     Beatrice        Jennie     Fackler        19220113
# 4           0_262         Eura        Nadine      Crusen        19220305
# ...           ...          ...           ...         ...             ...
# 20471     0_20687      Matthew       Michael    Phillips        19800224
# 20472     0_20686       Jermey         Tyler      Wimmer        19860415
# 20473     0_20692    Brittanie        Lauren        Thao        19950118
# 20474     0_20662       Marcus        Jasper      Murphy        20201230
# 20475     0_20673       Analia       Brielle      Kynard        20201231
#
#         sex_x        ssn_x event_type_x event_date_x first_name_y  \
# 0      Female  786-77-6454     creation     19191204       Evelyn
# 1        Male  688-88-6377     creation     19210616          NaN
# 2      Female  651-33-9561     creation     19220113     Beatrice
# 3      Female  651-33-9561     creation     19220113     Beatrice
# 4      Female  665-25-7858     creation     19220305          NaN
# ...       ...          ...          ...          ...          ...
# 20471    Male  183-90-0619     creation     20201229          NaN
# 20472    Male  803-81-8527     creation     20201229          NaN
# 20473  Female  170-62-5253     creation     20201229          NaN
# 20474    Male  281-88-9330     creation     20201230       Marcus
# 20475  Female  547-99-7034     creation     20200334          NaN
#
#       middle_name_y last_name_y date_of_birth_y   sex_y        ssn_y  \
# 0             Nancy       Hines        19191204  Female  786-77-6454
# 1               NaN         NaN             NaN     NaN          NaN
# 2            Jennie     Fackler        19220113  Female  651-33-9561
# 3            Jennie     Fackler        19220113  Female  651-33-9561
# 4               NaN         NaN             NaN     NaN          NaN
# ...             ...         ...             ...     ...          ...
# 20471           NaN         NaN             NaN     NaN          NaN
# 20472           NaN         NaN             NaN     NaN          NaN
# 20473           NaN         NaN             NaN     NaN          NaN
# 20474        Jasper      Murphy        20201230    Male  281-88-9330
# 20475           NaN         NaN             NaN     NaN          NaN
#
#       event_type_y event_date_y
# 0         creation     19191204
# 1              NaN          NaN
# 2         creation     19220113
# 3            death     20191231
# 4              NaN          NaN
# ...            ...          ...
# 20471          NaN          NaN
# 20472          NaN          NaN
# 20473          NaN          NaN
# 20474     creation     20201230
# 20475          NaN          NaN
#
# [20476 rows x 17 columns]

# %% [markdown]
# ## Verify that index does not "leak data" by telling use which rows are omitted

# %%
# This verifies that corresponding rows almost always have different index numbers in the two versions of the SSA data.
# Thus we don't have a "data leakage" problem in the index.
data.social_security.join(ssa_missing, rsuffix='_m')
# Out:
#       simulant_id first_name middle_name   last_name date_of_birth     sex  \
# 0         0_19979     Evelyn       Nancy       Hines      19191204  Female
# 1          0_6846     George      Robert     Dickens      19210616    Male
# 2         0_19983   Beatrice      Jennie     Fackler      19220113  Female
# 3           0_262       Eura      Nadine      Crusen      19220305  Female
# 4         0_12473    Roberta        Ruth  Muilenburg      19220306  Female
# ...           ...        ...         ...         ...           ...     ...
# 20289     0_20687    Matthew     Michael    Phillips      19800224    Male
# 20290     0_20686     Jermey       Tyler      Wimmer      19860415    Male
# 20291     0_20692  Brittanie      Lauren        Thao      19950118  Female
# 20292     0_20662     Marcus      Jasper      Murphy      20201230    Male
# 20293     0_20673     Analia     Brielle      Kynard      20201231  Female
#
#                ssn event_type event_date simulant_id_m first_name_m  \
# 0      786-77-6454   creation   19191204       0_19979       Evelyn
# 1      688-88-6377   creation   19210616       0_19983     Beatrice
# 2      651-33-9561   creation   19220113       0_19941        Betty
# 3      665-25-7858   creation   19220305        0_7141        Betty
# 4      875-10-2359   creation   19220306       0_18338         Lois
# ...            ...        ...        ...           ...          ...
# 20289  183-90-0619   creation   20201229           NaN          NaN
# 20290  803-81-8527   creation   20201229           NaN          NaN
# 20291  170-62-5253   creation   20201229           NaN          NaN
# 20292  281-88-9330   creation   20201230           NaN          NaN
# 20293  547-99-7034   creation   20200334           NaN          NaN
#
#       middle_name_m   last_name_m date_of_birth_m   sex_m        ssn_m  \
# 0             Nancy         Hines        19191204  Female  786-77-6454
# 1            Jennie       Fackler        19220113  Female  651-33-9561
# 2              Mary           Bee        19220307  Female  420-19-3737
# 3             Rhoda       Stutler        19220508  Female  494-11-1947
# 4              Mary  Dewispelaere        19220710  Female  325-04-6183
# ...             ...           ...             ...     ...          ...
# 20289           NaN           NaN             NaN     NaN          NaN
# 20290           NaN           NaN             NaN     NaN          NaN
# 20291           NaN           NaN             NaN     NaN          NaN
# 20292           NaN           NaN             NaN     NaN          NaN
# 20293           NaN           NaN             NaN     NaN          NaN
#
#       event_type_m event_date_m
# 0         creation     19191204
# 1         creation     19220113
# 2            death     19220307
# 3         creation     19220508
# 4         creation     19220710
# ...            ...          ...
# 20289          NaN          NaN
# 20290          NaN          NaN
# 20291          NaN          NaN
# 20292          NaN          NaN
# 20293          NaN          NaN
#
# [20294 rows x 18 columns]

# %% [markdown]
# # Look at 1040 tax form
#
# The `tax_year` column is in the wrong place -- it should be the last column, but it's in the middle.

# %%
data.taxes_1040
# Out:
#       simulant_id household_id first_name middle_initial   last_name  \
# 0             0_0          0_6     Gerald              R     Sorrell
# 1             0_2          0_7      Diana              P       Kelly
# 2             0_8          0_9  Elizabeth              P    Gonzalez
# 3            0_14         0_11     Gerald              R   Hutchison
# 4            0_17         0_12     Gerald              R    Mcintyre
# ...           ...          ...        ...            ...         ...
# 12353     0_20750          0_5    Michael              E     Longley
# 12354     0_20751       0_3336      Brody              J   Dominguez
# 12355     0_20753       0_2825   Jennifer              T  Concepcion
# 12356     0_20754       0_6380    Jazmine              A      Hughes
# 12357     0_20759       0_8741     Athena              G      Borkar
#
#       mailing_address_street_number mailing_address_street_name  \
# 0                               NaN                 barbara cir
# 1                              5112                         NaN
# 2                                12                 meridian st
# 3                               502                n bingham st
# 4                              2105                hyde park ln
# ...                             ...                         ...
# 12353                          4000            nw skycrest pkwy
# 12354                           120                   32 avenue
# 12355                          4920                    10th way
# 12356                          2690          norh e 65th street
# 12357                          3133              shady brook dr
#
#       mailing_address_unit_number mailing_address_po_box mailing_address_city  \
# 0                             NaN                    NaN         williamsburg
# 1                             NaN                    NaN             portland
# 2                             NaN                    NaN               albany
# 3                             NaN                    NaN              oakland
# 4                             NaN                    NaN               s bend
# ...                           ...                    ...                  ...
# 12353                         NaN                    NaN            new caney
# 12354                         NaN                    NaN          e brunswick
# 12355                         NaN                    NaN          painesville
# 12356                         NaN                    NaN           birmingham
# 12357                         NaN                    NaN             lockport
#
#        ... dependent_1_ssn dependent_2_first_name dependent_2_last_name  \
# 0      ...             NaN                    NaN                   NaN
# 1      ...             NaN                    NaN                   NaN
# 2      ...     395-30-9975                    NaN                   NaN
# 3      ...     462-01-8027                Dominic             Hutchison
# 4      ...             NaN                    NaN                   NaN
# ...    ...             ...                    ...                   ...
# 12353  ...             NaN                    NaN                   NaN
# 12354  ...             NaN                    NaN                   NaN
# 12355  ...             NaN                    NaN                   NaN
# 12356  ...             NaN                    NaN                   NaN
# 12357  ...             NaN                    NaN                   NaN
#
#       dependent_2_ssn dependent_3_first_name dependent_3_last_name  \
# 0                 NaN                    NaN                   NaN
# 1                 NaN                    NaN                   NaN
# 2                 NaN                    NaN                   NaN
# 3         178-81-4204                    NaN                   NaN
# 4                 NaN                    NaN                   NaN
# ...               ...                    ...                   ...
# 12353             NaN                    NaN                   NaN
# 12354             NaN                    NaN                   NaN
# 12355             NaN                    NaN                   NaN
# 12356             NaN                    NaN                   NaN
# 12357             NaN                    NaN                   NaN
#
#       dependent_3_ssn dependent_4_first_name dependent_4_last_name  \
# 0                 NaN                    NaN                   NaN
# 1                 NaN                    NaN                   NaN
# 2                 NaN                    NaN                   NaN
# 3                 NaN                    NaN                   NaN
# 4                 NaN                    NaN                   NaN
# ...               ...                    ...                   ...
# 12353             NaN                    NaN                   NaN
# 12354             NaN                    NaN                   NaN
# 12355             NaN                    NaN                   NaN
# 12356             NaN                    NaN                   NaN
# 12357             NaN                    NaN                   NaN
#
#       dependent_4_ssn
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 12353             NaN
# 12354             NaN
# 12355             NaN
# 12356             NaN
# 12357             NaN
#
# [12358 rows x 30 columns]

# %%
data.taxes_1040.memory_usage(deep=True) / len(data.taxes_1040)
# Out:
# Index                             0.010358
# simulant_id                      63.466904
# household_id                     62.722447
# first_name                       62.622188
# middle_initial                   57.768652
# last_name                        63.312753
# mailing_address_street_number    59.097993
# mailing_address_street_name      68.429358
# mailing_address_unit_number      34.784917
# mailing_address_po_box           32.025247
# mailing_address_city             65.610050
# mailing_address_state             1.413740
# mailing_address_zipcode          61.687328
# ssn                              66.517964
# tax_year                         36.000000
# spouse_first_name                35.105357
# spouse_middle_initial            34.621460
# spouse_last_name                 35.179155
# spouse_ssn                       35.414226
# dependent_1_first_name           38.008820
# dependent_1_last_name            38.166289
# dependent_1_ssn                  38.939230
# dependent_2_first_name           35.165965
# dependent_2_last_name            35.260803
# dependent_2_ssn                  35.682311
# dependent_3_first_name           33.137158
# dependent_3_last_name            33.173895
# dependent_3_ssn                  33.319631
# dependent_4_first_name           32.365350
# dependent_4_last_name            32.377569
# dependent_4_ssn                  32.428306
# dtype: float64

# %%
data.taxes_1040.memory_usage(deep=True).sum() / 1e6
# Out:
# 15.988971

# %%
sizemb(data.taxes_1040)
# Out:
# 15.988987

# %%
data.taxes_1040.memory_usage(deep=True) / 1000
# Out:
# Index                              0.128
# simulant_id                      784.324
# household_id                     775.124
# first_name                       773.885
# middle_initial                   713.905
# last_name                        782.419
# mailing_address_street_number    730.333
# mailing_address_street_name      845.650
# mailing_address_unit_number      429.872
# mailing_address_po_box           395.768
# mailing_address_city             810.809
# mailing_address_state             17.471
# mailing_address_zipcode          762.332
# ssn                              822.029
# tax_year                         444.888
# spouse_first_name                433.832
# spouse_middle_initial            427.852
# spouse_last_name                 434.744
# spouse_ssn                       437.649
# dependent_1_first_name           469.713
# dependent_1_last_name            471.659
# dependent_1_ssn                  481.211
# dependent_2_first_name           434.581
# dependent_2_last_name            435.753
# dependent_2_ssn                  440.962
# dependent_3_first_name           409.509
# dependent_3_last_name            409.963
# dependent_3_ssn                  411.764
# dependent_4_first_name           399.971
# dependent_4_last_name            400.122
# dependent_4_ssn                  400.749
# dtype: float64

# %%
s = data.taxes_1040.dependent_1_ssn.astype('category')
s
# Out:
# 0                NaN
# 1                NaN
# 2        395-30-9975
# 3        462-01-8027
# 4                NaN
#             ...
# 12353            NaN
# 12354            NaN
# 12355            NaN
# 12356            NaN
# 12357            NaN
# Name: dependent_1_ssn, Length: 12358, dtype: category
# Categories (2158, object): ['001-02-4588', '002-05-7114', '002-08-7357', '002-36-2766', ..., '897-53-4216', '899-23-4006', '899-23-6208', '899-86-3167']

# %%
s.memory_usage(deep=True) / 1000
# Out:
# 237.679

# %% [markdown]
# # It looks like we have addresses from all over the US instead of just in Anytown, US

# %%
 data.taxes_1040.filter(like='mailing')
# Out:
#       mailing_address_street_number mailing_address_street_name  \
# 0                               NaN                 barbara cir
# 1                              5112                         NaN
# 2                                12                 meridian st
# 3                               502                n bingham st
# 4                              2105                hyde park ln
# ...                             ...                         ...
# 12353                          4000            nw skycrest pkwy
# 12354                           120                   32 avenue
# 12355                          4920                    10th way
# 12356                          2690          norh e 65th street
# 12357                          3133              shady brook dr
#
#       mailing_address_unit_number mailing_address_po_box mailing_address_city  \
# 0                             NaN                    NaN         williamsburg
# 1                             NaN                    NaN             portland
# 2                             NaN                    NaN               albany
# 3                             NaN                    NaN              oakland
# 4                             NaN                    NaN               s bend
# ...                           ...                    ...                  ...
# 12353                         NaN                    NaN            new caney
# 12354                         NaN                    NaN          e brunswick
# 12355                         NaN                    NaN          painesville
# 12356                         NaN                    NaN           birmingham
# 12357                         NaN                    NaN             lockport
#
#       mailing_address_state mailing_address_zipcode
# 0                        VA                   22802
# 1                        OR                   97601
# 2                        NY                   12308
# 3                        CA                   95678
# 4                        IN                   46033
# ...                     ...                     ...
# 12353                    TX                   78645
# 12354                    NJ                   07047
# 12355                    OH                   44095
# 12356                    AL                   36117
# 12357                    NY                   10029
#
# [12358 rows x 7 columns]

# %%
data.decennial_census
# Out:
#       simulant_id household_id first_name middle_initial     last_name age  \
# 0             0_0          0_6     Gerald              R       Sorrell  70
# 1             0_1          0_6    Earline              R       Sorrell  63
# 2             0_2          0_7      Diana              P         Kellv  25
# 3             0_3          0_7       Anna              A           NaN  25
# 4             0_4          0_8       Eric              R  Stark Lozano  38
# ...           ...          ...        ...            ...           ...  ..
# 19819     0_20449       0_6619    Bridget              L          Ford  22
# 19820     0_20450        0_383   Jonathan              M        Morgan  38
# 19821     0_20451       0_8366     Dennis              D        Aagard  58
# 19822     0_20452       0_8366       Lisa              S        Aagard  55
# 19823     0_20453       0_8367      Danny              J      Vanduzer  60
#
#       date_of_birth street_number        street_name unit_number  \
# 0        01/18/1950           NaN        barbara cir         NaN
# 1        12/23/1956           NaN        barbara cir         NaN
# 2        05/06/1994          5112           145th st         NaN
# 3        09/69/1994          5174           145th st         NaN
# 4        05/29/1981          1501    interlake ave n         NaN
# ...             ...           ...                ...         ...
# 19819    08/13/1997           100         milling st         NaN
# 19820    09/18/1981         20430    autumn ridge dr         NaN
# 19821    09/24/1961          1894      nrte 103rd st         NaN
# 19822    08/05/1964          1894      nrte 103rd st         NaN
# 19823           NaN           520  n gambel quail tr         NaN
#
#                city state zipcode relationship_to_reference_person     sex  \
# 0      williamsburg    VA   22802                 Reference person    Male
# 1      williamsburg    VA   22802                   Opp-sex spouse  Female
# 2          portland    OR   97601                 Reference person  Female
# 3          portland    OR   97601                   Other relative  Female
# 4         bradenton    FL   33174                 Reference person    Male
# ...             ...   ...     ...                              ...     ...
# 19819  reynoldsburg    OH   45242                Other nonrelative  Female
# 19820   bella vista    AR   72704                          Sibling    Male
# 19821      goose cr    SC   29625                 Reference person    Male
# 19822      goose cr    FL   29625                   Opp-sex spouse  Female
# 19823   river grove    IL   60154                 Reference person    Male
#
#       race_ethnicity  year
# 0              White  2020
# 1              White  2020
# 2              White  2020
# 3              White  2020
# 4             Latino  2020
# ...              ...   ...
# 19819          White  2020
# 19820         Latino  2020
# 19821          White  2020
# 19822          White  2020
# 19823          White  2020
#
# [19824 rows x 17 columns]

# %%
data.american_community_survey
# Out:
#    simulant_id household_id survey_date first_name middle_initial last_name  \
# 0       0_6874       0_2799  2020-01-28    Heather              J    Howard
# 1       0_6875       0_2799  2020-01-28   Cristina              E    Howard
# 2       0_6876       0_2799  2020-01-28      Chloe              G    Howard
# 3       0_1804          0_3  2020-04-21   Benjamin              M  Mcmillon
# 4       0_1928          0_3  2020-04-21    Lucille              C     Smith
# ..         ...          ...         ...        ...            ...       ...
# 84     0_15064       0_6067  2020-08-11    Jeffrey              J   Deakins
# 85     0_12124       0_4898  2020-10-06    Raymond              J    Valdez
# 86     0_20535       0_4898  2020-10-06      Ronin              K    Valdez
# 87      0_4986       0_2040  2020-11-03      Sarah              G  Wilbanks
# 88      0_2896       0_1179  2020-12-01    Katelyn              A    Nelson
#
#    age date_of_birth street_number          street_name     unit_number  \
# 0   45    11/21/1974          3670             pearl dr             NaN
# 1    9    09/12/2010          3670             pearl dr             NaN
# 2    8    11/23/2011          3670             pearl dr             NaN
# 3   21    01/09/1999          8203  west farwell avenue             NaN
# 4   81    12/10/1938          8203  west farwell avenue             NaN
# ..  ..           ...           ...                  ...             ...
# 84  50    05/10/1977          4209              yost ln             NaN
# 85  16    10/22/2003           820         cameron road             NaN
# 86   0    08/04/2020           820         cameron road             NaN
# 87  61    06/28/1959           282          rathford dr  no 682 level 6
# 88  33    12/04/1989        111-24          gonzalez dr      apt # 5002
#
#             city state zipcode relationship_to_reference_person     sex  \
# 0       lawrence    KS   66046                   Opp-sex spouse  Female
# 1       lawrence    KS   66046                 Biological child  Female
# 2       lawrence    KS   66046                 Biological child  Female
# 3        augusta    GA   30350      Noninstitutionalized GQ pop    Male
# 4        augusta    GA   30350      Noninstitutionalized GQ pop  Female
# ..           ...   ...     ...                              ...     ...
# 84         bixby    OK   73013                  Same-sex spouse    Male
# 85  new york cty    NY   14120                 Biological child    Male
# 86  new york cty    NY   14120                 Biological child    Male
# 87    brookhaven    NY   14201                 Reference person  Female
# 88    clearwater    FL   34491                   Opp-sex spouse  Female
#
#    race_ethnicity
# 0           White
# 1           White
# 2           White
# 3           White
# 4           Black
# ..            ...
# 84          White
# 85          Asian
# 86          Asian
# 87          White
# 88          White
#
# [89 rows x 17 columns]

# %% [markdown]
# # Does SSN column in 1040 contain both SSNs and ITINs, or are ITIN rows just missing?
#
# Answer from SWEs: The SSN column currently only contains SSNs, with no ITINs. So presumably people with ITINs will just have NaN for their SSN in the current data.

# %%
data.taxes_1040.ssn.isna().sum()
# Out:
# 509

# %%
# Calculate percent missing
100 * data.taxes_1040.ssn.isna().sum() / len(data.taxes_1040.ssn.isna())
# Out:
# 4.118789448130766

# %%
# There should only be 1% missing if missingness were just due to noise
config['taxes_1040']['column_noise']['ssn']
# Out:
# {'leave_blank': {'cell_probability': 0.01},
#  'copy_from_household_member': {'cell_probability': 0.01},
#  'write_wrong_digits': {'cell_probability': 0.01, 'token_probability': 0.1},
#  'make_ocr_errors': {'cell_probability': 0.01, 'token_probability': 0.1},
#  'make_typos': {'cell_probability': 0.01, 'token_probability': 0.1}}

# %% [markdown]
# # Does it work to pass `NO_NOISE` when generating a dataset?

# %%
# %%time
wic0 = psp.generate_women_infants_and_children(config=psp.NO_NOISE)
wic0
# Out:
# CPU times: user 468 ms, sys: 3.06 ms, total: 471 ms
# Wall time: 468 ms
#     simulant_id household_id first_name middle_initial        last_name  \
# 0          0_58         0_27       Anna              A          Terrell
# 1         0_725        0_288   Samantha              S            Ohara
# 2        0_1176        0_474  Stephanie              A  Martinez Burgos
# 3        0_1177        0_475       Anna              M            Dixon
# 4        0_1312        0_527       Sara              S          Farrell
# ..          ...          ...        ...            ...              ...
# 304     0_20356       0_6751      Wyatt              H            Lopez
# 305     0_20357       0_6765   Benjamin              R          Quigley
# 306     0_20362       0_7561      Miles              M         Kinneman
# 307     0_20363       0_5570    Donovan              P          Hansley
# 308     0_20364       0_5827       Kira              M          Bridges
#
#     date_of_birth street_number      street_name unit_number  \
# 0        03071986            20          jill pl         NaN
# 1        07281999           NaN       keemont dr        # 63
# 2        10041996          2509     w venturi dr         NaN
# 3        11011994          4525  princess anne r         NaN
# 4        11291986           829       second ave         NaN
# ..            ...           ...              ...         ...
# 304      01192020           716     armory drive         NaN
# 305      01222020         13209     ne milton st         NaN
# 306      01072020          6258     pinestead dr         NaN
# 307      01202020          9618      western ave         NaN
# 308      01042020          2626    terrace hl dv         NaN
#
#                  city state zipcode     sex race_ethnicity  year
# 0             detroit    MI   49635  Female          White  2020
# 1              auburn    KS   67460  Female          White  2020
# 2            portland    OR   97301  Female         Latino  2020
# 3        philadelphia    PA   19124  Female          Black  2020
# 4    steamboat sprngs    CO   80204  Female         Latino  2020
# ..                ...   ...     ...     ...            ...   ...
# 304          carlsbad    CA   91340    Male         Latino  2020
# 305        lauderhill    FL   32563    Male          White  2020
# 306            geneva    IL   60540    Male          White  2020
# 307    old bridge twp    NJ   08846    Male          Black  2020
# 308         lancaster    CA   94509  Female          Black  2020
#
# [309 rows x 15 columns]

# %%
# %%time
w2_0 = psp.generate_taxes_w2_and_1099(config=psp.NO_NOISE)
w2_0
# Out:
# CPU times: user 1.9 s, sys: 75.8 ms, total: 1.97 s
# Wall time: 1.96 s
#       simulant_id household_id first_name middle_initial last_name age  \
# 0             0_0          0_6     Gerald              R   Sorrell  70
# 1             0_1          0_6    Earline              R   Sorrell  64
# 2             0_2          0_7      Diana              P     Kelly  26
# 3             0_2          0_7      Diana              P     Kelly  26
# 4             0_3          0_7       Anna              A     Kelly  26
# ...           ...          ...        ...            ...       ...  ..
# 18737     0_20629       0_8599     Jamone              B   Tercero  27
# 18738     0_20631       0_8600     Ashley              E     Cooke  33
# 18739     0_20657       0_3505    Yesenia              K   Kilgore  19
# 18740     0_20659       0_5225       Eric              C   Mcilwee  43
# 18741     0_20660       0_8625     Denise              J  Lockwood  71
#
#       date_of_birth mailing_address_street_number mailing_address_street_name  \
# 0        01/18/1950                           NaN                 barbara cir
# 1        12/23/1956                           NaN                 barbara cir
# 2        05/06/1994                          5112                    145th st
# 3        05/06/1994                          5112                    145th st
# 4        09/29/1994                          5112                    145th st
# ...             ...                           ...                         ...
# 18737    05/01/1993                         11001               e johnson ave
# 18738    08/23/1987
# 18739    10/25/2001                           710                 n dancer rd
# 18740    11/11/1977                          3195                 woodglen dr
# 18741    10/03/1949                           943                 s wabash av
#
#       mailing_address_unit_number  ... employer_id  \
# 0                             NaN  ...         100
# 1                             NaN  ...          78
# 2                             NaN  ...          27
# 3                             NaN  ...          95
# 4                             NaN  ...          23
# ...                           ...  ...         ...
# 18737                         NaN  ...         104
# 18738                              ...          60
# 18739                         NaN  ...          90
# 18740                         NaN  ...          41
# 18741                         NaN  ...          90
#
#                               employer_name employer_street_number  \
# 0      Twin Boro Auto Repair Service (USPS)                    NaN
# 1              Autism and Bob's Big Louie's                   1960
# 2            The Wicked Pho Licious Burgers                   5525
# 3                    Pikes Creek Campground                      e
# 4                 Greenway Med Spa Services                    631
# ...                                     ...                    ...
# 18737  San Benito Martinez Landscape Supply                   4212
# 18738              Freeway Insurance Agency                   1105
# 18739           Northwell Health Center Inc                    NaN
# 18740                              Aquarium                   2916
# 18741           Northwell Health Center Inc                    NaN
#
#       employer_street_name employer_unit_number   employer_city  \
# 0             edgecliff ct                  NaN        kingston
# 1              skyview ter             unit 170         houston
# 2             r r property                  NaN    independence
# 3                  ince dr                  NaN  virginia beach
# 4               regent ave                  NaN            mena
# ...                    ...                  ...             ...
# 18737     morning vista dr                  NaN     beavercreek
# 18738           largess ln                  NaN       milwaukee
# 18739         barge roa sw                  NaN      washington
# 18740            4th ave w                  NaN  citrus heights
# 18741         barge roa sw                  NaN      washington
#
#       employer_state employer_zipcode tax_form tax_year
# 0                 NY            12180       W2     2020
# 1                 TX            78543       W2     2020
# 2                 MO            65401       W2     2020
# 3                 VA            22026       W2     2020
# 4                 AR            71744       W2     2020
# ...              ...              ...      ...      ...
# 18737             OH            44281       W2     2020
# 18738             WI            53140       W2     2020
# 18739             DC            20016     1099     2020
# 18740             CA            92118       W2     2020
# 18741             DC            20016       W2     2020
#
# [18742 rows x 26 columns]

# %%
w2_0.isna().sum()
# Out:
# simulant_id                          0
# household_id                         0
# first_name                           0
# middle_initial                       0
# last_name                            0
# age                                  0
# date_of_birth                        0
# mailing_address_street_number      686
# mailing_address_street_name          0
# mailing_address_unit_number      17110
# mailing_address_po_box           18068
# mailing_address_city                 0
# mailing_address_state                0
# mailing_address_zipcode              0
# ssn                                  0
# wages                                0
# employer_id                          0
# employer_name                        0
# employer_street_number             765
# employer_street_name                 0
# employer_unit_number             17831
# employer_city                        0
# employer_state                       0
# employer_zipcode                     0
# tax_form                             0
# tax_year                             0
# dtype: int64

# %%
# %%time
t1040_0 = psp.generate_taxes_1040(config=psp.NO_NOISE)
t1040_0
# Out:
# CPU times: user 24.6 s, sys: 41.9 ms, total: 24.6 s
# Wall time: 24.6 s
#       simulant_id household_id first_name middle_initial   last_name  \
# 0             0_0          0_6     Gerald              R     Sorrell
# 1             0_2          0_7      Diana              P       Kelly
# 2             0_8          0_9  Elizabeth              P    Gonzalez
# 3            0_14         0_11     Gerald              R   Hutchison
# 4            0_17         0_12     Gerald              R    Mcintyre
# ...           ...          ...        ...            ...         ...
# 12353     0_20750          0_5    Michael              E     Longley
# 12354     0_20751       0_3336      Brody              J   Dominguez
# 12355     0_20753       0_2825   Jennifer              T  Concepcion
# 12356     0_20754       0_6380    Jazmine              A      Hughes
# 12357     0_20759       0_8741     Athena              G      Borkar
#
#       mailing_address_street_number mailing_address_street_name  \
# 0                               NaN                 barbara cir
# 1                              5112                    145th st
# 2                                12                 meridian st
# 3                               502                n bingham st
# 4                              2105                hyde park ln
# ...                             ...                         ...
# 12353                          4000            nw skycrest pkwy
# 12354                           120                   32 avenue
# 12355                          4920                    10th way
# 12356                          2690          norh e 65th street
# 12357                          3133              shady brook dr
#
#       mailing_address_unit_number mailing_address_po_box mailing_address_city  \
# 0                             NaN                    NaN         williamsburg
# 1                             NaN                    NaN             portland
# 2                             NaN                    NaN               albany
# 3                             NaN                    NaN              oakland
# 4                             NaN                    NaN               s bend
# ...                           ...                    ...                  ...
# 12353                         NaN                    NaN            new caney
# 12354                         NaN                    NaN          e brunswick
# 12355                         NaN                    NaN          painesville
# 12356                         NaN                    NaN           birmingham
# 12357                         NaN                    NaN             lockport
#
#        ... dependent_1_ssn dependent_2_first_name dependent_2_last_name  \
# 0      ...             NaN                    NaN                   NaN
# 1      ...             NaN                    NaN                   NaN
# 2      ...     268-18-4020                    NaN                   NaN
# 3      ...     462-01-8027                Dominic             Hutchison
# 4      ...             NaN                    NaN                   NaN
# ...    ...             ...                    ...                   ...
# 12353  ...             NaN                    NaN                   NaN
# 12354  ...             NaN                    NaN                   NaN
# 12355  ...             NaN                    NaN                   NaN
# 12356  ...             NaN                    NaN                   NaN
# 12357  ...             NaN                    NaN                   NaN
#
#       dependent_2_ssn dependent_3_first_name dependent_3_last_name  \
# 0                 NaN                    NaN                   NaN
# 1                 NaN                    NaN                   NaN
# 2                 NaN                    NaN                   NaN
# 3         178-81-4204                    NaN                   NaN
# 4                 NaN                    NaN                   NaN
# ...               ...                    ...                   ...
# 12353             NaN                    NaN                   NaN
# 12354             NaN                    NaN                   NaN
# 12355             NaN                    NaN                   NaN
# 12356             NaN                    NaN                   NaN
# 12357             NaN                    NaN                   NaN
#
#       dependent_3_ssn dependent_4_first_name dependent_4_last_name  \
# 0                 NaN                    NaN                   NaN
# 1                 NaN                    NaN                   NaN
# 2                 NaN                    NaN                   NaN
# 3                 NaN                    NaN                   NaN
# 4                 NaN                    NaN                   NaN
# ...               ...                    ...                   ...
# 12353             NaN                    NaN                   NaN
# 12354             NaN                    NaN                   NaN
# 12355             NaN                    NaN                   NaN
# 12356             NaN                    NaN                   NaN
# 12357             NaN                    NaN                   NaN
#
#       dependent_4_ssn
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 12353             NaN
# 12354             NaN
# 12355             NaN
# 12356             NaN
# 12357             NaN
#
# [12358 rows x 30 columns]

# %%
t1040_0.isna().sum()
# Out:
# simulant_id                          0
# household_id                         0
# first_name                           0
# middle_initial                       0
# last_name                            0
# mailing_address_street_number      485
# mailing_address_street_name          0
# mailing_address_unit_number      11231
# mailing_address_po_box           11909
# mailing_address_city                 0
# mailing_address_state                0
# mailing_address_zipcode              0
# ssn                                401
# tax_year                             0
# spouse_first_name                11101
# spouse_middle_initial            11101
# spouse_last_name                 11101
# spouse_ssn                       11172
# dependent_1_first_name            9927
# dependent_1_last_name             9927
# dependent_1_ssn                   9948
# dependent_2_first_name           11076
# dependent_2_last_name            11076
# dependent_2_ssn                  11084
# dependent_3_first_name           11900
# dependent_3_last_name            11900
# dependent_3_ssn                  11901
# dependent_4_first_name           12211
# dependent_4_last_name            12211
# dependent_4_ssn                  12211
# dtype: int64

# %% [markdown]
# # Try generating all datasets with no noise

# %%
# %%time
data0 = generate_data(config=psp.NO_NOISE)
data0.keylist()
# Out:
# CPU times: user 29.3 s, sys: 209 ms, total: 29.5 s
# Wall time: 29.5 s
# ['american_community_survey',
#  'current_population_survey',
#  'decennial_census',
#  'social_security',
#  'taxes_1040',
#  'taxes_w2_and_1099',
#  'women_infants_and_children']

# %%
data0.women_infants_and_children.equals(wic0)
# Out:
# True

# %%
data0.taxes_1040.equals(t1040_0)
# Out:
# True

# %%
data0.taxes_1040.equals(data.taxes_1040)
# Out:
# False

# %% [markdown]
# # Check how noisy some datasets are

# %%
alpha.percent_of_rows_with_difference(data.women_infants_and_children, data0.women_infants_and_children)
# Out:
# 21.035598705501616

# %%
alpha.percent_different_in_columns(data.women_infants_and_children, data0.women_infants_and_children)
# Out:
# simulant_id        0.000000
# household_id       0.000000
# first_name         2.912621
# middle_initial     1.618123
# last_name          1.941748
# date_of_birth      3.883495
# street_number      3.883495
# street_name        2.588997
# unit_number       94.174757
# city               3.559871
# state              1.941748
# zipcode            1.294498
# sex                2.265372
# race_ethnicity     0.647249
# year               0.000000
# dtype: float64

# %%
alpha.percent_different_in_columns(data.women_infants_and_children, data0.women_infants_and_children)
# Out:
# simulant_id       0.000000
# household_id      0.000000
# first_name        2.912621
# middle_initial    1.618123
# last_name         1.941748
# date_of_birth     3.883495
# street_number     0.647249
# street_name       2.588997
# unit_number       0.000000
# city              3.559871
# state             1.941748
# zipcode           1.294498
# sex               2.265372
# race_ethnicity    0.647249
# year              0.000000
# dtype: float64

# %%
alpha.percent_different_in_columns(data.taxes_1040, data0.taxes_1040)
# Out:
# simulant_id                      0.000000
# household_id                     0.000000
# first_name                       3.892216
# middle_initial                   1.019582
# last_name                        3.341965
# mailing_address_street_number    1.764039
# mailing_address_street_name      2.767438
# mailing_address_unit_number      0.080919
# mailing_address_po_box           0.097103
# mailing_address_city             2.468037
# mailing_address_state            1.925878
# mailing_address_zipcode          2.492313
# ssn                              3.261045
# tax_year                         0.000000
# spouse_first_name                0.461240
# spouse_middle_initial            0.089011
# spouse_last_name                 0.364137
# spouse_ssn                       1.302800
# dependent_1_first_name           0.712089
# dependent_1_last_name            0.550251
# dependent_1_ssn                  1.715488
# dependent_2_first_name           0.404596
# dependent_2_last_name            0.388412
# dependent_2_ssn                  1.173329
# dependent_3_first_name           0.137563
# dependent_3_last_name            0.064735
# dependent_3_ssn                  1.108594
# dependent_4_first_name           0.024276
# dependent_4_last_name            0.008092
# dependent_4_ssn                  1.003399
# dtype: float64

# %% [markdown]
# # Write a function to check percent missingness

# %%
def percent_missing(df):
    return 100 * df.isna().sum() / len(df)

# %%
percent_missing(data.taxes_1040)
# Out:
# simulant_id                       0.000000
# household_id                      0.000000
# first_name                        0.995307
# middle_initial                    0.890112
# last_name                         1.027674
# mailing_address_street_number     4.976533
# mailing_address_street_name       1.043858
# mailing_address_unit_number      90.904677
# mailing_address_po_box           96.382910
# mailing_address_city              0.962939
# mailing_address_state             0.954847
# mailing_address_zipcode           1.043858
# ssn                               4.118789
# tax_year                          0.000000
# spouse_first_name                89.933646
# spouse_middle_initial            89.917462
# spouse_last_name                 89.933646
# spouse_ssn                       90.516265
# dependent_1_first_name           80.538922
# dependent_1_last_name            80.522738
# dependent_1_ssn                  80.725036
# dependent_2_first_name           89.771808
# dependent_2_last_name            89.731348
# dependent_2_ssn                  89.771808
# dependent_3_first_name           96.334358
# dependent_3_last_name            96.301991
# dependent_3_ssn                  96.334358
# dependent_4_first_name           98.818579
# dependent_4_last_name            98.810487
# dependent_4_ssn                  98.810487
# dtype: float64

# %% [markdown]
# # Test module functions after copying code to `alpha.py`

# %%
# %%time
data00 = alpha.generate_datasets(config=psp.NO_NOISE)
data00.keylist()
# Out:
# CPU times: user 30 s, sys: 140 ms, total: 30.1 s
# Wall time: 30.1 s
# ['american_community_survey',
#  'current_population_survey',
#  'decennial_census',
#  'social_security',
#  'taxes_1040',
#  'taxes_w2_and_1099',
#  'women_infants_and_children']

# %%
data00.american_community_survey
# Out:
#    simulant_id household_id survey_date first_name middle_initial last_name  \
# 0       0_6874       0_2799  2020-01-28    Heather              J    Howard
# 1       0_6875       0_2799  2020-01-28   Cristina              E    Howard
# 2       0_6876       0_2799  2020-01-28      Chloe              G    Howard
# 3       0_1804          0_3  2020-04-21   Benjamin              M  Mcmillon
# 4       0_1928          0_3  2020-04-21    Lucille              C     Smith
# ..         ...          ...         ...        ...            ...       ...
# 84     0_15064       0_6067  2020-08-11    Jeffrey              J   Deakins
# 85     0_12124       0_4898  2020-10-06    Raymond              J    Valdez
# 86     0_20535       0_4898  2020-10-06      Ronin              K    Valdez
# 87      0_4986       0_2040  2020-11-03      Sarah              G  Wilbanks
# 88      0_2896       0_1179  2020-12-01    Katelyn              A    Nelson
#
#    age date_of_birth street_number          street_name     unit_number  \
# 0   45    11/21/1974          3670             pearl dr             NaN
# 1    9    09/12/2010          3670             pearl dr             NaN
# 2    8    11/23/2011          3670             pearl dr             NaN
# 3   21    01/09/1999          8203  west farwell avenue             NaN
# 4   81    12/10/1938          8203  west farwell avenue             NaN
# ..  ..           ...           ...                  ...             ...
# 84  50    08/06/1969          4209              yost ln             NaN
# 85  16    10/22/2003           820         cameron road             NaN
# 86   0    08/04/2020           820         cameron road             NaN
# 87  61    06/28/1959           282          rathford dr  no 682 level 6
# 88  30    12/04/1989        111-24          gonzalez dr      apt # 5002
#
#             city state zipcode relationship_to_reference_person     sex  \
# 0       lawrence    KS   66046                   Opp-sex spouse  Female
# 1       lawrence    KS   66046                 Biological child  Female
# 2       lawrence    KS   66046                 Biological child  Female
# 3        augusta    GA   30350      Noninstitutionalized GQ pop    Male
# 4        augusta    GA   30350      Noninstitutionalized GQ pop  Female
# ..           ...   ...     ...                              ...     ...
# 84         bixby    OK   73013                  Same-sex spouse    Male
# 85  new york cty    NY   14120                 Biological child    Male
# 86  new york cty    NY   14120                 Biological child    Male
# 87    brookhaven    NY   14201                 Reference person  Female
# 88    clearwater    FL   34491                   Opp-sex spouse  Female
#
#    race_ethnicity
# 0           White
# 1           White
# 2           White
# 3           White
# 4           Black
# ..            ...
# 84          White
# 85          Asian
# 86          Asian
# 87          White
# 88          White
#
# [89 rows x 17 columns]

# %%
config0 = alpha.get_zero_noise_config()
config0
# Out:
# {'decennial_census': {'row_noise': {'do_not_respond': {'row_probability': 0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'misreport_age': {'cell_probability': 0,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'swap_month_and_day': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'zipcode': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'relationship_to_reference_person': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'sex': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}}}},
#  'american_community_survey': {'row_noise': {'do_not_respond': {'row_probability': 0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'misreport_age': {'cell_probability': 0,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'swap_month_and_day': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'zipcode': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'relationship_to_reference_person': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'sex': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}}}},
#  'current_population_survey': {'row_noise': {'do_not_respond': {'row_probability': 0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'misreport_age': {'cell_probability': 0,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'swap_month_and_day': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'zipcode': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'sex': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}}}},
#  'women_infants_and_children': {'row_noise': {'omit_row': {'row_probability': 0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'swap_month_and_day': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'street_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'street_name': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'unit_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'city': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'state': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'zipcode': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'sex': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'race_ethnicity': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}}}},
#  'social_security': {'row_noise': {'omit_row': {'row_probability': 0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'middle_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'swap_month_and_day': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'sex': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'ssn': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'event_type': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'event_date': {'leave_blank': {'cell_probability': 0},
#     'swap_month_and_day': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}}}},
#  'taxes_w2_and_1099': {'row_noise': {'omit_row': {'row_probability': 0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'age': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'misreport_age': {'cell_probability': 0,
#      'possible_age_differences': {-2: 0.1, -1: 0.4, 1: 0.4, 2: 0.1}},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'date_of_birth': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'swap_month_and_day': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_street_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_street_name': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_unit_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_po_box': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_city': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_state': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'mailing_address_zipcode': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'ssn': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'wages': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'employer_name': {'leave_blank': {'cell_probability': 0},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'employer_street_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'employer_street_name': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'employer_unit_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'employer_city': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'employer_state': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'employer_zipcode': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'tax_form': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}}}},
#  'taxes_1040': {'row_noise': {'omit_row': {'row_probability': 0}},
#   'column_noise': {'first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'middle_initial': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_street_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_street_name': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_unit_number': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_po_box': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_city': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'mailing_address_state': {'leave_blank': {'cell_probability': 0},
#     'choose_wrong_option': {'cell_probability': 0}},
#    'mailing_address_zipcode': {'leave_blank': {'cell_probability': 0},
#     'write_wrong_zipcode_digits': {'cell_probability': 0,
#      'digit_probabilities': [0.04, 0.04, 0.2, 0.36, 0.36]},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'ssn': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'spouse_first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'spouse_middle_initial': {'leave_blank': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'spouse_last_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'spouse_ssn': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_1_first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_1_last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_1_ssn': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_2_first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_2_last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_2_ssn': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_3_first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_3_last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_3_ssn': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_4_first_name': {'leave_blank': {'cell_probability': 0},
#     'use_nickname': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_4_last_name': {'leave_blank': {'cell_probability': 0},
#     'use_fake_name': {'cell_probability': 0},
#     'make_phonetic_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}},
#    'dependent_4_ssn': {'leave_blank': {'cell_probability': 0},
#     'copy_from_household_member': {'cell_probability': 0},
#     'write_wrong_digits': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_ocr_errors': {'cell_probability': 0, 'token_probability': 0.1},
#     'make_typos': {'cell_probability': 0, 'token_probability': 0.1}}}}}

# %%
f = getattr(psp, 'generate_taxes_1040')
f
# Out:
# <function pseudopeople.interface.generate_taxes_1040(source: Union[pathlib.Path, str] = None, seed: int = 0, config: Union[pathlib.Path, str, Dict[str, Dict]] = None, year: Optional[int] = 2020, state: Optional[str] = None, verbose: bool = False) -> pandas.core.frame.DataFrame>

# %%
f.__class__
# Out:
# function

# %%
conda list
# Out:
# # packages in environment at /ihme/homes/ndbs/miniconda3/envs/pppl310:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# alabaster                 0.7.13                   pypi_0    pypi
# anyio                     3.7.1                    pypi_0    pypi
# argon2-cffi               21.3.0                   pypi_0    pypi
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# arrow                     1.2.3                    pypi_0    pypi
# asttokens                 2.2.1                    pypi_0    pypi
# async-lru                 2.0.4                    pypi_0    pypi
# attrs                     23.1.0                   pypi_0    pypi
# babel                     2.12.1                   pypi_0    pypi
# backcall                  0.2.0                    pypi_0    pypi
# beautifulsoup4            4.12.2                   pypi_0    pypi
# bleach                    6.0.0                    pypi_0    pypi
# blosc2                    2.0.0                    pypi_0    pypi
# bzip2                     1.0.8                h7f98852_4    conda-forge
# ca-certificates           2023.7.22            hbcca054_0    conda-forge
# certifi                   2023.7.22                pypi_0    pypi
# cffi                      1.15.1                   pypi_0    pypi
# charset-normalizer        3.2.0                    pypi_0    pypi
# click                     8.1.6                    pypi_0    pypi
# comm                      0.1.3                    pypi_0    pypi
# contourpy                 1.1.0                    pypi_0    pypi
# cycler                    0.11.0                   pypi_0    pypi
# cython                    3.0.0                    pypi_0    pypi
# debugpy                   1.6.7                    pypi_0    pypi
# decorator                 5.1.1                    pypi_0    pypi
# defusedxml                0.7.1                    pypi_0    pypi
# docutils                  0.18.1                   pypi_0    pypi
# exceptiongroup            1.1.2                    pypi_0    pypi
# executing                 1.2.0                    pypi_0    pypi
# fastjsonschema            2.18.0                   pypi_0    pypi
# fonttools                 4.41.1                   pypi_0    pypi
# fqdn                      1.5.1                    pypi_0    pypi
# idna                      3.4                      pypi_0    pypi
# imagesize                 1.4.1                    pypi_0    pypi
# iniconfig                 2.0.0                    pypi_0    pypi
# ipykernel                 6.25.0                   pypi_0    pypi
# ipython                   8.14.0                   pypi_0    pypi
# ipython-genutils          0.2.0                    pypi_0    pypi
# ipywidgets                8.0.7                    pypi_0    pypi
# isoduration               20.11.0                  pypi_0    pypi
# jedi                      0.18.2                   pypi_0    pypi
# jinja2                    3.1.2                    pypi_0    pypi
# json5                     0.9.14                   pypi_0    pypi
# jsonpointer               2.4                      pypi_0    pypi
# jsonschema                4.18.4                   pypi_0    pypi
# jsonschema-specifications 2023.7.1                 pypi_0    pypi
# jupyter                   1.0.0                    pypi_0    pypi
# jupyter-client            8.3.0                    pypi_0    pypi
# jupyter-console           6.6.3                    pypi_0    pypi
# jupyter-core              5.3.1                    pypi_0    pypi
# jupyter-events            0.6.3                    pypi_0    pypi
# jupyter-lsp               2.2.0                    pypi_0    pypi
# jupyter-server            2.7.0                    pypi_0    pypi
# jupyter-server-terminals  0.4.4                    pypi_0    pypi
# jupyterlab                4.0.3                    pypi_0    pypi
# jupyterlab-pygments       0.2.2                    pypi_0    pypi
# jupyterlab-server         2.24.0                   pypi_0    pypi
# jupyterlab-widgets        3.0.8                    pypi_0    pypi
# kiwisolver                1.4.4                    pypi_0    pypi
# ld_impl_linux-64          2.40                 h41732ed_0    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libgcc-ng                 13.1.0               he5830b7_0    conda-forge
# libgomp                   13.1.0               he5830b7_0    conda-forge
# libnsl                    2.0.0                h7f98852_0    conda-forge
# libsqlite                 3.42.0               h2797004_0    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libzlib                   1.2.13               hd590300_5    conda-forge
# loguru                    0.7.0                    pypi_0    pypi
# markupsafe                2.1.3                    pypi_0    pypi
# matplotlib                3.7.2                    pypi_0    pypi
# matplotlib-inline         0.1.6                    pypi_0    pypi
# mistune                   3.0.1                    pypi_0    pypi
# msgpack                   1.0.5                    pypi_0    pypi
# nbclient                  0.8.0                    pypi_0    pypi
# nbconvert                 7.7.3                    pypi_0    pypi
# nbformat                  5.9.1                    pypi_0    pypi
# ncurses                   6.4                  hcb278e6_0    conda-forge
# nest-asyncio              1.5.6                    pypi_0    pypi
# networkx                  3.1                      pypi_0    pypi
# notebook                  7.0.0                    pypi_0    pypi
# notebook-shim             0.2.3                    pypi_0    pypi
# numexpr                   2.8.4                    pypi_0    pypi
# numpy                     1.25.1                   pypi_0    pypi
# openssl                   3.1.1                hd590300_1    conda-forge
# overrides                 7.3.1                    pypi_0    pypi
# packaging                 23.1                     pypi_0    pypi
# pandas                    1.5.3                    pypi_0    pypi
# pandocfilters             1.5.0                    pypi_0    pypi
# parso                     0.8.3                    pypi_0    pypi
# pexpect                   4.8.0                    pypi_0    pypi
# pickleshare               0.7.5                    pypi_0    pypi
# pillow                    10.0.0                   pypi_0    pypi
# pip                       23.2.1             pyhd8ed1ab_0    conda-forge
# platformdirs              3.9.1                    pypi_0    pypi
# pluggy                    1.2.0                    pypi_0    pypi
# prometheus-client         0.17.1                   pypi_0    pypi
# prompt-toolkit            3.0.39                   pypi_0    pypi
# pseudopeople              0.6.5                    pypi_0    pypi
# psutil                    5.9.5                    pypi_0    pypi
# ptyprocess                0.7.0                    pypi_0    pypi
# pure-eval                 0.2.2                    pypi_0    pypi
# py-cpuinfo                9.0.0                    pypi_0    pypi
# pyarrow                   12.0.1                   pypi_0    pypi
# pycparser                 2.21                     pypi_0    pypi
# pygments                  2.15.1                   pypi_0    pypi
# pyparsing                 3.0.9                    pypi_0    pypi
# pytest                    7.4.0                    pypi_0    pypi
# pytest-mock               3.11.1                   pypi_0    pypi
# python                    3.10.12         hd12c33a_0_cpython    conda-forge
# python-dateutil           2.8.2                    pypi_0    pypi
# python-json-logger        2.0.7                    pypi_0    pypi
# pytz                      2023.3                   pypi_0    pypi
# pyyaml                    6.0.1                    pypi_0    pypi
# pyzmq                     25.1.0                   pypi_0    pypi
# qtconsole                 5.4.3                    pypi_0    pypi
# qtpy                      2.3.1                    pypi_0    pypi
# readline                  8.2                  h8228510_1    conda-forge
# referencing               0.30.0                   pypi_0    pypi
# requests                  2.31.0                   pypi_0    pypi
# rfc3339-validator         0.1.4                    pypi_0    pypi
# rfc3986-validator         0.1.1                    pypi_0    pypi
# rpds-py                   0.9.2                    pypi_0    pypi
# scipy                     1.11.1                   pypi_0    pypi
# send2trash                1.8.2                    pypi_0    pypi
# setuptools                68.0.0             pyhd8ed1ab_0    conda-forge
# six                       1.16.0                   pypi_0    pypi
# sniffio                   1.3.0                    pypi_0    pypi
# snowballstemmer           2.2.0                    pypi_0    pypi
# soupsieve                 2.4.1                    pypi_0    pypi
# sphinx                    6.2.1                    pypi_0    pypi
# sphinx-click              4.4.0                    pypi_0    pypi
# sphinx-rtd-theme          1.2.2                    pypi_0    pypi
# sphinxcontrib-applehelp   1.0.4                    pypi_0    pypi
# sphinxcontrib-devhelp     1.0.2                    pypi_0    pypi
# sphinxcontrib-htmlhelp    2.0.1                    pypi_0    pypi
# sphinxcontrib-jquery      4.1                      pypi_0    pypi
# sphinxcontrib-jsmath      1.0.1                    pypi_0    pypi
# sphinxcontrib-qthelp      1.0.3                    pypi_0    pypi
# sphinxcontrib-serializinghtml 1.1.5                    pypi_0    pypi
# stack-data                0.6.2                    pypi_0    pypi
# tables                    3.8.0                    pypi_0    pypi
# terminado                 0.17.1                   pypi_0    pypi
# tinycss2                  1.2.1                    pypi_0    pypi
# tk                        8.6.12               h27826a3_0    conda-forge
# tomli                     2.0.1                    pypi_0    pypi
# tornado                   6.3.2                    pypi_0    pypi
# tqdm                      4.65.0                   pypi_0    pypi
# traitlets                 5.9.0                    pypi_0    pypi
# typing-extensions         4.7.1                    pypi_0    pypi
# tzdata                    2023.3                   pypi_0    pypi
# uri-template              1.3.0                    pypi_0    pypi
# urllib3                   2.0.4                    pypi_0    pypi
# vivarium                  1.2.1                    pypi_0    pypi
# vivarium-research-prl     0.0.1                     dev_0    <develop>
# wcwidth                   0.2.6                    pypi_0    pypi
# webcolors                 1.13                     pypi_0    pypi
# webencodings              0.5.1                    pypi_0    pypi
# websocket-client          1.6.1                    pypi_0    pypi
# wheel                     0.41.0             pyhd8ed1ab_0    conda-forge
# widgetsnbextension        4.0.8                    pypi_0    pypi
# xz                        5.2.6                h166bdaf_0    conda-forge
#
# Note: you may need to restart the kernel to use updated packages.

# %%
psp.generate_taxes_1040()
# Out:
#       simulant_id household_id first_name middle_initial   last_name  \
# 0             0_0          0_6     Gerald              R     Sorrell
# 1             0_2          0_7      Diana              P       Kelly
# 2             0_8          0_9  Elizabeth              P    Gonzalez
# 3            0_14         0_11     Gerald              R   Hutchison
# 4            0_17         0_12     Gerald              R    Mcintyre
# ...           ...          ...        ...            ...         ...
# 12353     0_20750          0_5    Michael              E     Longley
# 12354     0_20751       0_3336      Brody              J   Dominguez
# 12355     0_20753       0_2825   Jennifer              T  Concepcion
# 12356     0_20754       0_6380    Jazmine              A      Hughes
# 12357     0_20759       0_8741     Athena              G      Borkar
#
#       mailing_address_street_number mailing_address_street_name  \
# 0                               NaN                 barbara cir
# 1                              5112                         NaN
# 2                                12                 meridian st
# 3                               502                n bingham st
# 4                              2105                hyde park ln
# ...                             ...                         ...
# 12353                          4000            nw skycrest pkwy
# 12354                           120                   32 avenue
# 12355                          4920                    10th way
# 12356                          2690          norh e 65th street
# 12357                          3133              shady brook dr
#
#       mailing_address_unit_number mailing_address_po_box mailing_address_city  \
# 0                             NaN                    NaN         williamsburg
# 1                             NaN                    NaN             portland
# 2                             NaN                    NaN               albany
# 3                             NaN                    NaN              oakland
# 4                             NaN                    NaN               s bend
# ...                           ...                    ...                  ...
# 12353                         NaN                    NaN            new caney
# 12354                         NaN                    NaN          e brunswick
# 12355                         NaN                    NaN          painesville
# 12356                         NaN                    NaN           birmingham
# 12357                         NaN                    NaN             lockport
#
#        ... dependent_1_ssn dependent_2_first_name dependent_2_last_name  \
# 0      ...             NaN                    NaN                   NaN
# 1      ...             NaN                    NaN                   NaN
# 2      ...     395-30-9975                    NaN                   NaN
# 3      ...     462-01-8027                Dominic             Hutchison
# 4      ...             NaN                    NaN                   NaN
# ...    ...             ...                    ...                   ...
# 12353  ...             NaN                    NaN                   NaN
# 12354  ...             NaN                    NaN                   NaN
# 12355  ...             NaN                    NaN                   NaN
# 12356  ...             NaN                    NaN                   NaN
# 12357  ...             NaN                    NaN                   NaN
#
#       dependent_2_ssn dependent_3_first_name dependent_3_last_name  \
# 0                 NaN                    NaN                   NaN
# 1                 NaN                    NaN                   NaN
# 2                 NaN                    NaN                   NaN
# 3         178-81-4204                    NaN                   NaN
# 4                 NaN                    NaN                   NaN
# ...               ...                    ...                   ...
# 12353             NaN                    NaN                   NaN
# 12354             NaN                    NaN                   NaN
# 12355             NaN                    NaN                   NaN
# 12356             NaN                    NaN                   NaN
# 12357             NaN                    NaN                   NaN
#
#       dependent_3_ssn dependent_4_first_name dependent_4_last_name  \
# 0                 NaN                    NaN                   NaN
# 1                 NaN                    NaN                   NaN
# 2                 NaN                    NaN                   NaN
# 3                 NaN                    NaN                   NaN
# 4                 NaN                    NaN                   NaN
# ...               ...                    ...                   ...
# 12353             NaN                    NaN                   NaN
# 12354             NaN                    NaN                   NaN
# 12355             NaN                    NaN                   NaN
# 12356             NaN                    NaN                   NaN
# 12357             NaN                    NaN                   NaN
#
#       dependent_4_ssn
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 12353             NaN
# 12354             NaN
# 12355             NaN
# 12356             NaN
# 12357             NaN
#
# [12358 rows x 30 columns]

# %%
conda_env_other = """
# packages in environment at /ihme/homes/ndbs/miniconda3/envs/pppl310:
#
# Name                    Version                   Build  Channel
_libgcc_mutex             0.1                 conda_forge    conda-forge
_openmp_mutex             4.5                       2_gnu    conda-forge
alabaster                 0.7.13                   pypi_0    pypi
anyio                     3.7.1                    pypi_0    pypi
argon2-cffi               21.3.0                   pypi_0    pypi
argon2-cffi-bindings      21.2.0                   pypi_0    pypi
arrow                     1.2.3                    pypi_0    pypi
asttokens                 2.2.1                    pypi_0    pypi
async-lru                 2.0.4                    pypi_0    pypi
attrs                     23.1.0                   pypi_0    pypi
babel                     2.12.1                   pypi_0    pypi
backcall                  0.2.0                    pypi_0    pypi
beautifulsoup4            4.12.2                   pypi_0    pypi
bleach                    6.0.0                    pypi_0    pypi
blosc2                    2.0.0                    pypi_0    pypi
bzip2                     1.0.8                h7f98852_4    conda-forge
ca-certificates           2023.7.22            hbcca054_0    conda-forge
certifi                   2023.7.22                pypi_0    pypi
cffi                      1.15.1                   pypi_0    pypi
charset-normalizer        3.2.0                    pypi_0    pypi
click                     8.1.6                    pypi_0    pypi
comm                      0.1.3                    pypi_0    pypi
contourpy                 1.1.0                    pypi_0    pypi
cycler                    0.11.0                   pypi_0    pypi
cython                    3.0.0                    pypi_0    pypi
debugpy                   1.6.7                    pypi_0    pypi
decorator                 5.1.1                    pypi_0    pypi
defusedxml                0.7.1                    pypi_0    pypi
docutils                  0.18.1                   pypi_0    pypi
exceptiongroup            1.1.2                    pypi_0    pypi
executing                 1.2.0                    pypi_0    pypi
fastjsonschema            2.18.0                   pypi_0    pypi
fonttools                 4.41.1                   pypi_0    pypi
fqdn                      1.5.1                    pypi_0    pypi
idna                      3.4                      pypi_0    pypi
imagesize                 1.4.1                    pypi_0    pypi
iniconfig                 2.0.0                    pypi_0    pypi
ipykernel                 6.25.0                   pypi_0    pypi
ipython                   8.14.0                   pypi_0    pypi
ipython-genutils          0.2.0                    pypi_0    pypi
ipywidgets                8.0.7                    pypi_0    pypi
isoduration               20.11.0                  pypi_0    pypi
jedi                      0.18.2                   pypi_0    pypi
jinja2                    3.1.2                    pypi_0    pypi
json5                     0.9.14                   pypi_0    pypi
jsonpointer               2.4                      pypi_0    pypi
jsonschema                4.18.4                   pypi_0    pypi
jsonschema-specifications 2023.7.1                 pypi_0    pypi
jupyter                   1.0.0                    pypi_0    pypi
jupyter-client            8.3.0                    pypi_0    pypi
jupyter-console           6.6.3                    pypi_0    pypi
jupyter-core              5.3.1                    pypi_0    pypi
jupyter-events            0.6.3                    pypi_0    pypi
jupyter-lsp               2.2.0                    pypi_0    pypi
jupyter-server            2.7.0                    pypi_0    pypi
jupyter-server-terminals  0.4.4                    pypi_0    pypi
jupyterlab                4.0.3                    pypi_0    pypi
jupyterlab-pygments       0.2.2                    pypi_0    pypi
jupyterlab-server         2.24.0                   pypi_0    pypi
jupyterlab-widgets        3.0.8                    pypi_0    pypi
kiwisolver                1.4.4                    pypi_0    pypi
ld_impl_linux-64          2.40                 h41732ed_0    conda-forge
libffi                    3.4.2                h7f98852_5    conda-forge
libgcc-ng                 13.1.0               he5830b7_0    conda-forge
libgomp                   13.1.0               he5830b7_0    conda-forge
libnsl                    2.0.0                h7f98852_0    conda-forge
libsqlite                 3.42.0               h2797004_0    conda-forge
libuuid                   2.38.1               h0b41bf4_0    conda-forge
libzlib                   1.2.13               hd590300_5    conda-forge
loguru                    0.7.0                    pypi_0    pypi
markupsafe                2.1.3                    pypi_0    pypi
matplotlib                3.7.2                    pypi_0    pypi
matplotlib-inline         0.1.6                    pypi_0    pypi
mistune                   3.0.1                    pypi_0    pypi
msgpack                   1.0.5                    pypi_0    pypi
nbclient                  0.8.0                    pypi_0    pypi
nbconvert                 7.7.3                    pypi_0    pypi
nbformat                  5.9.1                    pypi_0    pypi
ncurses                   6.4                  hcb278e6_0    conda-forge
nest-asyncio              1.5.6                    pypi_0    pypi
networkx                  3.1                      pypi_0    pypi
notebook                  7.0.0                    pypi_0    pypi
notebook-shim             0.2.3                    pypi_0    pypi
numexpr                   2.8.4                    pypi_0    pypi
numpy                     1.25.1                   pypi_0    pypi
openssl                   3.1.1                hd590300_1    conda-forge
overrides                 7.3.1                    pypi_0    pypi
packaging                 23.1                     pypi_0    pypi
pandas                    1.5.3                    pypi_0    pypi
pandocfilters             1.5.0                    pypi_0    pypi
parso                     0.8.3                    pypi_0    pypi
pexpect                   4.8.0                    pypi_0    pypi
pickleshare               0.7.5                    pypi_0    pypi
pillow                    10.0.0                   pypi_0    pypi
pip                       23.2.1             pyhd8ed1ab_0    conda-forge
platformdirs              3.9.1                    pypi_0    pypi
pluggy                    1.2.0                    pypi_0    pypi
prometheus-client         0.17.1                   pypi_0    pypi
prompt-toolkit            3.0.39                   pypi_0    pypi
pseudopeople              0.6.5                    pypi_0    pypi
psutil                    5.9.5                    pypi_0    pypi
ptyprocess                0.7.0                    pypi_0    pypi
pure-eval                 0.2.2                    pypi_0    pypi
py-cpuinfo                9.0.0                    pypi_0    pypi
pyarrow                   12.0.1                   pypi_0    pypi
pycparser                 2.21                     pypi_0    pypi
pygments                  2.15.1                   pypi_0    pypi
pyparsing                 3.0.9                    pypi_0    pypi
pytest                    7.4.0                    pypi_0    pypi
pytest-mock               3.11.1                   pypi_0    pypi
python                    3.10.12         hd12c33a_0_cpython    conda-forge
python-dateutil           2.8.2                    pypi_0    pypi
python-json-logger        2.0.7                    pypi_0    pypi
pytz                      2023.3                   pypi_0    pypi
pyyaml                    6.0.1                    pypi_0    pypi
pyzmq                     25.1.0                   pypi_0    pypi
qtconsole                 5.4.3                    pypi_0    pypi
qtpy                      2.3.1                    pypi_0    pypi
readline                  8.2                  h8228510_1    conda-forge
referencing               0.30.0                   pypi_0    pypi
requests                  2.31.0                   pypi_0    pypi
rfc3339-validator         0.1.4                    pypi_0    pypi
rfc3986-validator         0.1.1                    pypi_0    pypi
rpds-py                   0.9.2                    pypi_0    pypi
scipy                     1.11.1                   pypi_0    pypi
send2trash                1.8.2                    pypi_0    pypi
setuptools                68.0.0             pyhd8ed1ab_0    conda-forge
six                       1.16.0                   pypi_0    pypi
sniffio                   1.3.0                    pypi_0    pypi
snowballstemmer           2.2.0                    pypi_0    pypi
soupsieve                 2.4.1                    pypi_0    pypi
sphinx                    6.2.1                    pypi_0    pypi
sphinx-click              4.4.0                    pypi_0    pypi
sphinx-rtd-theme          1.2.2                    pypi_0    pypi
sphinxcontrib-applehelp   1.0.4                    pypi_0    pypi
sphinxcontrib-devhelp     1.0.2                    pypi_0    pypi
sphinxcontrib-htmlhelp    2.0.1                    pypi_0    pypi
sphinxcontrib-jquery      4.1                      pypi_0    pypi
sphinxcontrib-jsmath      1.0.1                    pypi_0    pypi
sphinxcontrib-qthelp      1.0.3                    pypi_0    pypi
sphinxcontrib-serializinghtml 1.1.5                    pypi_0    pypi
stack-data                0.6.2                    pypi_0    pypi
tables                    3.8.0                    pypi_0    pypi
terminado                 0.17.1                   pypi_0    pypi
tinycss2                  1.2.1                    pypi_0    pypi
tk                        8.6.12               h27826a3_0    conda-forge
tomli                     2.0.1                    pypi_0    pypi
tornado                   6.3.2                    pypi_0    pypi
tqdm                      4.65.0                   pypi_0    pypi
traitlets                 5.9.0                    pypi_0    pypi
typing-extensions         4.7.1                    pypi_0    pypi
tzdata                    2023.3                   pypi_0    pypi
uri-template              1.3.0                    pypi_0    pypi
urllib3                   2.0.4                    pypi_0    pypi
vivarium                  1.2.1                    pypi_0    pypi
vivarium-research-prl     0.0.1                     dev_0    <develop>
wcwidth                   0.2.6                    pypi_0    pypi
webcolors                 1.13                     pypi_0    pypi
webencodings              0.5.1                    pypi_0    pypi
websocket-client          1.6.1                    pypi_0    pypi
wheel                     0.41.0             pyhd8ed1ab_0    conda-forge
widgetsnbextension        4.0.8                    pypi_0    pypi
xz                        5.2.6                h166bdaf_0    conda-forge

Note: you may need to restart the kernel to use updated packages.
"""

# %%
conda_env = """
# packages in environment at /ihme/homes/ndbs/miniconda3/envs/pppl310:
#
# Name                    Version                   Build  Channel
_libgcc_mutex             0.1                 conda_forge    conda-forge
_openmp_mutex             4.5                       2_gnu    conda-forge
alabaster                 0.7.13                   pypi_0    pypi
anyio                     3.7.1                    pypi_0    pypi
argon2-cffi               21.3.0                   pypi_0    pypi
argon2-cffi-bindings      21.2.0                   pypi_0    pypi
arrow                     1.2.3                    pypi_0    pypi
asttokens                 2.2.1                    pypi_0    pypi
async-lru                 2.0.4                    pypi_0    pypi
attrs                     23.1.0                   pypi_0    pypi
babel                     2.12.1                   pypi_0    pypi
backcall                  0.2.0                    pypi_0    pypi
beautifulsoup4            4.12.2                   pypi_0    pypi
bleach                    6.0.0                    pypi_0    pypi
blosc2                    2.0.0                    pypi_0    pypi
bzip2                     1.0.8                h7f98852_4    conda-forge
ca-certificates           2023.7.22            hbcca054_0    conda-forge
certifi                   2023.7.22                pypi_0    pypi
cffi                      1.15.1                   pypi_0    pypi
charset-normalizer        3.2.0                    pypi_0    pypi
click                     8.1.6                    pypi_0    pypi
comm                      0.1.3                    pypi_0    pypi
contourpy                 1.1.0                    pypi_0    pypi
cycler                    0.11.0                   pypi_0    pypi
cython                    3.0.0                    pypi_0    pypi
debugpy                   1.6.7                    pypi_0    pypi
decorator                 5.1.1                    pypi_0    pypi
defusedxml                0.7.1                    pypi_0    pypi
docutils                  0.18.1                   pypi_0    pypi
exceptiongroup            1.1.2                    pypi_0    pypi
executing                 1.2.0                    pypi_0    pypi
fastjsonschema            2.18.0                   pypi_0    pypi
fonttools                 4.41.1                   pypi_0    pypi
fqdn                      1.5.1                    pypi_0    pypi
idna                      3.4                      pypi_0    pypi
imagesize                 1.4.1                    pypi_0    pypi
iniconfig                 2.0.0                    pypi_0    pypi
ipykernel                 6.25.0                   pypi_0    pypi
ipython                   8.14.0                   pypi_0    pypi
ipython-genutils          0.2.0                    pypi_0    pypi
ipywidgets                8.0.7                    pypi_0    pypi
isoduration               20.11.0                  pypi_0    pypi
jedi                      0.18.2                   pypi_0    pypi
jinja2                    3.1.2                    pypi_0    pypi
json5                     0.9.14                   pypi_0    pypi
jsonpointer               2.4                      pypi_0    pypi
jsonschema                4.18.4                   pypi_0    pypi
jsonschema-specifications 2023.7.1                 pypi_0    pypi
jupyter                   1.0.0                    pypi_0    pypi
jupyter-client            8.3.0                    pypi_0    pypi
jupyter-console           6.6.3                    pypi_0    pypi
jupyter-core              5.3.1                    pypi_0    pypi
jupyter-events            0.6.3                    pypi_0    pypi
jupyter-lsp               2.2.0                    pypi_0    pypi
jupyter-server            2.7.0                    pypi_0    pypi
jupyter-server-terminals  0.4.4                    pypi_0    pypi
jupyterlab                4.0.3                    pypi_0    pypi
jupyterlab-pygments       0.2.2                    pypi_0    pypi
jupyterlab-server         2.24.0                   pypi_0    pypi
jupyterlab-widgets        3.0.8                    pypi_0    pypi
kiwisolver                1.4.4                    pypi_0    pypi
ld_impl_linux-64          2.40                 h41732ed_0    conda-forge
libffi                    3.4.2                h7f98852_5    conda-forge
libgcc-ng                 13.1.0               he5830b7_0    conda-forge
libgomp                   13.1.0               he5830b7_0    conda-forge
libnsl                    2.0.0                h7f98852_0    conda-forge
libsqlite                 3.42.0               h2797004_0    conda-forge
libuuid                   2.38.1               h0b41bf4_0    conda-forge
libzlib                   1.2.13               hd590300_5    conda-forge
loguru                    0.7.0                    pypi_0    pypi
markupsafe                2.1.3                    pypi_0    pypi
matplotlib                3.7.2                    pypi_0    pypi
matplotlib-inline         0.1.6                    pypi_0    pypi
mistune                   3.0.1                    pypi_0    pypi
msgpack                   1.0.5                    pypi_0    pypi
nbclient                  0.8.0                    pypi_0    pypi
nbconvert                 7.7.3                    pypi_0    pypi
nbformat                  5.9.1                    pypi_0    pypi
ncurses                   6.4                  hcb278e6_0    conda-forge
nest-asyncio              1.5.6                    pypi_0    pypi
networkx                  3.1                      pypi_0    pypi
notebook                  7.0.0                    pypi_0    pypi
notebook-shim             0.2.3                    pypi_0    pypi
numexpr                   2.8.4                    pypi_0    pypi
numpy                     1.25.1                   pypi_0    pypi
openssl                   3.1.1                hd590300_1    conda-forge
overrides                 7.3.1                    pypi_0    pypi
packaging                 23.1                     pypi_0    pypi
pandas                    1.5.3                    pypi_0    pypi
pandocfilters             1.5.0                    pypi_0    pypi
parso                     0.8.3                    pypi_0    pypi
pexpect                   4.8.0                    pypi_0    pypi
pickleshare               0.7.5                    pypi_0    pypi
pillow                    10.0.0                   pypi_0    pypi
pip                       23.2.1             pyhd8ed1ab_0    conda-forge
platformdirs              3.9.1                    pypi_0    pypi
pluggy                    1.2.0                    pypi_0    pypi
prometheus-client         0.17.1                   pypi_0    pypi
prompt-toolkit            3.0.39                   pypi_0    pypi
pseudopeople              0.6.5                    pypi_0    pypi
psutil                    5.9.5                    pypi_0    pypi
ptyprocess                0.7.0                    pypi_0    pypi
pure-eval                 0.2.2                    pypi_0    pypi
py-cpuinfo                9.0.0                    pypi_0    pypi
pyarrow                   12.0.1                   pypi_0    pypi
pycparser                 2.21                     pypi_0    pypi
pygments                  2.15.1                   pypi_0    pypi
pyparsing                 3.0.9                    pypi_0    pypi
pytest                    7.4.0                    pypi_0    pypi
pytest-mock               3.11.1                   pypi_0    pypi
python                    3.10.12         hd12c33a_0_cpython    conda-forge
python-dateutil           2.8.2                    pypi_0    pypi
python-json-logger        2.0.7                    pypi_0    pypi
pytz                      2023.3                   pypi_0    pypi
pyyaml                    6.0.1                    pypi_0    pypi
pyzmq                     25.1.0                   pypi_0    pypi
qtconsole                 5.4.3                    pypi_0    pypi
qtpy                      2.3.1                    pypi_0    pypi
readline                  8.2                  h8228510_1    conda-forge
referencing               0.30.0                   pypi_0    pypi
requests                  2.31.0                   pypi_0    pypi
rfc3339-validator         0.1.4                    pypi_0    pypi
rfc3986-validator         0.1.1                    pypi_0    pypi
rpds-py                   0.9.2                    pypi_0    pypi
scipy                     1.11.1                   pypi_0    pypi
send2trash                1.8.2                    pypi_0    pypi
setuptools                68.0.0             pyhd8ed1ab_0    conda-forge
six                       1.16.0                   pypi_0    pypi
sniffio                   1.3.0                    pypi_0    pypi
snowballstemmer           2.2.0                    pypi_0    pypi
soupsieve                 2.4.1                    pypi_0    pypi
sphinx                    6.2.1                    pypi_0    pypi
sphinx-click              4.4.0                    pypi_0    pypi
sphinx-rtd-theme          1.2.2                    pypi_0    pypi
sphinxcontrib-applehelp   1.0.4                    pypi_0    pypi
sphinxcontrib-devhelp     1.0.2                    pypi_0    pypi
sphinxcontrib-htmlhelp    2.0.1                    pypi_0    pypi
sphinxcontrib-jquery      4.1                      pypi_0    pypi
sphinxcontrib-jsmath      1.0.1                    pypi_0    pypi
sphinxcontrib-qthelp      1.0.3                    pypi_0    pypi
sphinxcontrib-serializinghtml 1.1.5                    pypi_0    pypi
stack-data                0.6.2                    pypi_0    pypi
tables                    3.8.0                    pypi_0    pypi
terminado                 0.17.1                   pypi_0    pypi
tinycss2                  1.2.1                    pypi_0    pypi
tk                        8.6.12               h27826a3_0    conda-forge
tomli                     2.0.1                    pypi_0    pypi
tornado                   6.3.2                    pypi_0    pypi
tqdm                      4.65.0                   pypi_0    pypi
traitlets                 5.9.0                    pypi_0    pypi
typing-extensions         4.7.1                    pypi_0    pypi
tzdata                    2023.3                   pypi_0    pypi
uri-template              1.3.0                    pypi_0    pypi
urllib3                   2.0.4                    pypi_0    pypi
vivarium                  1.2.1                    pypi_0    pypi
vivarium-research-prl     0.0.1                     dev_0    <develop>
wcwidth                   0.2.6                    pypi_0    pypi
webcolors                 1.13                     pypi_0    pypi
webencodings              0.5.1                    pypi_0    pypi
websocket-client          1.6.1                    pypi_0    pypi
wheel                     0.41.0             pyhd8ed1ab_0    conda-forge
widgetsnbextension        4.0.8                    pypi_0    pypi
xz                        5.2.6                h166bdaf_0    conda-forge

Note: you may need to restart the kernel to use updated packages.
"""

# %%
conda_env == conda_env_other
# Out:
# True

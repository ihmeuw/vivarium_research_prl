# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
# Set level to the lowest threshold (DEBUG) to capture all messages
logging.basicConfig(level=logging.DEBUG, format='{asctime} - {name} - {levelname} - {message}', style='{')
import numpy as np, matplotlib.pyplot as plt, pandas as pd
# For finding and loading multiple files
import os
# Use this to see how much memory the dataframes use
from sys import getsizeof
from pathlib import Path
from linetimer import CodeTimer, linetimer

import pseudopeople as psp

from vivarium_research_prl.utils import sizemb, MappingViaAttributes
from vivarium_research_prl import alpha, datatypes

# !date
# !whoami
# !uname -a
# !pwd
# !python --version
# !conda info --envs | grep '\*'
# !conda list | grep -e pandas -e numpy -e vivarium -e pseudopeople
# !pip freeze | grep pseudopeople
# Out:
# 2024-02-06 18:10:28,661 - matplotlib - DEBUG - matplotlib data path: /ihme/homes/ndbs/miniconda3/envs/ppplv1.0-311/lib/python3.11/site-packages/matplotlib/mpl-data
# 2024-02-06 18:10:28,679 - matplotlib - DEBUG - CONFIGDIR=/ihme/homes/ndbs/.config/matplotlib
# 2024-02-06 18:10:28,683 - matplotlib - DEBUG - interactive is False
# 2024-02-06 18:10:28,684 - matplotlib - DEBUG - platform is linux
# 2024-02-06 18:10:28,840 - matplotlib - DEBUG - CACHEDIR=/ihme/homes/ndbs/.cache/matplotlib
# 2024-02-06 18:10:28,846 - matplotlib.font_manager - DEBUG - Using fontManager instance from /ihme/homes/ndbs/.cache/matplotlib/fontlist-v330.json
# 2024-02-06 18:10:30,191 - numexpr.utils - INFO - Note: NumExpr detected 56 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# Tue 06 Feb 2024 06:10:37 PM PST
# ndbs
# Linux long-slurm-sarchive-p0040 5.4.0-167-generic #184-Ubuntu SMP Tue Oct 31 09:21:49 UTC 2023 x86_64 x86_64 x86_64 GNU/Linux
# /mnt/share/code/ndbs/vivarium_research_prl/pseudopeople_testing
# Python 3.11.7
# ppplv1.0-311          *  /ihme/homes/ndbs/miniconda3/envs/ppplv1.0-311
# numpy                     1.26.3                   pypi_0    pypi
# pandas                    2.1.4                    pypi_0    pypi
# pseudopeople              0.8.4.dev34+gc5d0c15          pypi_0    pypi
# vivarium                  2.3.1                    pypi_0    pypi
# vivarium-research-prl     0.0.1                     dev_0    <develop>
# pseudopeople @ git+https://github.com/ihmeuw/pseudopeople.git@c5d0c15dc889b0ef51f56fa9757c2949b8531f3b

# %%
# A clickable link to the GitHub UI to see what version I'm using
! pip freeze | grep pseudopeople | sed -e 's|pseudopeople @ ||' | sed -e 's|git+||' | sed -e 's|\.git@|/tree/|'
# Out:
# https://github.com/ihmeuw/pseudopeople/tree/c5d0c15dc889b0ef51f56fa9757c2949b8531f3b

# %% [markdown]
# # Find data
#
# ```
# /mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop
# ```

# %%
project_path = Path('/mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop')
usa_path = project_path / 'results/release_02_yellow/full_data/united_states_of_america'

# Not sure what these runs are for...
latest_run = usa_path / 'latest'
best_run = usa_path / 'best'
latest_run_path = usa_path / '2023_08_21_16_35_27/final_results/2024_01_11_07_27_51/pseudopeople_input_data_usa_2.0.0'
best_run_path = usa_path / '2023_07_28_08_33_09/final_results/2023_07_31_08_59_48/'

# I think this is the run we should be using...
last_zipped_path = usa_path / '2023_08_21_16_35_27/final_results/2023_08_31_15_58_01'

ri_data_dir = last_zipped_path / 'states/pseudopeople_simulated_population_rhode_island_2_0_0'
usa_data_dir = last_zipped_path / 'pseudopeople_simulated_population_usa_2_0_0'

# %%
# !ls -halt $project_path/results/release_02_yellow/full_data/united_states_of_america/latest
# Out:
# lrwxrwxrwx 1 albrja IHME-Simulationscience 218 Jan 11 12:08 /mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop/results/release_02_yellow/full_data/united_states_of_america/latest -> /mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop/results/release_02_yellow/full_data/united_states_of_america/2023_08_21_16_35_27/final_results/2024_01_11_07_27_51/pseudopeople_input_data_usa_2.0.0

# %%
# !ls $usa_data_dir
# Out:
# american_community_survey  decennial_census  taxes_1040
# CHANGELOG.rst		   logs		     taxes_w2_and_1099
# current_population_survey  social_security   women_infants_and_children

# %%
usa_data_dir
# Out:
# PosixPath('/mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop/results/release_02_yellow/full_data/united_states_of_america/2023_08_21_16_35_27/final_results/2023_08_31_15_58_01/pseudopeople_simulated_population_usa_2_0_0')

# %% [markdown]
# # Set up a logger to log to file

# %%
logs_directory = Path('logs')

# Set up a logger
file_logger = logging.getLogger(__name__) # This gets a new logger for the current, __main__ module

# Create and configure file log handler
file_handler = logging.FileHandler(logs_directory / 'usa_decennial_census_20240206.log')
# Set level to the lowest threshold (DEBUG) to capture all messages
file_handler.setLevel(logging.DEBUG)
file_format = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler.setFormatter(file_format)

# Add handlers to the logger
# logger.addHandler(console_handler)
file_logger.addHandler(file_handler)

# %% [markdown]
# # Generate full USA decennial census

# %%
# %%time
file_logger.info(f"Generating USA decennial census from directory {usa_data_dir}")
file_logger.info(f"Calling function {psp.generate_decennial_census.__name__}")
with CodeTimer("USA decennial census generation", unit='h', logger_func=file_logger.info):
    census = psp.generate_decennial_census(usa_data_dir)
# Out:
# 2024-02-06 18:17:26,819 - __main__ - INFO - Generating USA decennial census from directory /mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop/results/release_02_yellow/full_data/united_states_of_america/2023_08_21_16_35_27/final_results/2023_08_31_15_58_01/pseudopeople_simulated_population_usa_2_0_0
# 2024-02-06 18:17:26,821 - __main__ - INFO - Calling function generate_decennial_census
# Noising data:   0%|                                                                                | 0/334 [00:00<?, ?it/s]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:08<01:53,  8.10s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:10<01:00,  4.62s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:11<00:34,  2.84s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:13<00:28,  2.56s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:13<00:17,  1.80s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:14<00:12,  1.42s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:14<00:08,  1.02s/type]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:14<00:05,  1.32type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:14<00:03,  1.73type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:15<00:03,  1.67type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:15<00:02,  1.91type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:16<00:01,  2.04type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:18<00:01,  1.10type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:20<00:01,  1.41s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.63s/type]
# Noising data:   0%|▏                                                                     | 1/334 [00:41<3:52:28, 41.89s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:49,  7.82s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:58,  4.50s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:33,  2.78s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:27,  2.52s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:13<00:17,  1.77s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.40s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:14<00:08,  1.01s/type]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:14<00:05,  1.34type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:14<00:03,  1.76type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:15<00:02,  1.67type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:15<00:02,  1.94type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.05type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.08type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:20<00:01,  1.42s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.65s/type]
# Noising data:   1%|▍                                                                     | 2/334 [01:21<3:43:33, 40.40s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:46,  7.60s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:57,  4.41s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:32,  2.75s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:27,  2.48s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:13<00:17,  1.74s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.38s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:13<00:07,  1.01type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:14<00:05,  1.36type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:14<00:03,  1.79type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:14<00:02,  1.70type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:15<00:02,  1.97type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.11type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.13type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:19<00:01,  1.37s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.61s/type]
# Noising data:   1%|▋                                                                     | 3/334 [01:59<3:37:30, 39.43s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:46,  7.61s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:56,  4.38s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:32,  2.71s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:26,  2.44s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:12<00:17,  1.71s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.35s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:13<00:07,  1.03type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:13<00:05,  1.39type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:14<00:03,  1.82type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:14<00:02,  1.74type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:15<00:01,  2.01type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.13type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.10type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:19<00:01,  1.37s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:21<00:00,  1.59s/type]
# Noising data:   1%|▊                                                                     | 4/334 [02:37<3:33:52, 38.89s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:47,  7.67s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:57,  4.43s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:32,  2.74s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:27,  2.47s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:13<00:17,  1.74s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.37s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:13<00:07,  1.01type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:14<00:05,  1.36type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:14<00:03,  1.79type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:14<00:02,  1.72type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:15<00:02,  1.98type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.11type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.12type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:19<00:01,  1.36s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.57s/type]
# Noising data:   1%|█                                                                     | 5/334 [03:16<3:33:37, 38.96s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:48,  7.75s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:57,  4.44s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:33,  2.77s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:27,  2.49s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:13<00:17,  1.75s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.39s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:14<00:08,  1.00s/type]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:14<00:05,  1.35type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:14<00:03,  1.78type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:15<00:02,  1.69type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:15<00:02,  1.95type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.09type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.10type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:20<00:01,  1.38s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.60s/type]
# Noising data:   2%|█▎                                                                    | 6/334 [03:54<3:31:33, 38.70s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:44,  7.45s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:55,  4.30s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:32,  2.69s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:26,  2.42s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:12<00:16,  1.70s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.34s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:13<00:07,  1.03type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:13<00:05,  1.40type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:13<00:03,  1.83type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:14<00:02,  1.75type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:14<00:01,  2.01type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.11type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.16type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:19<00:01,  1.34s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:21<00:00,  1.56s/type]
# Noising data:   2%|█▍                                                                    | 7/334 [04:32<3:29:49, 38.50s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:47,  7.69s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:57,  4.39s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:32,  2.75s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:27,  2.48s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:13<00:17,  1.74s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.37s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:13<00:07,  1.01type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:14<00:05,  1.36type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:14<00:03,  1.79type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:14<00:02,  1.71type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:15<00:02,  1.97type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.09type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.11type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:19<00:01,  1.37s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.59s/type]
# Noising data:   2%|█▋                                                                    | 8/334 [05:11<3:29:22, 38.53s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:44,  7.44s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:55,  4.31s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:32,  2.69s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:26,  2.44s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:12<00:17,  1.71s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.35s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:13<00:07,  1.03type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:13<00:05,  1.39type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:13<00:03,  1.82type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:14<00:02,  1.73type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:14<00:01,  2.00type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.13type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.15type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:19<00:01,  1.33s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:21<00:00,  1.56s/type]
# Noising data:   3%|█▉                                                                    | 9/334 [05:48<3:26:51, 38.19s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:50,  7.86s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:10<00:59,  4.55s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:33,  2.80s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:27,  2.50s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:13<00:17,  1.76s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.38s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:14<00:07,  1.00type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:14<00:05,  1.35type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:14<00:03,  1.79type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:15<00:02,  1.70type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:15<00:02,  1.98type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.11type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.14type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:20<00:01,  1.34s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.56s/type]
# Noising data:   3%|██                                                                   | 10/334 [06:27<3:26:45, 38.29s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:44,  7.43s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:55,  4.29s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:31,  2.66s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:26,  2.42s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:12<00:16,  1.69s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.34s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:13<00:07,  1.04type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:13<00:05,  1.40type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:13<00:03,  1.83type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:14<00:02,  1.74type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:14<00:01,  2.02type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.16type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.14type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:19<00:01,  1.36s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:21<00:00,  1.62s/type]
# Noising data:   3%|██▎                                                                  | 11/334 [07:05<3:25:21, 38.15s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:46,  7.58s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:57,  4.40s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:32,  2.73s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:27,  2.51s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:13<00:17,  1.77s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.41s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:14<00:08,  1.01s/type]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:14<00:05,  1.33type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:14<00:03,  1.75type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:15<00:03,  1.66type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:15<00:02,  1.92type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.04type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.09type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:20<00:01,  1.39s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.59s/type]
# Noising data:   4%|██▍                                                                  | 12/334 [07:44<3:25:56, 38.37s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:08<01:52,  8.04s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:10<01:00,  4.64s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:11<00:34,  2.88s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:13<00:28,  2.62s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:13<00:18,  1.84s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:14<00:13,  1.45s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:14<00:08,  1.04s/type]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:14<00:05,  1.29type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:15<00:03,  1.70type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:15<00:03,  1.60type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:16<00:02,  1.83type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:16<00:01,  1.93type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:18<00:01,  1.02type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:21<00:01,  1.47s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:23<00:00,  1.66s/type]
# Noising data:   4%|██▋                                                                  | 13/334 [08:23<3:27:31, 38.79s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:07<01:43,  7.38s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:09<00:55,  4.29s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:10<00:32,  2.67s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:12<00:26,  2.41s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:12<00:16,  1.69s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:13<00:12,  1.34s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:13<00:07,  1.03type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:13<00:05,  1.39type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:13<00:03,  1.84type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:14<00:02,  1.76type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:14<00:01,  2.04type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:15<00:01,  2.17type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:17<00:01,  1.16type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:19<00:01,  1.29s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:21<00:00,  1.49s/type]
# Noising data:   4%|██▉                                                                  | 14/334 [09:00<3:24:01, 38.25s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:34,  6.75s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:50,  3.90s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:09<00:29,  2.42s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:11<00:23,  2.17s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:11<00:15,  1.52s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:12<00:10,  1.20s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:12<00:06,  1.15type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:12<00:04,  1.57type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:12<00:02,  2.06type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:13<00:02,  1.98type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:13<00:01,  2.28type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.47type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:15<00:01,  1.33type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:17<00:01,  1.16s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:19<00:00,  1.34s/type]
# Noising data:   4%|███                                                                  | 15/334 [09:34<3:16:11, 36.90s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:32,  6.57s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:49,  3.83s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:09<00:28,  2.37s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:23,  2.10s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:11<00:14,  1.47s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.17s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.19type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:12<00:04,  1.62type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:12<00:02,  2.12type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.05type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.37type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.54type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.38type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.11s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.33s/type]
# Noising data:   5%|███▎                                                                 | 16/334 [10:07<3:08:27, 35.56s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:32,  6.60s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:49,  3.82s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:09<00:28,  2.37s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:23,  2.09s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:11<00:14,  1.47s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.15s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.20type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:12<00:04,  1.63type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:12<00:02,  2.15type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.08type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.39type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.52type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.38type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.10s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.30s/type]
# Noising data:   5%|███▌                                                                 | 17/334 [10:39<3:02:09, 34.48s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:30,  6.48s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:48,  3.73s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:27,  2.31s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.01s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.41s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.12s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.23type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.68type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.21type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.15type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.51type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.76type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.47type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.07s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:17<00:00,  1.27s/type]
# Noising data:   5%|███▋                                                                 | 18/334 [11:10<2:56:57, 33.60s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:35,  6.85s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:51,  3.97s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:09<00:29,  2.47s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:11<00:23,  2.17s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:11<00:15,  1.53s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:12<00:10,  1.21s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:12<00:06,  1.14type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:12<00:04,  1.55type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:12<00:02,  2.04type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:13<00:02,  1.99type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:13<00:01,  2.32type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.50type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:15<00:01,  1.32type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:17<00:01,  1.15s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:19<00:00,  1.33s/type]
# Noising data:   6%|███▉                                                                 | 19/334 [11:47<3:01:54, 34.65s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:29,  6.42s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:49,  3.78s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:28,  2.34s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.05s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.44s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.14s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.21type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.64type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.16type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.11type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.47type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.63type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.44type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.06s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:17<00:00,  1.22s/type]
# Noising data:   6%|████▏                                                                | 20/334 [12:19<2:55:56, 33.62s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:31,  6.57s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:49,  3.78s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:09<00:28,  2.35s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.05s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.43s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.14s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.21type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.64type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:12<00:02,  2.16type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.07type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.39type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.62type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.41type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.08s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.24s/type]
# Noising data:   6%|████▎                                                                | 21/334 [12:50<2:52:13, 33.01s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:31,  6.51s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:48,  3.76s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:27,  2.33s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.06s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:11<00:14,  1.47s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.19s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.16type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:12<00:04,  1.56type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:12<00:02,  2.02type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  1.86type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:13<00:01,  2.12type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.29type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:15<00:01,  1.22type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:17<00:01,  1.25s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:19<00:00,  1.46s/type]
# Noising data:   7%|████▌                                                                | 22/334 [13:23<2:51:15, 32.93s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:31,  6.54s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:49,  3.81s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:09<00:28,  2.36s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.09s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:11<00:14,  1.47s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.17s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.19type/s]
# ...
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.35s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.07s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.29type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:03,  1.76type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.31type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.23type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.59type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.83type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.51type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.00type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.14s/type]
# Noising data:  52%|██████████████████████████████████▍                               | 174/334 [1:44:27<1:18:42, 29.52s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:27,  6.25s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:47,  3.62s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.24s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:21,  1.95s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.36s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.08s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.28type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.74type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.29type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.21type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.59type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.83type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.50type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:01,  1.03s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:17<00:00,  1.16s/type]
# Noising data:  52%|██████████████████████████████████▌                               | 175/334 [1:44:57<1:18:25, 29.59s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:25,  6.09s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:45,  3.53s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.20s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:21,  1.92s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.35s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.07s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.29type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:03,  1.76type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.31type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.23type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.59type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.83type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.53type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.00type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.17s/type]
# Noising data:  53%|██████████████████████████████████▊                               | 176/334 [1:45:26<1:17:57, 29.60s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:25,  6.13s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:46,  3.57s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.22s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:21,  1.94s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.36s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.08s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.28type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.74type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.29type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.21type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.57type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.82type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.52type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:01,  1.00s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.15s/type]
# Noising data:  53%|██████████████████████████████████▉                               | 177/334 [1:45:56<1:17:24, 29.58s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:28,  6.34s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:47,  3.65s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:27,  2.26s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:21,  1.96s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.37s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:09,  1.08s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.27type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.73type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.28type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.21type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.57type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.81type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.54type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.01type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:17<00:00,  1.15s/type]
# Noising data:  53%|███████████████████████████████████▏                              | 178/334 [1:46:25<1:16:37, 29.47s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:25,  6.13s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:46,  3.55s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.20s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:21,  1.93s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.35s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.07s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.29type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:03,  1.75type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.31type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.22type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.59type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.83type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.52type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:01,  1.00s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.15s/type]
# Noising data:  54%|███████████████████████████████████▎                              | 179/334 [1:46:55<1:16:14, 29.51s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:24,  6.05s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:45,  3.52s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.19s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:21,  1.93s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.35s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.07s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.29type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:03,  1.75type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.31type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.22type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.57type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.82type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.52type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:01,  1.00s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.14s/type]
# Noising data:  54%|███████████████████████████████████▌                              | 180/334 [1:47:24<1:15:32, 29.43s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:30,  6.43s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:48,  3.70s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:27,  2.29s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:21,  1.97s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.38s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:09,  1.09s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.27type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.73type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.28type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.21type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.58type/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
file_logger.info(f"{type(census)} census occupies {sizemb(census)} MB in memory")
# Out:
# 2024-02-06 21:54:30,228 - __main__ - INFO - <class 'pandas.core.frame.DataFrame'> census occupies 277575.444814 MB in memory

# %%
file_logger.info(f"DataFrame info: {census.info()}")
# Out:
# 2024-02-06 21:54:30,857 - __main__ - INFO - DataFrame info: None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330811542 entries, 0 to 330811541
# Data columns (total 18 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   simulant_id                       object
#  1   household_id                      object
#  2   first_name                        object
#  3   middle_initial                    object
#  4   last_name                         object
#  5   age                               object
#  6   date_of_birth                     object
#  7   street_number                     object
#  8   street_name                       object
#  9   unit_number                       object
#  10  city                              object
#  11  state                             category
#  12  zipcode                           object
#  13  housing_type                      object
#  14  relationship_to_reference_person  category
#  15  sex                               category
#  16  race_ethnicity                    category
#  17  year                              object
# dtypes: category(4), object(14)
# memory usage: 35.7+ GB

# %%
file_logger.info(f"Detailed DataFrame memory usage: {census.memory_usage(deep=True)}")
# Out:
# 2024-02-06 22:10:42,944 - __main__ - INFO - Detailed DataFrame memory usage: Index                                       132
# simulant_id                         22431980013
# household_id                        22308622678
# first_name                          20707715312
# middle_initial                      19101141995
# last_name                           20925307730
# age                                 19390311234
# date_of_birth                       22048792559
# street_number                       19551188244
# street_name                         22753729177
# unit_number                         11209476244
# city                                21724459018
# state                                 330816655
# zipcode                             20411153783
# housing_type                        21779096905
# relationship_to_reference_person      330813526
# sex                                   330811774
# race_ethnicity                        330812291
# year                                11909215512
# dtype: int64

# %%
# %%time
file_logger.info("Converting to ints and categoricals...")
with CodeTimer("US census datatype conversion", unit='m', logger_func=file_logger.info):
    census = datatypes.to_int_and_categorical(census)
# Out:
# 2024-02-07 00:13:59,890 - __main__ - INFO - Converting to ints and categoricals...

# %%
file_logger.info(f"After converting to ints and categoricals, {type(census)} census occupies {sizemb(census)} MB in memory")

# %%
file_logger.info(f"Detailed DataFrame memory usage after converting: {census.memory_usage(deep=True)}")

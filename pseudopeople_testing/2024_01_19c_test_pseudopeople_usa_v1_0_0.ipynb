# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
# Set level to the lowest threshold (DEBUG) to capture all messages
logging.basicConfig(level=logging.DEBUG, format='{asctime} - {name} - {levelname} - {message}', style='{')
import numpy as np, matplotlib.pyplot as plt, pandas as pd
# For finding and loading multiple files
import os
# Use this to see how much memory the dataframes use
from sys import getsizeof
from pathlib import Path
from linetimer import CodeTimer, linetimer

import pseudopeople as psp

from vivarium_research_prl.utils import sizemb, MappingViaAttributes
from vivarium_research_prl import alpha, datatypes

# !date
# !whoami
# !uname -a
# !pwd
# !python --version
# !conda info --envs | grep '\*'
# !conda list | grep -e pandas -e numpy -e vivarium -e pseudopeople
# !pip freeze | grep pseudopeople
# Out:
# 2024-02-09 02:44:40,178 - matplotlib - DEBUG - matplotlib data path: /ihme/homes/ndbs/miniconda3/envs/ppplv1.0-311/lib/python3.11/site-packages/matplotlib/mpl-data
# 2024-02-09 02:44:40,189 - matplotlib - DEBUG - CONFIGDIR=/ihme/homes/ndbs/.config/matplotlib
# 2024-02-09 02:44:40,193 - matplotlib - DEBUG - interactive is False
# 2024-02-09 02:44:40,194 - matplotlib - DEBUG - platform is linux
# 2024-02-09 02:44:40,319 - matplotlib - DEBUG - CACHEDIR=/ihme/homes/ndbs/.cache/matplotlib
# 2024-02-09 02:44:40,324 - matplotlib.font_manager - DEBUG - Using fontManager instance from /ihme/homes/ndbs/.cache/matplotlib/fontlist-v330.json
# 2024-02-09 02:44:41,080 - numexpr.utils - INFO - Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# Fri 09 Feb 2024 02:44:46 AM PST
# ndbs
# Linux long-slurm-sarchive-p0050 5.4.0-167-generic #184-Ubuntu SMP Tue Oct 31 09:21:49 UTC 2023 x86_64 x86_64 x86_64 GNU/Linux
# /mnt/share/code/ndbs/vivarium_research_prl/pseudopeople_testing
# Python 3.11.7
# ppplv1.0-311          *  /ihme/homes/ndbs/miniconda3/envs/ppplv1.0-311
# numpy                     1.26.3                   pypi_0    pypi
# pandas                    2.1.4                    pypi_0    pypi
# pseudopeople              0.8.4.dev34+gc5d0c15          pypi_0    pypi
# vivarium                  2.3.1                    pypi_0    pypi
# vivarium-research-prl     0.0.1                     dev_0    <develop>
# pseudopeople @ git+https://github.com/ihmeuw/pseudopeople.git@c5d0c15dc889b0ef51f56fa9757c2949b8531f3b

# %%
# A clickable link to the GitHub UI to see what version I'm using
! pip freeze | grep pseudopeople | sed -e 's|pseudopeople @ ||' | sed -e 's|git+||' | sed -e 's|\.git@|/tree/|'
# Out:
# https://github.com/ihmeuw/pseudopeople/tree/c5d0c15dc889b0ef51f56fa9757c2949b8531f3b

# %% [markdown]
# # Find data
#
# ```
# /mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop
# ```

# %%
project_path = Path('/mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop')
usa_path = project_path / 'results/release_02_yellow/full_data/united_states_of_america'

# Not sure what these runs are for...
latest_run = usa_path / 'latest'
best_run = usa_path / 'best'
latest_run_path = usa_path / '2023_08_21_16_35_27/final_results/2024_01_11_07_27_51/pseudopeople_input_data_usa_2.0.0'
best_run_path = usa_path / '2023_07_28_08_33_09/final_results/2023_07_31_08_59_48/'

# I think this is the run we should be using...
last_zipped_path = usa_path / '2023_08_21_16_35_27/final_results/2023_08_31_15_58_01'

ri_data_dir = last_zipped_path / 'states/pseudopeople_simulated_population_rhode_island_2_0_0'
usa_data_dir = last_zipped_path / 'pseudopeople_simulated_population_usa_2_0_0'

# %%
# !ls -halt $project_path/results/release_02_yellow/full_data/united_states_of_america/latest
# Out:
# lrwxrwxrwx 1 albrja IHME-Simulationscience 218 Jan 11 12:08 /mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop/results/release_02_yellow/full_data/united_states_of_america/latest -> /mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop/results/release_02_yellow/full_data/united_states_of_america/2023_08_21_16_35_27/final_results/2024_01_11_07_27_51/pseudopeople_input_data_usa_2.0.0

# %%
# !ls $usa_data_dir
# Out:
# american_community_survey  decennial_census  taxes_1040
# CHANGELOG.rst		   logs		     taxes_w2_and_1099
# current_population_survey  social_security   women_infants_and_children

# %%
usa_data_dir
# Out:
# PosixPath('/mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop/results/release_02_yellow/full_data/united_states_of_america/2023_08_21_16_35_27/final_results/2023_08_31_15_58_01/pseudopeople_simulated_population_usa_2_0_0')

# %% [markdown]
# # Set up a logger to log to file

# %%
logs_directory = Path('logs')

# Set up a logger
file_logger = logging.getLogger(__name__) # This gets a new logger for the current, __main__ module

# Create and configure file log handler
file_handler = logging.FileHandler(logs_directory / 'usa_decennial_census_20240209.log')
# Set level to the lowest threshold (DEBUG) to capture all messages
file_handler.setLevel(logging.DEBUG)
file_format = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler.setFormatter(file_format)

# Add handlers to the logger
# logger.addHandler(console_handler)
file_logger.addHandler(file_handler)

# %% [markdown]
# # Generate full USA decennial census

# %%
# %%time
file_logger.info(f"Generating USA decennial census from directory {usa_data_dir}")
file_logger.info(f"Calling function {psp.generate_decennial_census.__name__}")
with CodeTimer("USA decennial census generation", unit='h', logger_func=file_logger.info):
    census = psp.generate_decennial_census(usa_data_dir)
# Out:
# 2024-02-09 02:44:58,659 - __main__ - INFO - Generating USA decennial census from directory /mnt/team/simulation_science/pub/models/vivarium_census_prl_synth_pop/results/release_02_yellow/full_data/united_states_of_america/2023_08_21_16_35_27/final_results/2023_08_31_15_58_01/pseudopeople_simulated_population_usa_2_0_0
# 2024-02-09 02:44:58,659 - __main__ - INFO - Calling function generate_decennial_census
# Noising data:   0%|                                                                                | 0/334 [00:00<?, ?it/s]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:29,  6.40s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:47,  3.67s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.24s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.07s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.47s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.17s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.19type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.60type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.10type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  1.97type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.29type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.47type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.39type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.12s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.29s/type]
# Noising data:   0%|▏                                                                     | 1/334 [00:31<2:55:38, 31.65s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:22,  5.93s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:45,  3.48s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.13s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.89s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.33s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.06s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.30type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.76type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.32type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.18type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.56type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.80type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.55type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.01type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.13s/type]
# Noising data:   1%|▍                                                                     | 2/334 [01:01<2:48:45, 30.50s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:28,  6.30s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:47,  3.65s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:27,  2.26s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.08s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.46s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.16s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.19type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.61type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.12type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.02type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.37type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.53type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.37type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.12s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.29s/type]
# Noising data:   1%|▋                                                                     | 3/334 [01:33<2:51:12, 31.03s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:23,  5.95s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:44,  3.45s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.14s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.90s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.34s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.07s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.29type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:04,  1.75type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.29type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.20type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.58type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.81type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.52type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:01,  1.00s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.16s/type]
# Noising data:   1%|▊                                                                     | 4/334 [02:02<2:47:25, 30.44s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:22,  5.90s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:44,  3.42s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.12s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.90s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.33s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.08s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.28type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:04,  1.74type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.29type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.20type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.59type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.82type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.53type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.01type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.14s/type]
# Noising data:   1%|█                                                                     | 5/334 [02:32<2:44:58, 30.09s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:22,  5.92s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:44,  3.41s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.10s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.88s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:09<00:13,  1.32s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.06s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.30type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.77type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:10<00:02,  2.32type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.23type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.61type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:11<00:01,  2.83type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.55type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.01type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.13s/type]
# Noising data:   2%|█▎                                                                    | 6/334 [03:00<2:42:04, 29.65s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:27,  6.25s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:47,  3.63s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.25s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.05s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.44s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.15s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.20type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.62type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.13type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.02type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.37type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.51type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.36type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.12s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.30s/type]
# Noising data:   2%|█▍                                                                    | 7/334 [03:32<2:44:25, 30.17s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:22,  5.91s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:44,  3.42s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.12s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.89s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.33s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.06s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.30type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.76type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.32type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.22type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.60type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.83type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.57type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.02type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.13s/type]
# Noising data:   2%|█▋                                                                    | 8/334 [04:01<2:42:46, 29.96s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:27,  6.26s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:47,  3.64s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.23s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.03s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.43s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.14s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.20type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.62type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.12type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.03type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.35type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.47type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.36type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.13s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.31s/type]
# Noising data:   3%|█▉                                                                    | 9/334 [04:33<2:45:15, 30.51s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:21,  5.83s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:43,  3.38s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:24,  2.08s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.86s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:09<00:13,  1.31s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.05s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.31type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.78type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:10<00:02,  2.34type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.23type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.61type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:11<00:01,  2.84type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.59type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:14<00:00,  1.03type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.13s/type]
# Noising data:   3%|██                                                                   | 10/334 [05:02<2:42:58, 30.18s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:27,  6.28s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:47,  3.63s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.23s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.03s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.43s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.14s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.21type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.63type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.15type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.03type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.35type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.49type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.37type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.14s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.31s/type]
# Noising data:   3%|██▎                                                                  | 11/334 [05:33<2:43:23, 30.35s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:21,  5.80s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:43,  3.36s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:07<00:24,  2.07s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.85s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:09<00:13,  1.30s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.04s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.32type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.79type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:10<00:02,  2.35type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.24type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.63type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:11<00:01,  2.86type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.56type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:14<00:00,  1.01type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.13s/type]
# Noising data:   4%|██▍                                                                  | 12/334 [06:02<2:40:43, 29.95s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:27,  6.22s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:46,  3.59s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.22s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.02s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.42s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.14s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.21type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.64type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.16type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.04type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.36type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.51type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.35type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.13s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.30s/type]
# Noising data:   4%|██▋                                                                  | 13/334 [06:33<2:42:06, 30.30s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:22,  5.91s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:44,  3.41s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.09s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.87s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:09<00:13,  1.31s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.05s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.31type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.78type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:10<00:02,  2.34type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.21type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.59type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:11<00:01,  2.83type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.58type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:14<00:00,  1.02type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.13s/type]
# Noising data:   4%|██▉                                                                  | 14/334 [07:02<2:39:44, 29.95s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:25,  6.12s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:46,  3.54s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.19s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.01s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.41s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.13s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.22type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.65type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.16type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.06type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.40type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.56type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.38type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.13s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:17<00:00,  1.29s/type]
# Noising data:   4%|███                                                                  | 15/334 [07:33<2:39:48, 30.06s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:21,  5.85s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:43,  3.38s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:24,  2.08s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.87s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:09<00:13,  1.31s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.05s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.31type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.77type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:10<00:02,  2.33type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.20type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.59type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:11<00:01,  2.81type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.53type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.00type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.14s/type]
# Noising data:   5%|███▎                                                                 | 16/334 [08:02<2:38:04, 29.83s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:23,  5.94s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:44,  3.43s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.11s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.88s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.32s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.06s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.30type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.77type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.33type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.22type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.60type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.83type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.54type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.01type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.15s/type]
# Noising data:   5%|███▌                                                                 | 17/334 [08:31<2:37:07, 29.74s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:22,  5.86s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:44,  3.40s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.10s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.87s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:09<00:13,  1.32s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.06s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.31type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.77type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:10<00:02,  2.33type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.23type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.61type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:11<00:01,  2.84type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.57type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.02type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.13s/type]
# Noising data:   5%|███▋                                                                 | 18/334 [09:00<2:35:31, 29.53s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:28,  6.34s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:47,  3.66s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:27,  2.25s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.04s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.43s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.14s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.20type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.63type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.14type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.03type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.38type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.55type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.37type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.13s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.30s/type]
# Noising data:   6%|███▉                                                                 | 19/334 [09:32<2:37:36, 30.02s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:22,  5.87s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:44,  3.41s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.10s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.87s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:09<00:13,  1.32s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.06s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.30type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.77type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:10<00:02,  2.33type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.22type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.60type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:11<00:01,  2.82type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.57type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.01type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.13s/type]
# Noising data:   6%|████▏                                                                | 20/334 [10:01<2:35:58, 29.80s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:31,  6.50s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:48,  3.73s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:27,  2.31s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.07s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.45s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.16s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.19type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.62type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:12<00:02,  2.13type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.03type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.38type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.55type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.36type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.12s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.29s/type]
# Noising data:   6%|████▎                                                                | 21/334 [10:32<2:37:22, 30.17s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:05<01:21,  5.85s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:44,  3.39s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.09s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:20,  1.89s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:09<00:13,  1.32s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.06s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.30type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:10<00:03,  1.76type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:10<00:02,  2.32type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.21type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:11<00:01,  2.60type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:11<00:01,  2.82type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.56type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:00,  1.01type/s]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.13s/type]
# Noising data:   7%|████▌                                                                | 22/334 [11:01<2:35:47, 29.96s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:29,  6.37s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:47,  3.68s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:27,  2.26s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.05s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.44s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.16s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.20type/s]
# ...
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.70type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.23type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.10type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.46type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.67type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.46type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:01,  1.04s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:17<00:00,  1.22s/type]
# Noising data:  98%|██████████████████████████████████████████████████████████████████▌ | 327/334 [2:45:59<03:38, 31.19s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:25,  6.11s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:46,  3.58s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.21s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.04s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.44s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.16s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.19type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.61type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.10type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  1.98type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.33type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.49type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.35type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.15s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.31s/type]
# Noising data:  98%|██████████████████████████████████████████████████████████████████▊ | 328/334 [2:46:30<03:06, 31.12s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:24,  6.06s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:45,  3.51s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.18s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:21,  1.96s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.38s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.10s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.25type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.71type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.25type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.14type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.53type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.72type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.52type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:01,  1.02s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:17<00:00,  1.17s/type]
# Noising data:  99%|██████████████████████████████████████████████████████████████████▉ | 329/334 [2:47:01<02:35, 31.09s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:28,  6.32s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:48,  3.72s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:27,  2.28s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:23,  2.10s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.48s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.18s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.17type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.57type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:12<00:02,  2.07type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  1.98type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.31type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.48type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.33type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.15s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.32s/type]
# Noising data:  99%|███████████████████████████████████████████████████████████████████▏| 330/334 [2:47:33<02:04, 31.22s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:24,  6.03s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:45,  3.50s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.17s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:21,  1.95s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.37s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.10s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.26type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.71type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.24type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.15type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.50type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.71type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.50type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:01,  1.03s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:17<00:00,  1.17s/type]
# Noising data:  99%|███████████████████████████████████████████████████████████████████▍| 331/334 [2:48:03<01:33, 31.05s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:25,  6.10s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:46,  3.58s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:26,  2.21s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:22,  2.03s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:14,  1.43s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.16s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.19type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.61type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.12type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  2.01type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.35type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.51type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.38type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.11s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.29s/type]
# Noising data:  99%|███████████████████████████████████████████████████████████████████▌| 332/334 [2:48:35<01:02, 31.09s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:24,  6.00s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:07<00:45,  3.49s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:25,  2.16s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:09<00:21,  1.94s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:10<00:13,  1.36s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:10<00:09,  1.09s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:10<00:06,  1.27type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.72type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:11<00:02,  2.27type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:11<00:02,  2.17type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.53type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:12<00:01,  2.76type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:13<00:01,  1.53type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:15<00:01,  1.01s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:16<00:00,  1.16s/type]
# Noising data: 100%|███████████████████████████████████████████████████████████████████▊| 333/334 [2:49:05<00:30, 30.89s/it]
# Applying noise:   0%|                                                                             | 0/15 [00:00<?, ?type/s]
# Applying noise:   7%|████▌                                                                | 1/15 [00:06<01:28,  6.32s/type]
# Applying noise:  13%|█████████▏                                                           | 2/15 [00:08<00:48,  3.72s/type]
# Applying noise:  20%|█████████████▊                                                       | 3/15 [00:08<00:27,  2.29s/type]
# Applying noise:  27%|██████████████████▍                                                  | 4/15 [00:10<00:23,  2.12s/type]
# Applying noise:  33%|███████████████████████                                              | 5/15 [00:11<00:14,  1.48s/type]
# Applying noise:  40%|███████████████████████████▌                                         | 6/15 [00:11<00:10,  1.19s/type]
# Applying noise:  47%|████████████████████████████████▏                                    | 7/15 [00:11<00:06,  1.16type/s]
# Applying noise:  53%|████████████████████████████████████▊                                | 8/15 [00:11<00:04,  1.58type/s]
# Applying noise:  60%|█████████████████████████████████████████▍                           | 9/15 [00:12<00:02,  2.08type/s]
# Applying noise:  67%|█████████████████████████████████████████████▎                      | 10/15 [00:12<00:02,  1.97type/s]
# Applying noise:  73%|█████████████████████████████████████████████████▊                  | 11/15 [00:12<00:01,  2.30type/s]
# Applying noise:  80%|██████████████████████████████████████████████████████▍             | 12/15 [00:13<00:01,  2.46type/s]
# Applying noise:  87%|██████████████████████████████████████████████████████████▉         | 13/15 [00:14<00:01,  1.36type/s]
# Applying noise:  93%|███████████████████████████████████████████████████████████████▍    | 14/15 [00:16<00:01,  1.14s/type]
# Applying noise: 100%|████████████████████████████████████████████████████████████████████| 15/15 [00:18<00:00,  1.33s/type]
# 2024-02-09 05:52:08,353 - __main__ - INFO - Code block 'USA decennial census generation' took: 3.11936 h
# CPU times: user 2h 48min 42s, sys: 18min 1s, total: 3h 6min 43s
# Wall time: 3h 7min 9s

# %%
file_logger.info(f"{type(census)} census occupies {sizemb(census)} MB in memory")
# Out:
# 2024-02-09 06:06:34,931 - __main__ - INFO - <class 'pandas.core.frame.DataFrame'> census occupies 277575.444814 MB in memory

# %%
file_logger.info(f"DataFrame info: {census.info()}")
# Out:
# 2024-02-09 06:06:35,578 - __main__ - INFO - DataFrame info: None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330811542 entries, 0 to 330811541
# Data columns (total 18 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   simulant_id                       object
#  1   household_id                      object
#  2   first_name                        object
#  3   middle_initial                    object
#  4   last_name                         object
#  5   age                               object
#  6   date_of_birth                     object
#  7   street_number                     object
#  8   street_name                       object
#  9   unit_number                       object
#  10  city                              object
#  11  state                             category
#  12  zipcode                           object
#  13  housing_type                      object
#  14  relationship_to_reference_person  category
#  15  sex                               category
#  16  race_ethnicity                    category
#  17  year                              object
# dtypes: category(4), object(14)
# memory usage: 35.7+ GB

# %%
file_logger.info(f"Detailed DataFrame memory usage: {census.memory_usage(deep=True)}")
# Out:
# 2024-02-09 06:21:06,175 - __main__ - INFO - Detailed DataFrame memory usage: Index                                       132
# simulant_id                         22431980013
# household_id                        22308622678
# first_name                          20707715312
# middle_initial                      19101141995
# last_name                           20925307730
# age                                 19390311234
# date_of_birth                       22048792559
# street_number                       19551188244
# street_name                         22753729177
# unit_number                         11209476244
# city                                21724459018
# state                                 330816655
# zipcode                             20411153783
# housing_type                        21779096905
# relationship_to_reference_person      330813526
# sex                                   330811774
# race_ethnicity                        330812291
# year                                11909215512
# dtype: int64

# %%
# %%time
file_logger.info("Converting to ints and categoricals...")
with CodeTimer("US census datatype conversion", unit='m', logger_func=file_logger.info):
    census = datatypes.to_int_and_categorical(census)
# Out:
# 2024-02-09 06:21:06,947 - __main__ - INFO - Converting to ints and categoricals...
# 2024-02-09 07:08:58,906 - __main__ - INFO - Code block 'US census datatype conversion' took: 47.86595 m
# CPU times: user 37min 48s, sys: 10min 10s, total: 47min 59s
# Wall time: 47min 51s

# %%
file_logger.info(f"After converting to ints and categoricals, {type(census)} census occupies {sizemb(census)} MB in memory")
# Out:
# 2024-02-09 07:09:08,513 - __main__ - INFO - After converting to ints and categoricals, <class 'pandas.core.frame.DataFrame'> census occupies 20641.082617 MB in memory

# %%
file_logger.info(f"Detailed DataFrame memory usage after converting: {census.memory_usage(deep=True)}")
# Out:
# 2024-02-09 07:09:14,300 - __main__ - INFO - Detailed DataFrame memory usage after converting: Index                                      132
# simulant_id                         2646492336
# household_id                        2646492336
# first_name                          1373800152
# middle_initial                       661637661
# last_name                           1791896428
# age                                  661742943
# date_of_birth                       1513028204
# street_number                       1352244039
# street_name                         1856733640
# unit_number                         1347389322
# city                                1449424652
# state                                330816655
# zipcode                             1355322510
# housing_type                         330812326
# relationship_to_reference_person     330813526
# sex                                  330811774
# race_ethnicity                       330812291
# year                                 330811658
# dtype: int64

# %% [markdown]
# # Investigate guardian-based duplication in the census
#
# ## First find duplicates

# %%
# %%time
dup_ids = census.simulant_id.duplicated(keep=False)
duplicates = census.loc[dup_ids]
duplicates
# Out:
# CPU times: user 1min 9s, sys: 6.45 s, total: 1min 15s
# Wall time: 1min 15s
#              simulant_id   household_id first_name middle_initial last_name  \
# 17         1007000000017  1007000000015    Aaliyah              E     Wiles
# 2898       1007000002998  1007000001255    Janiyah              C   Nannini
# 4506       1007000004678  1007000001947      Ayden              D  Williams
# 5059       1007000005250  1007000002157       Sean              A   Hopkins
# 7852       1007000008108  1007000003309     Daniel              A    Taylor
# ...                  ...            ...        ...            ...       ...
# 330811537  9971000970069  9971000288034      Lacie              K   Bennett
# 330811538  9971000980981  9971000178884  Stephanie              G  Pearlman
# 330811539  9971000975589  9971000163772    Brendon              B      Moss
# 330811540  9971000979343  9971000310654       Sean              J   Charles
# 330811541  9971000978488  9971000155539     Alfred              J   Garrick
#
#           age date_of_birth street_number        street_name unit_number  \
# 17         12    05/21/2007          7458         pawley ave         NaN
# 2898        9    02/04/2011         18005        isleview dr         NaN
# 4506        9    06/13/2010          1523    green valley rd         NaN
# 5059       10    10/05/2009           NaN       sweetwood dr         NaN
# 7852       12    02/16/2008           NaN       n ramunno dr         NaN
# ...        ..           ...           ...                ...         ...
# 330811537  23    09/10/1996          3200           broad st         NaN
# 330811538  19    10/28/2000          2143           w 5500 s         NaN
# 330811539  20    01/05/2000           230        cialella ps         NaN
# 330811540  21    01/28/1999          1048      10th place se         NaN
# 330811541  21    04/24/1998          3083  warwick boulevard         NaN
#
#                  city state zipcode housing_type  \
# 17             stokes    OH   43506    Household
# 2898       greenville    SC   29040    Household
# 4506        boonville    IN   46342    Household
# 5059       pine bluff    AR   71801    Household
# 7852        maryville    TN   37210    Household
# ...               ...   ...     ...          ...
# 330811537  pittsburgh    PA   19128    Household
# 330811538       young    AZ   85387    Household
# 330811539   ellenwood    GA   31522    Household
# 330811540     brandon    MS   39117    Household
# 330811541      foster    RI   02816    Household
#
#           relationship_to_reference_person     sex race_ethnicity  year
# 17                                 Sibling  Female          White  2020
# 2898                      Biological child  Female          White  2020
# 4506                      Biological child    Male          Black  2020
# 5059                             Stepchild    Male          White  2020
# 7852                 Roommate or housemate    Male          Black  2020
# ...                                    ...     ...            ...   ...
# 330811537                   Other relative  Female          White  2020
# 330811538                   Other relative  Female          White  2020
# 330811539                   Other relative    Male          White  2020
# 330811540                   Other relative    Male          Black  2020
# 330811541                   Other relative    Male          White  2020
#
# [470488 rows x 18 columns]

# %%
len(duplicates)/2
# Out:
# 235244.0

# %%
duplicates.simulant_id.value_counts().unique()
# Out:
# array([2])

# %% [markdown]
# # Figure out household IDs for group quarters
#
# I think the GQ household IDs within each shard are 0,1,2,3,4,5, and there's one of each type in each of the 334 shards.

# %%
# %%time
college_hh_counts = census.query("housing_type == 'College'")['household_id'].value_counts()
college_hh_counts
# Out:
# CPU times: user 2.24 s, sys: 1.38 s, total: 3.62 s
# Wall time: 3.62 s
# household_id
# 3713000000003    6642
# 9588000000003    6622
# 778000000003     6612
# 3624000000003    6611
# 5628000000003    6603
#                  ...
# 3793000278641       1
# 3793000279461       1
# 3793000279601       1
# 3793000279838       1
# 3793000278018       1
# Name: count, Length: 525865, dtype: int64

# %%
college_hh_counts.loc[college_hh_counts > 6000]
# Out:
# household_id
# 3713000000003    6642
# 9588000000003    6622
# 778000000003     6612
# 3624000000003    6611
# 5628000000003    6603
#                  ...
# 2787000000003    6200
# 9859000000003    6185
# 5300000000003    6176
# 3731000000003    6174
# 1154000000003    6168
# Name: count, Length: 334, dtype: int64

# %%
college_hh_counts.loc[(college_hh_counts > 1000) & (college_hh_counts < 6000)]
# Out:
# Series([], Name: count, dtype: int64)

# %%
college_hh_counts.loc[(college_hh_counts > 10) & (college_hh_counts < 6000)]
# Out:
# household_id
# 8305000000001    22
# 103000000000     22
# 6929000000002    22
# 4950000000001    21
# 8501000000001    21
#                  ..
# 1559000000002    11
# 1632000000004    11
# 2500000000001    11
# 6520000000005    11
# 338000000005     11
# Name: count, Length: 771, dtype: int64

# %%
# %%time
census.query("household_id == 8305000000001")['housing_type'].value_counts()
# Out:
# CPU times: user 1.49 s, sys: 1.42 s, total: 2.91 s
# Wall time: 2.92 s
# housing_type
# Nursing home              6187
# College                     22
# Military                    14
# Carceral                    12
# Other institutional         10
# Household                    8
# Other noninstitutional       6
# Name: count, dtype: int64

# %%
# %%time
census.query("household_id == 103000000000")['housing_type'].value_counts()
# Out:
# CPU times: user 1.53 s, sys: 1.36 s, total: 2.89 s
# Wall time: 2.89 s
# housing_type
# Carceral                  6139
# College                     22
# Nursing home                20
# Military                    13
# Other institutional         10
# Other noninstitutional       6
# Household                    5
# Name: count, dtype: int64

# %%
# %%time
census.query("household_id == 6929000000002")['housing_type'].value_counts()
# Out:
# CPU times: user 1.54 s, sys: 1.38 s, total: 2.92 s
# Wall time: 2.92 s
# housing_type
# Other institutional       6131
# College                     22
# Carceral                    15
# Nursing home                13
# Military                     9
# Other noninstitutional       9
# Household                    6
# Name: count, dtype: int64

# %%
# %%time
census.query("household_id == 338000000005")['housing_type'].value_counts()
# Out:
# CPU times: user 1.55 s, sys: 1.37 s, total: 2.92 s
# Wall time: 2.92 s
# housing_type
# Other noninstitutional    6217
# Household                   12
# College                     11
# Military                    11
# Carceral                    10
# Nursing home                 9
# Other institutional          6
# Name: count, dtype: int64

# %%
datatypes.ID_PAD_WIDTH
# Out:
# 9

# %%
# %%time
hh_id_1 = census.query(f"household_id % {10**datatypes.ID_PAD_WIDTH} == 1")
hh_id_1
# Out:
# CPU times: user 6.78 s, sys: 1.41 s, total: 8.2 s
# Wall time: 8.19 s
#              simulant_id   household_id first_name middle_initial   last_name  \
# 104        1007000000114  1007000000001       Dell              F       Graff
# 413        1007000000432  1007000000001      Aaron              E   Cavicchio
# 954        1007000000985  1007000000001   Salvador              Z       Roach
# 2033       1007000002110  1007000000001    Michael              J     Russell
# 2313       1007000002397  1007000000001      Louis              G      Murphy
# ...                  ...            ...        ...            ...         ...
# 330810958  9971000583451  9971000000001      Helen              C     Coleman
# 330811036  9971000448939  9971000000001      Amari              B  Delatejera
# 330811116  9971000173458  9971000000001     Cortez              D         Joa
# 330811147  9971000360446  9971000000001      Leila              I       Moore
# 330811215  9971000091627  9971000000001   Theodore              D     Rehbein
#
#           age date_of_birth street_number       street_name unit_number  \
# 104        88    05/01/1931           600       n blair ave         NaN
# 413        17    10/12/2002           600       n blair ave         NaN
# 954        19    07/28/2000           600       n blair ave         NaN
# 2033       46    01/02/1974           600       n blair ave         NaN
# 2313       19    02/03/2001           600       n blair ave         NaN
# ...        ..           ...           ...               ...         ...
# 330810958  14    01/27/2006         11801               NaN         NaN
# 330811036  10    03/16/2010         11801  west 26th street         NaN
# 330811116  12    11/20/2007         11801  west 26th street         NaN
# 330811147   9    11/08/2010         11801  west 26th street         NaN
# 330811215   4    02/04/2016         11801  west 26th street         NaN
#
#                   city state zipcode  housing_type  \
# 104             vadito    NM   87001  Nursing home
# 413             vadito    AL   87001  Nursing home
# 954             vadito    NM   87001  Nursing home
# 2033            vadito    NM   87001  Nursing home
# 2313            vadito    NM   87001  Nursing home
# ...                ...   ...     ...           ...
# 330810958  statesville    NC   27011  Nursing home
# 330811036  statesville    NC   27011  Nursing home
# 330811116  statesville    NC   27011  Nursing home
# 330811147  statesville    NC   27011  Nursing home
# 330811215          NaN    NC   27011  Nursing home
#
#                       relationship_to_reference_person     sex  \
# 104        Institutionalized group quarters population  Female
# 413        Institutionalized group quarters population    Male
# 954        Institutionalized group quarters population    Male
# 2033       Institutionalized group quarters population    Male
# 2313       Institutionalized group quarters population    Male
# ...                                                ...     ...
# 330810958  Institutionalized group quarters population  Female
# 330811036  Institutionalized group quarters population    Male
# 330811116  Institutionalized group quarters population    Male
# 330811147  Institutionalized group quarters population  Female
# 330811215  Institutionalized group quarters population    Male
#
#                  race_ethnicity  year
# 104                       White  2020
# 413                       White  2020
# 954                       Asian  2020
# 2033       Multiracial or Other  2020
# 2313                      White  2020
# ...                         ...   ...
# 330810958                 Black  2020
# 330811036                Latino  2020
# 330811116                 White  2020
# 330811147                  AIAN  2020
# 330811215                 White  2020
#
# [2084289 rows x 18 columns]

# %%
hh_id_1['housing_type'].value_counts()
# Out:
# housing_type
# Nursing home              2043321
# Other institutional          3452
# Carceral                     3442
# College                      3412
# Household                    3389
# Other noninstitutional       3350
# Military                     3327
# Name: count, dtype: int64

# %%
hh_id_1.household_id.nunique()
# Out:
# 334

# %% [markdown]
# # Let's do some quick and dirty calculations of the number of simulants in each duplication category

# %%
# Get list of ages under 18 because we can't directly do comparisons with Categoricals
under_18_ages = list(map(str, range(18)))
in_households_under_18 = census.query(f"age in {under_18_ages} and housing_type == 'Household'")
in_households_under_18
# Out:
#              simulant_id   household_id   first_name middle_initial  \
# 17         1007000000017  1007000000015      Aaliyah              E
# 25         1007000000025  1007000000018        Aaron              E
# 28         1007000000028  1007000000019        Aaron              E
# 34         1007000000034  1007000000021       Olivia              J
# 35         1007000000035  1007000000021        Aaron              E
# ...                  ...            ...          ...            ...
# 330811465  9971000665249  9971000267275      Ernesto              W
# 330811504  9971000182680  9971000073564       Robert              B
# 330811512  9971000610423  9971000405219  Christopher              A
# 330811514  9971000973328  9971000308163      Justice              P
# 330811531  9971000657806  9971000264301      Makenna              K
#
#               last_name age date_of_birth street_number      street_name  \
# 17                Wiles  12    05/21/2007          7458       pawley ave
# 25              Roberts  16    07/22/2003          2103       south bdwy
# 28              Jackson  11    05/04/2008          1146       ocean avnu
# 34              Whiddon  12    11/25/2007          1480          high st
# 35              Whiddon   9    01/12/2011          1480          high st
# ...                 ...  ..           ...           ...              ...
# 330811465        Bryant  14    01/14/2003        116-09      w payran st
# 330811504  Torres-Mejia  17    03/02/2003         10195  chases grove ro
# 330811512     Gutierrez  17    10/22/2002         36206              NaN
# 330811514          King  17    05/29/2002         21509       gregory st
# 330811531       Freeman   6    08/23/2013       132-142     first street
#
#             unit_number              city state zipcode housing_type  \
# 17                  NaN            stokes    OH   43506    Household
# 25                  NaN            spring    TX   75165    Household
# 28                  NaN            smyrna    TN   37334    Household
# 34                  NaN  st. clair shores    MI   49638    Household
# 35                  NaN  st. clair shores    MI   49638    Household
# ...                 ...               ...   ...     ...          ...
# 330811465  4th platform     san francisco    CA   90036    Household
# 330811504           NaN          portland    OR   97140    Household
# 330811512           NaN     green oak twp    MI   49315    Household
# 330811514           NaN         woodstock    GA   30442    Household
# 330811531           NaN          columbus    OH   45406    Household
#
#           relationship_to_reference_person     sex race_ethnicity  year
# 17                                 Sibling  Female          White  2020
# 25                        Biological child    Male          White  2020
# 28                        Biological child    Male          White  2020
# 34                        Biological child  Female          White  2020
# 35                              Grandchild    Male          White  2020
# ...                                    ...     ...            ...   ...
# 330811465                   Other relative    Male          Black  2020
# 330811504                   Other relative    Male         Latino  2020
# 330811512                   Other relative    Male         Latino  2020
# 330811514                   Other relative  Female          Black  2020
# 330811531                   Other relative  Female          White  2020
#
# [70342284 rows x 18 columns]

# %%
in_households_under_18_dups = duplicates.query(f"age in {under_18_ages} and housing_type == 'Household'")
in_households_under_18_dups
# Out:
#              simulant_id   household_id   first_name middle_initial  \
# 17         1007000000017  1007000000015      Aaliyah              E
# 2898       1007000002998  1007000001255      Janiyah              C
# 4506       1007000004678  1007000001947        Ayden              D
# 5059       1007000005250  1007000002157         Sean              A
# 7852       1007000008108  1007000003309       Daniel              A
# ...                  ...            ...          ...            ...
# 330811465  9971000665249  9971000267275      Ernesto              W
# 330811504  9971000182680  9971000073564       Robert              B
# 330811512  9971000610423  9971000405219  Christopher              A
# 330811514  9971000973328  9971000308163      Justice              P
# 330811531  9971000657806  9971000264301      Makenna              K
#
#               last_name age date_of_birth street_number      street_name  \
# 17                Wiles  12    05/21/2007          7458       pawley ave
# 2898            Nannini   9    02/04/2011         18005      isleview dr
# 4506           Williams   9    06/13/2010          1523  green valley rd
# 5059            Hopkins  10    10/05/2009           NaN     sweetwood dr
# 7852             Taylor  12    02/16/2008           NaN     n ramunno dr
# ...                 ...  ..           ...           ...              ...
# 330811465        Bryant  14    01/14/2003        116-09      w payran st
# 330811504  Torres-Mejia  17    03/02/2003         10195  chases grove ro
# 330811512     Gutierrez  17    10/22/2002         36206              NaN
# 330811514          King  17    05/29/2002         21509       gregory st
# 330811531       Freeman   6    08/23/2013       132-142     first street
#
#             unit_number           city state zipcode housing_type  \
# 17                  NaN         stokes    OH   43506    Household
# 2898                NaN     greenville    SC   29040    Household
# 4506                NaN      boonville    IN   46342    Household
# 5059                NaN     pine bluff    AR   71801    Household
# 7852                NaN      maryville    TN   37210    Household
# ...                 ...            ...   ...     ...          ...
# 330811465  4th platform  san francisco    CA   90036    Household
# 330811504           NaN       portland    OR   97140    Household
# 330811512           NaN  green oak twp    MI   49315    Household
# 330811514           NaN      woodstock    GA   30442    Household
# 330811531           NaN       columbus    OH   45406    Household
#
#           relationship_to_reference_person     sex race_ethnicity  year
# 17                                 Sibling  Female          White  2020
# 2898                      Biological child  Female          White  2020
# 4506                      Biological child    Male          Black  2020
# 5059                             Stepchild    Male          White  2020
# 7852                 Roommate or housemate    Male          Black  2020
# ...                                    ...     ...            ...   ...
# 330811465                   Other relative    Male          Black  2020
# 330811504                   Other relative    Male         Latino  2020
# 330811512                   Other relative    Male         Latino  2020
# 330811514                   Other relative  Female          Black  2020
# 330811531                   Other relative  Female          White  2020
#
# [334963 rows x 18 columns]

# %%
len(in_households_under_18_dups) / len(in_households_under_18)
# Out:
# 0.004761901106310395
